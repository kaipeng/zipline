# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK','SPY']
fields=['CALL_IMP_VOL_30D','CALL_IMP_VOL_60D','CALL_IMP_VOL_90D']

algo_name = "Equal Weighted - Sector ETFs"
data_name = 'bbg_sector_vol_data-12yr'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle(data_name+'.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYE EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYF EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYC EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYK EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'SPY EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 10 (items) x 3480 (major_axis) x 9 (minor_axis)
# Items axis: IYE to SPY
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to CALL_IMP_VOL_90D

# %%
import pandas as pd
data = pd.read_pickle(data_name+'.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

# Define algorithm
def initialize(context):                  
    # Register 3 histories that maintain windows of trailing data
    context.windows = [83]
    
    for t in context.windows:
        add_history(t, '1d', 'price')
        
    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.002))

def handle_data(context, data):
    # Skip first 60 days to get full windows
    context.i += 1
    if context.i < context.windows[-1] or (context.i % 27 != 0):
        return
    
    # Progess report
    if context.i % 1 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    hist_used = history(context.windows[-1], '1d', 'price')
    del hist_used['SPY']
    minvarport = zip(hist_used.keys().values, minvar(hist_used.values))
    
    for sec, weight in minvarport:
        #target=weight*(context.portfolio.portfolio_value)
        target=1.0/len(minvarport)*(context.portfolio.portfolio_value)

        order_target_value(sec, target)
        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-weight', target)
        

        
def minvar(prices):
    cov = np.cov((prices[1:] / prices[:-1] - 1).transpose())
    vu = np.array(cov.shape[1] * [1], float)
    num = np.dot(np.linalg.inv(cov), vu)
    den = np.dot(vu, num)
    return num / den  

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle(data_name+'.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  108 2001-06-06 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  135 2001-07-16 00:00:00+00:00 Pos Value:  94081.3215 PnL:  -5990.55344333
# Bars Completed:
#  162 2001-08-22 00:00:00+00:00 Pos Value:  92000.0663 PnL:  -8002.37567933
# Bars Completed:
#  189 2001-10-05 00:00:00+00:00 Pos Value:  84367.7722 PnL:  -15600.112824
# Bars Completed:
#  216 2001-11-13 00:00:00+00:00 Pos Value:  89762.5352 PnL:  -10123.9160617
# Bars Completed:
#  243 2001-12-21 00:00:00+00:00 Pos Value:  91201.2898 PnL:  -8779.43471143
# Bars Completed:
#  270 2002-02-01 00:00:00+00:00 Pos Value:  89193.4587 PnL:  -10818.8286871
# Bars Completed:
#  297 2002-03-13 00:00:00+00:00 Pos Value:  92439.9029 PnL:  -7611.93898321
# Bars Completed:
#  324 2002-04-22 00:00:00+00:00 Pos Value:  89016.5381 PnL:  -11003.3511043
# Bars Completed:
#  351 2002-05-30 00:00:00+00:00 Pos Value:  86125.1762 PnL:  -13887.3050642
# Bars Completed:
#  378 2002-07-09 00:00:00+00:00 Pos Value:  76940.2237 PnL:  -23027.4526413
# Bars Completed:
#  405 2002-08-15 00:00:00+00:00 Pos Value:  74410.4836 PnL:  -25621.4775571
# Bars Completed:
#  432 2002-09-24 00:00:00+00:00 Pos Value:  65829.3375 PnL:  -34208.1428757
# Bars Completed:
#  459 2002-10-31 00:00:00+00:00 Pos Value:  71601.2542 PnL:  -28383.3165346
# Bars Completed:
#  486 2002-12-10 00:00:00+00:00 Pos Value:  73806.8019 PnL:  -26115.4534767
# Bars Completed:
#  513 2003-01-21 00:00:00+00:00 Pos Value:  72768.547 PnL:  -27191.4479018
# Bars Completed:
#  540 2003-02-28 00:00:00+00:00 Pos Value:  68793.9296 PnL:  -31185.9914075
# Bars Completed:
#  567 2003-04-08 00:00:00+00:00 Pos Value:  71422.1573 PnL:  -28569.883389
# Bars Completed:
#  594 2003-05-16 00:00:00+00:00 Pos Value:  77227.1209 PnL:  -22761.7435228
# Bars Completed:
#  621 2003-06-25 00:00:00+00:00 Pos Value:  80429.7905 PnL:  -19520.3627251
# Bars Completed:
#  648 2003-08-04 00:00:00+00:00 Pos Value:  81020.42 PnL:  -18888.6745285
# Bars Completed:
#  675 2003-09-11 00:00:00+00:00 Pos Value:  84249.3885 PnL:  -15776.362938
# Bars Completed:
#  702 2003-10-20 00:00:00+00:00 Pos Value:  85981.4988 PnL:  -14003.5010677
# Bars Completed:
#  729 2003-11-26 00:00:00+00:00 Pos Value:  87917.6706 PnL:  -12078.6306852
# Bars Completed:
#  756 2004-01-07 00:00:00+00:00 Pos Value:  94713.7846 PnL:  -5327.39411833
# Bars Completed:
#  783 2004-02-17 00:00:00+00:00 Pos Value:  97344.8096 PnL:  -2634.75322587
# Bars Completed:
#  810 2004-03-25 00:00:00+00:00 Pos Value:  93222.2548 PnL:  -6757.99033732
# Bars Completed:
#  837 2004-05-04 00:00:00+00:00 Pos Value:  94967.9513 PnL:  -5062.13393946
# Bars Completed:
#  864 2004-06-14 00:00:00+00:00 Pos Value:  94823.3039 PnL:  -5084.84616522
# Bars Completed:
#  891 2004-07-22 00:00:00+00:00 Pos Value:  93667.1764 PnL:  -6310.92707308
# Bars Completed:
#  918 2004-08-30 00:00:00+00:00 Pos Value:  94189.9738 PnL:  -5765.905415
# Bars Completed:
#  945 2004-10-07 00:00:00+00:00 Pos Value:  98365.9658 PnL:  -1575.08583305
# Bars Completed:
#  972 2004-11-15 00:00:00+00:00 Pos Value:  102493.4856 PnL:  2600.54739004
# Bars Completed:
#  999 2004-12-23 00:00:00+00:00 Pos Value:  105601.0849 PnL:  5575.80588389
# Bars Completed:
#  1026 2005-02-02 00:00:00+00:00 Pos Value:  104340.9052 PnL:  4348.80648239
# Bars Completed:
#  1053 2005-03-14 00:00:00+00:00 Pos Value:  106728.6059 PnL:  6831.21278042
# Bars Completed:
#  1080 2005-04-21 00:00:00+00:00 Pos Value:  102295.2101 PnL:  2337.22945338
# Bars Completed:
#  1107 2005-05-31 00:00:00+00:00 Pos Value:  104895.9035 PnL:  4985.69225064
# Bars Completed:
#  1134 2005-07-08 00:00:00+00:00 Pos Value:  107666.4484 PnL:  7619.9246472
# Bars Completed:
#  1161 2005-08-16 00:00:00+00:00 Pos Value:  109021.8275 PnL:  9053.40184178
# Bars Completed:
#  1188 2005-09-23 00:00:00+00:00 Pos Value:  108391.5318 PnL:  8588.85253908
# Bars Completed:
#  1215 2005-11-01 00:00:00+00:00 Pos Value:  107475.4647 PnL:  7608.12873619
# Bars Completed:
#  1242 2005-12-09 00:00:00+00:00 Pos Value:  113186.6081 PnL:  13113.5284345
# Bars Completed:
#  1269 2006-01-20 00:00:00+00:00 Pos Value:  114187.5148 PnL:  14101.473433
# Bars Completed:
#  1296 2006-03-01 00:00:00+00:00 Pos Value:  117420.8051 PnL:  17511.1802328
# Bars Completed:
#  1323 2006-04-07 00:00:00+00:00 Pos Value:  119257.9163 PnL:  19308.9225266
# Bars Completed:
#  1350 2006-05-17 00:00:00+00:00 Pos Value:  116761.9466 PnL:  16838.7593236
# Bars Completed:
#  1377 2006-06-26 00:00:00+00:00 Pos Value:  114976.698 PnL:  14858.209215
# Bars Completed:
#  1404 2006-08-03 00:00:00+00:00 Pos Value:  117393.7865 PnL:  17369.9709136
# Bars Completed:
#  1431 2006-09-12 00:00:00+00:00 Pos Value:  119953.0711 PnL:  19950.5129432
# Bars Completed:
#  1458 2006-10-19 00:00:00+00:00 Pos Value:  125635.7115 PnL:  25479.5271012
# Bars Completed:
#  1485 2006-11-28 00:00:00+00:00 Pos Value:  127740.7729 PnL:  27782.7166772
# Bars Completed:
#  1512 2007-01-09 00:00:00+00:00 Pos Value:  129781.7817 PnL:  29804.0509742
# Bars Completed:
#  1539 2007-02-16 00:00:00+00:00 Pos Value:  136008.4096 PnL:  35914.1590705
# Bars Completed:
#  1566 2007-03-28 00:00:00+00:00 Pos Value:  133523.2761 PnL:  33585.0611674
# Bars Completed:
#  1593 2007-05-07 00:00:00+00:00 Pos Value:  141926.7866 PnL:  42106.7654624
# Bars Completed:
#  1620 2007-06-14 00:00:00+00:00 Pos Value:  145207.0917 PnL:  45118.4700597
# Bars Completed:
#  1647 2007-07-24 00:00:00+00:00 Pos Value:  145690.1681 PnL:  45772.3696389
# Bars Completed:
#  1674 2007-08-30 00:00:00+00:00 Pos Value:  139915.9472 PnL:  39897.5894361
# Bars Completed:
#  1701 2007-10-09 00:00:00+00:00 Pos Value:  150630.182 PnL:  50727.3384339
# Bars Completed:
#  1728 2007-11-15 00:00:00+00:00 Pos Value:  139927.6261 PnL:  39892.1268285
# Bars Completed:
#  1755 2007-12-26 00:00:00+00:00 Pos Value:  145791.2475 PnL:  45799.3133634
# Bars Completed:
#  1782 2008-02-05 00:00:00+00:00 Pos Value:  130056.8378 PnL:  30144.0214588
# Bars Completed:
#  1809 2008-03-14 00:00:00+00:00 Pos Value:  126267.8145 PnL:  26227.2073393
# Bars Completed:
#  1836 2008-04-23 00:00:00+00:00 Pos Value:  135696.8959 PnL:  35588.307336
# Bars Completed:
#  1863 2008-06-02 00:00:00+00:00 Pos Value:  138999.5897 PnL:  39015.5794231
# Bars Completed:
#  1890 2008-07-10 00:00:00+00:00 Pos Value:  125927.2225 PnL:  25943.0370128
# Bars Completed:
#  1917 2008-08-18 00:00:00+00:00 Pos Value:  129210.183 PnL:  29364.8737037
# Bars Completed:
#  1944 2008-09-25 00:00:00+00:00 Pos Value:  121518.1852 PnL:  21204.6072908
# Bars Completed:
#  1971 2008-11-03 00:00:00+00:00 Pos Value:  94237.2725 PnL:  -5777.87801524
# Bars Completed:
#  1998 2008-12-11 00:00:00+00:00 Pos Value:  85079.6019 PnL:  -15062.251819
# Bars Completed:
#  2025 2009-01-22 00:00:00+00:00 Pos Value:  81708.4299 PnL:  -18356.5686201
# Bars Completed:
#  2052 2009-03-03 00:00:00+00:00 Pos Value:  69395.9224 PnL:  -30647.9373223
# Bars Completed:
#  2079 2009-04-09 00:00:00+00:00 Pos Value:  87168.0689 PnL:  -12772.3301247
# Bars Completed:
#  2106 2009-05-19 00:00:00+00:00 Pos Value:  93751.2489 PnL:  -6119.02673327
# Bars Completed:
#  2133 2009-06-26 00:00:00+00:00 Pos Value:  94633.9808 PnL:  -5344.4213336
# Bars Completed:
#  2160 2009-08-05 00:00:00+00:00 Pos Value:  103883.8717 PnL:  3931.42696603
# Bars Completed:
#  2187 2009-09-14 00:00:00+00:00 Pos Value:  109183.568 PnL:  9262.90106403
# Bars Completed:
#  2214 2009-10-21 00:00:00+00:00 Pos Value:  112687.7414 PnL:  12684.4824627
# Bars Completed:
#  2241 2009-11-30 00:00:00+00:00 Pos Value:  114087.1646 PnL:  14079.6169621
# Bars Completed:
#  2268 2010-01-08 00:00:00+00:00 Pos Value:  121299.9503 PnL:  21229.167161
# Bars Completed:
#  2295 2010-02-18 00:00:00+00:00 Pos Value:  116997.7192 PnL:  17058.378358
# Bars Completed:
#  2322 2010-03-29 00:00:00+00:00 Pos Value:  124496.457 PnL:  24529.0913477
# Bars Completed:
#  2349 2010-05-06 00:00:00+00:00 Pos Value:  119649.6482 PnL:  19685.6344435
# Bars Completed:
#  2376 2010-06-15 00:00:00+00:00 Pos Value:  119264.027 PnL:  19252.8027435
# Bars Completed:
#  2403 2010-07-23 00:00:00+00:00 Pos Value:  118226.6816 PnL:  18176.3701432
# Bars Completed:
#  2430 2010-08-31 00:00:00+00:00 Pos Value:  113283.4754 PnL:  13310.55254
# Bars Completed:
#  2457 2010-10-08 00:00:00+00:00 Pos Value:  127127.2224 PnL:  27076.063239
# Bars Completed:
#  2484 2010-11-16 00:00:00+00:00 Pos Value:  129132.8744 PnL:  29018.2201282
# Bars Completed:
#  2511 2010-12-27 00:00:00+00:00 Pos Value:  139160.4802 PnL:  39182.0213193
# Bars Completed:
#  2538 2011-02-03 00:00:00+00:00 Pos Value:  144131.2242 PnL:  44215.120709
# Bars Completed:
#  2565 2011-03-15 00:00:00+00:00 Pos Value:  141697.3933 PnL:  41840.3533846
# Bars Completed:
#  2592 2011-04-21 00:00:00+00:00 Pos Value:  149575.0595 PnL:  49578.3839833
# Bars Completed:
#  2619 2011-06-01 00:00:00+00:00 Pos Value:  148172.6395 PnL:  48209.3169818
# Bars Completed:
#  2646 2011-07-11 00:00:00+00:00 Pos Value:  148742.3527 PnL:  48765.7520797
# Bars Completed:
#  2673 2011-08-17 00:00:00+00:00 Pos Value:  133032.7138 PnL:  32974.584775
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  127819.988 PnL:  27780.1053658
# Bars Completed:
#  2727 2011-11-02 00:00:00+00:00 Pos Value:  136457.3636 PnL:  36545.2294572
# Bars Completed:
#  2754 2011-12-12 00:00:00+00:00 Pos Value:  135921.6219 PnL:  35997.6893523
# Bars Completed:
#  2781 2012-01-23 00:00:00+00:00 Pos Value:  145326.9342 PnL:  45356.7571499
# Bars Completed:
#  2808 2012-03-01 00:00:00+00:00 Pos Value:  152134.4744 PnL:  52120.4513464
# Bars Completed:
#  2835 2012-04-10 00:00:00+00:00 Pos Value:  148844.1895 PnL:  48838.7755451
# Bars Completed:
#  2862 2012-05-17 00:00:00+00:00 Pos Value:  142898.7086 PnL:  42706.2703267
# Bars Completed:
#  2889 2012-06-26 00:00:00+00:00 Pos Value:  144630.1648 PnL:  44604.1945188
# Bars Completed:
#  2916 2012-08-03 00:00:00+00:00 Pos Value:  152547.9748 PnL:  52614.9109115
# Bars Completed:
#  2943 2012-09-12 00:00:00+00:00 Pos Value:  159744.7464 PnL:  59874.2528058
# Bars Completed:
#  2970 2012-10-19 00:00:00+00:00 Pos Value:  159743.4419 PnL:  59684.5772482
# Bars Completed:
#  2997 2012-11-30 00:00:00+00:00 Pos Value:  158210.7459 PnL:  58127.8109409
# Bars Completed:
#  3024 2013-01-10 00:00:00+00:00 Pos Value:  165841.9798 PnL:  65783.02764
# Bars Completed:
#  3051 2013-02-20 00:00:00+00:00 Pos Value:  168927.8104 PnL:  69049.8021377
# Bars Completed:
#  3078 2013-04-01 00:00:00+00:00 Pos Value:  174240.7612 PnL:  74090.3857288
# Bars Completed:
#  3105 2013-05-08 00:00:00+00:00 Pos Value:  182946.2976 PnL:  83025.3156273
# Bars Completed:
#  3132 2013-06-17 00:00:00+00:00 Pos Value:  183201.9009 PnL:  83252.4762262
# Bars Completed:
#  3159 2013-07-25 00:00:00+00:00 Pos Value:  190773.8051 PnL:  90702.5673256
# Bars Completed:
#  3186 2013-09-03 00:00:00+00:00 Pos Value:  185853.8751 PnL:  85888.4346209
# Bars Completed:
#  3213 2013-10-10 00:00:00+00:00 Pos Value:  193070.5211 PnL:  92932.8031196
# Bars Completed:
#  3240 2013-11-18 00:00:00+00:00 Pos Value:  203585.5238 PnL:  103671.916518
# Bars Completed:
#  3267 2013-12-27 00:00:00+00:00 Pos Value:  210537.7765 PnL:  110450.758418
# Bars Completed:
#  3294 2014-02-06 00:00:00+00:00 Pos Value:  202372.4773 PnL:  102351.477513
# Bars Completed:
#  3321 2014-03-18 00:00:00+00:00 Pos Value:  214973.0578 PnL:  114814.284406
# Bars Completed:
#  3348 2014-04-25 00:00:00+00:00 Pos Value:  212672.4765 PnL:  112572.535106
# Bars Completed:
#  3375 2014-06-04 00:00:00+00:00 Pos Value:  220514.3824 PnL:  120497.390302
# Bars Completed:
#  3402 2014-07-14 00:00:00+00:00 Pos Value:  226780.1634 PnL:  126672.922102
# Bars Completed:
#  3429 2014-08-20 00:00:00+00:00 Pos Value:  227648.2771 PnL:  127675.230602
# Bars Completed:
# [2014-11-20 23:20] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-20 23:20] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-20 23:20] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3456 2014-09-29 00:00:00+00:00 Pos Value:  225889.69 PnL:  125712.567695

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 100000.0/data['SPY']['price'][123]*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-weight']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  23.622

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(14)]]
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.113424                 0.139178 -0.010789
# 2013-10              0.120550                 0.276615  0.029612
# 2012-10              0.160699                 0.138486  0.006947
# 2011-10              0.224783                 0.068249  0.006699
# 2010-10              0.187743                 0.206438  0.060585
# 2009-10              0.366231                 0.137894  0.067199
# 2008-10              0.338569                -0.370497 -0.011892
# 2007-10              0.132460                 0.183142  0.061914
# 2006-10              0.108444                 0.174660  0.028087
# 2005-10              0.106923                 0.100640  0.033001
# 2004-10              0.111893                 0.124186  0.050140
# 2003-10              0.178880                 0.214250  0.037511
# 2002-10              0.248443                -0.151607  0.005419
# 2014-09              0.105680                 0.170544 -0.004758
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  1.015831
# 2013-10                      0.243868              0.117836  1.012913
# 2012-10                      0.126753              0.153977  1.038296
# 2011-10                      0.059192              0.215031  1.040654
# 2010-10                      0.141933              0.181490  1.028052
# 2009-10                      0.069615              0.358120  1.016371
# 2008-10                     -0.374750              0.346362  0.958410
# 2007-10                      0.124418              0.135401  0.962031
# 2006-10                      0.141614              0.100152  1.054070
# 2005-10                      0.067961              0.105708  0.987065
# 2004-10                      0.075654              0.112001  0.969545
# 2003-10                      0.186224              0.185829  0.945211
# 2002-10                     -0.164204              0.254499  0.959853
# 2014-09                      0.172900              0.102981  1.014000
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.138078    -0.024311      0.083470  1.217358  1.583777
# 2013-10            0.275615     0.097692      0.063340  2.286318  3.236263
# 2012-10            0.136681     0.041651      0.102722  0.850539  1.376008
# 2011-10            0.067049     0.029188      0.215869  0.298283  0.374321
# 2010-10            0.204238     0.165018      0.159094  1.087859  1.492359
# 2009-10            0.134194     0.100030      0.310677  0.366419  0.571547
# 2008-10           -0.383934     0.003787      0.445398 -1.133991 -1.560722
# 2007-10            0.142742     0.129788      0.100158  1.077621  1.289473
# 2006-10            0.124760     0.072948      0.091964  1.150458  1.819774
# 2005-10            0.057540     0.081355      0.074656  0.538146  0.853313
# 2004-10            0.101324     0.102626      0.072016  0.905539  1.416085
# 2003-10            0.201150     0.039401      0.145235  1.124494  1.864285
# 2002-10           -0.166207     0.018286      0.334561 -0.668993 -1.170608
# 2014-09            0.169244    -0.006667      0.060134  1.601478  2.141413
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
# 2014-09                252                0.001300
