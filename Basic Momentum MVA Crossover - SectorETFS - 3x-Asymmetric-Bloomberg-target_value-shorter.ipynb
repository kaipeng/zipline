# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['TLT','IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=[]
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))

# %%
data.to_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg-target_value-shorter"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(20, '1d', 'price')
    add_history(40, '1d', 'price')
    add_history(80, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(20, '1d', 'price').mean()
    med_mavg = history(40, '1d', 'price').mean()
    long_mavg = history(80, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0.0
        if short_mavg[sec] > med_mavg[sec]:
            target += .2
        if short_mavg[sec] > long_mavg[sec]:
            target += .3
        if med_mavg[sec] > long_mavg[sec]:
            target += .5

        if short_mavg[sec] < med_mavg[sec]:
            target -= .1
        if short_mavg[sec] < long_mavg[sec]:
            target -= .05
        if med_mavg[sec] < long_mavg[sec]:
            target -= 0
            
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
        

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  49035.5356 PnL:  909.211665383
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  -14074.1637 PnL:  -376.230805465
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  64490.8652 PnL:  -5275.6013332
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  96474.9516 PnL:  -3328.81675052
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  71242.4069 PnL:  3173.37544849
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  99923.2312 PnL:  10494.8973455
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  42868.4834 PnL:  8434.04237671
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  116520.8636 PnL:  16450.3019078
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  12655.7128 PnL:  15590.7840579
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  21512.7881 PnL:  15321.585773
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  102426.8038 PnL:  16631.8685498
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  33159.0739 PnL:  16266.0948087
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  124986.1001 PnL:  24872.5081241
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  129321.3503 PnL:  29365.8420471
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  74670.2436 PnL:  28570.4824941
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  7410.8648 PnL:  20899.7394
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  1721.0464 PnL:  15545.8209741
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  -3706.5195 PnL:  15130.0986792
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  90828.9361 PnL:  13944.3446152
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  125344.3885 PnL:  25447.5712072
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  50401.1781 PnL:  30703.6877625
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  -4649.7882 PnL:  27284.4750178
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  119600.0225 PnL:  39881.6044299
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  125656.9586 PnL:  51581.5404582
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  11887.4895 PnL:  44944.666633
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  145466.6293 PnL:  55536.2137655
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  51930.9757 PnL:  53133.6729365
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  33738.0093 PnL:  55700.4173568
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  120194.7702 PnL:  66027.8010471
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  119346.4578 PnL:  70707.6750199
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  105752.094 PnL:  80158.1950459
# Bars Completed:
# [2014-11-12 20:39] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-12 20:39] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-12 20:39] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  183560.7805 PnL:  89417.1964704

# %%
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 180)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
# Out:
# Total Commish:  6340.56

# %%
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.080297                 0.061504 -0.037985
# 2013-10              0.089159                 0.122306 -0.053384
# 2012-10              0.093928                 0.093692  0.030547
# 2011-10              0.089465                 0.072672  0.063945
# 2010-10              0.112518                 0.071126  0.002445
# 2009-10              0.139791                 0.117435  0.107039
# 2008-10              0.076674                -0.136636 -0.132011
# 2007-10              0.086133                 0.069246 -0.016044
# 2006-10              0.060839                 0.056380 -0.036215
# 2005-10              0.062653                 0.030625 -0.024459
# 2004-10              0.068507                 0.073975  0.023798
# 2003-10              0.103194                 0.064184 -0.020055
# 2002-10              0.059968                -0.025554 -0.036465
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.671385
# 2013-10                      0.243868              0.117836  0.719279
# 2012-10                      0.126753              0.153977  0.490928
# 2011-10                      0.059192              0.215031  0.129802
# 2010-10                      0.141933              0.181490  0.475770
# 2009-10                      0.069615              0.358120  0.101573
# 2008-10                     -0.374750              0.346362  0.046529
# 2007-10                      0.124418              0.135401  0.534292
# 2006-10                      0.141614              0.100152  0.465523
# 2005-10                      0.067961              0.105708  0.482034
# 2004-10                      0.075654              0.112001  0.517401
# 2003-10                      0.186224              0.185829  0.410914
# 2002-10                     -0.164204              0.254499  0.020631
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.060404    -0.106633      0.051542  0.752262  0.936234
# 2013-10            0.121306    -0.154635      0.056901  1.360562  1.707946
# 2012-10            0.091887    -0.024410      0.058587  0.978278  1.520811
# 2011-10            0.071472    -0.001996      0.071442  0.798885  1.094595
# 2010-10            0.068926    -0.039194      0.099941  0.612576  0.720566
# 2009-10            0.113735    -0.001912      0.080032  0.813605  1.109523
# 2008-10           -0.150073     0.049310      0.125261 -1.957289 -2.695253
# 2007-10            0.028846    -0.044853      0.065060  0.334904  0.369710
# 2006-10            0.006480    -0.076766      0.052218  0.106518  0.142879
# 2005-10           -0.012475    -0.037467      0.039635 -0.199108 -0.290002
# 2004-10            0.051113    -0.005305      0.063952  0.746093  1.074003
# 2003-10            0.051084    -0.058554      0.089991  0.495034  0.711787
# 2002-10           -0.040154     0.030250      0.057865 -0.669596 -0.917616
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
