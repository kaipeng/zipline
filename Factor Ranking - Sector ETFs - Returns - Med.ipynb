# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg
from zipline.data.loader import load_bars_from_yahoo

import pandas as pd

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
fields=[]
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle('bbg_sector_etf_data-12yr.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYE EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYF EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYC EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYK EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 9 (items) x 3480 (major_axis) x 6 (minor_axis)
# Items axis: IYE to IYK
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price

# %%
import pandas as pd
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Factor Ranking - Sector ETFs - Returns - Med"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(10, '1d', 'price')
    add_history(20, '1d', 'price')
    add_history(60, '1d', 'price')

    context.i = 0
    #context.secs = secs

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200 or (context.i % 20 != 0):
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_return = history(5, '1d', 'price').ix[0]
    for k,v in data.items():
        short_return[k] = data[k].price / short_return[k]
    med_return = history(20, '1d', 'price').ix[0]
    for k,v in data.items():
        med_return[k] = data[k].price / med_return[k]    
    long_return = history(60, '1d', 'price').ix[0]
    for k,v in data.items():
        long_return[k] = data[k].price / long_return[k]
    #print short_return, med_return
    short_return_rank = short_return.rank()
    med_return_rank = med_return.rank()
    long_return_rank = long_return.rank()
    
    for sec in med_return_rank.keys():
        ##### Trading logic ######
        target = 0
        if(med_return_rank[sec] > len(med_return_rank.keys())/2.0+1):
            target = 1
        elif(med_return_rank[sec] < len(med_return_rank.keys())/2.0):
            target = -1
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_return_rank[sec])
        record(sec+'-m_ma', med_return_rank[sec])
        record(sec+'-l_ma', long_return_rank[sec])
    

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  753.3173 PnL:  -1103.56439763
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  1206.3485 PnL:  5459.49240473
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  -2679.3235 PnL:  -2673.20455178
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  -973.5765 PnL:  -775.94237104
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  -16.1084 PnL:  -1016.40412431
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  1693.8507 PnL:  -602.780822656
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  1766.595 PnL:  -3803.30502
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  -1197.9752 PnL:  -7205.64257644
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  300.3373 PnL:  -6366.54738554
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  32.1055 PnL:  -10304.8160257
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  -862.6227 PnL:  -12043.098841
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  1323.0543 PnL:  -11285.6727524
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  -778.0301 PnL:  -12350.9608222
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  -29.9042 PnL:  -12219.0708315
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  287.1655 PnL:  -9154.68690324
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  -786.2517 PnL:  -12100.4186137
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  -1615.5982 PnL:  -11348.0756424
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  -162.2718 PnL:  -8674.25703348
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  996.6229 PnL:  -7101.48933958
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  -469.1588 PnL:  -13579.6686881
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  359.8305 PnL:  -14592.2258366
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  -716.6503 PnL:  -16065.8452417
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  359.0206 PnL:  -15613.1379763
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  -1312.9451 PnL:  -16859.066747
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  1874.8288 PnL:  -15760.8028131
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  446.4267 PnL:  -16117.3626443
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  808.0877 PnL:  -11337.3361857
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  -56.2416 PnL:  -12743.2212593
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  1548.3862 PnL:  -10739.7507334
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  11.2121 PnL:  -13603.2466432
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  570.0221 PnL:  -14598.9606542
# Bars Completed:
# [2014-11-13 22:17] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-13 22:17] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-13 22:17] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  -535.5615 PnL:  -15249.5246675

# %%
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-m_ma']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  11368.32

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.025762                 0.017756  0.019524
# 2013-10              0.028754                -0.023593 -0.018281
# 2012-10              0.031910                 0.043016  0.039366
# 2011-10              0.041583                 0.008937  0.009962
# 2010-10              0.033567                -0.034576 -0.037987
# 2009-10              0.080869                -0.046844 -0.046643
# 2008-10              0.089042                -0.011592 -0.041931
# 2007-10              0.031639                 0.047313  0.005449
# 2006-10              0.041476                -0.022939 -0.068048
# 2005-10              0.035983                -0.051490 -0.094369
# 2004-10              0.037653                -0.038474 -0.059858
# 2003-10              0.055334                -0.018518 -0.040072
# 2002-10              0.072102                -0.003371 -0.033233
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213 -0.019574
# 2013-10                      0.243868              0.117836 -0.025991
# 2012-10                      0.126753              0.153977  0.014770
# 2011-10                      0.059192              0.215031 -0.038370
# 2010-10                      0.141933              0.181490  0.008666
# 2009-10                      0.069615              0.358120 -0.059174
# 2008-10                     -0.374750              0.346362 -0.043542
# 2007-10                      0.124418              0.135401  0.017415
# 2006-10                      0.141614              0.100152 -0.052238
# 2005-10                      0.067961              0.105708 -0.008918
# 2004-10                      0.075654              0.112001 -0.028002
# 2003-10                      0.186224              0.185829  0.048833
# 2002-10                     -0.164204              0.254499 -0.085354
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.016656    -0.068796      0.015249  0.646523  1.043481
# 2013-10           -0.024593    -0.126109      0.051161 -0.855288 -1.268600
# 2012-10            0.041211    -0.036050      0.020079  1.291498  1.900360
# 2011-10            0.007737    -0.019643      0.042157  0.186052  0.305823
# 2010-10           -0.036776    -0.063391      0.047144 -1.095608 -1.671643
# 2009-10           -0.050544    -0.028699      0.087478 -0.625010 -0.987144
# 2008-10           -0.025028     0.067924      0.078669 -0.281084 -0.383630
# 2007-10            0.006913    -0.036802      0.027982  0.218482  0.318129
# 2006-10           -0.072839    -0.088990      0.038211 -1.756176 -2.809523
# 2005-10           -0.094590    -0.069004      0.062840 -2.628736 -4.486040
# 2004-10           -0.061336    -0.061476      0.056325 -1.628996 -2.673311
# 2003-10           -0.031618    -0.069865      0.049669 -0.571397 -0.874562
# 2002-10           -0.017971     0.032396      0.060084 -0.249251 -0.373118
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
