# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK','SPY']
fields=['CALL_IMP_VOL_30D','CALL_IMP_VOL_60D','CALL_IMP_VOL_90D']

algo_name = "Minimum Variance Portfolio - Sector ETFs"
data_name = 'bbg_sector_vol_data-12yr'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle(data_name+'.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYE EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYF EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYC EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYK EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'SPY EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 10 (items) x 3480 (major_axis) x 9 (minor_axis)
# Items axis: IYE to SPY
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to CALL_IMP_VOL_90D

# %%
import pandas as pd
data = pd.read_pickle(data_name+'.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

# Define algorithm
def initialize(context):                  
    # Register 3 histories that maintain windows of trailing data
    context.windows = [71]
    
    for t in context.windows:
        add_history(t, '1d', 'price')
        
    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.002))

def handle_data(context, data):
    # Skip first 60 days to get full windows
    context.i += 1
    if context.i < context.windows[-1] or (context.i % context.windows[-1] != 0):
        return
    
    # Progess report
    if context.i % 1 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    hist_used = history(context.windows[-1], '1d', 'price')
    minvarport = zip(hist_used.keys().values, minvar(hist_used.values))
    
    for sec, weight in minvarport:
        target=weight*(context.portfolio.portfolio_value)
        order_target_value(sec, target)
        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-weight', weight)

        
def minvar(prices):
    cov = np.cov((prices[1:] / prices[:-1] - 1).transpose())
    vu = np.array(cov.shape[1] * [1], float)
    num = np.dot(np.linalg.inv(cov), vu)
    den = np.dot(vu, num)
    return num / den  

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle(data_name+'.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  23 2001-02-02 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  46 2001-03-08 00:00:00+00:00 Pos Value:  99804.1425 PnL:  -1710.65481774
#  713 2003-11-04 00:00:00+00:00 Pos Value:  82182.2123 PnL:  -18086.360872
# Bars Completed:
#  736 2003-12-08 00:00:00+00:00 Pos Value:  86447.4858 PnL:  -13571.3345065
# Bars Completed:
#  759 2004-01-12 00:00:00+00:00 Pos Value:  88378.2756 PnL:  -11963.1370827
# Bars Completed:
#  782 2004-02-13 00:00:00+00:00 Pos Value:  92092.6687 PnL:  -7182.31965598
# Bars Completed:
#  805 2004-03-18 00:00:00+00:00 Pos Value:  93594.8676 PnL:  -6425.0453063
# Bars Completed:
#  828 2004-04-21 00:00:00+00:00 Pos Value:  83574.8088 PnL:  -16775.0251277
# Bars Completed:
#  851 2004-05-24 00:00:00+00:00 Pos Value:  80299.847 PnL:  -21894.8102539
# Bars Completed:
#  874 2004-06-28 00:00:00+00:00 Pos Value:  79772.2182 PnL:  -19633.4556494
# Bars Completed:
#  897 2004-07-30 00:00:00+00:00 Pos Value:  78470.9811 PnL:  -21022.6278036
# Bars Completed:
#  920 2004-09-01 00:00:00+00:00 Pos Value:  80681.5336 PnL:  -18892.2890929
# Bars Completed:
#  943 2004-10-05 00:00:00+00:00 Pos Value:  77047.5049 PnL:  -23289.7451181
# Bars Completed:
#  966 2004-11-05 00:00:00+00:00 Pos Value:  80084.7307 PnL:  -20839.6646791
# Bars Completed:
#  989 2004-12-09 00:00:00+00:00 Pos Value:  79155.1671 PnL:  -20064.303834
# Bars Completed:
#  1012 2005-01-12 00:00:00+00:00 Pos Value:  80779.669 PnL:  -20561.4646362
# Bars Completed:
#  1035 2005-02-15 00:00:00+00:00 Pos Value:  79372.4753 PnL:  -20917.7674468
# Bars Completed:
#  1058 2005-03-21 00:00:00+00:00 Pos Value:  78626.6009 PnL:  -22369.4141705
# Bars Completed:
#  1081 2005-04-22 00:00:00+00:00 Pos Value:  75538.1533 PnL:  -24564.3368251
# Bars Completed:
#  1104 2005-05-25 00:00:00+00:00 Pos Value:  78846.69 PnL:  -21347.3321418
# Bars Completed:
#  1127 2005-06-28 00:00:00+00:00 Pos Value:  78911.588 PnL:  -20380.0205169
# Bars Completed:
#  1150 2005-08-01 00:00:00+00:00 Pos Value:  81208.8501 PnL:  -19503.7433068
# Bars Completed:
#  1173 2005-09-01 00:00:00+00:00 Pos Value:  78533.4185 PnL:  -21511.8095506
# Bars Completed:
#  1196 2005-10-05 00:00:00+00:00 Pos Value:  77173.051 PnL:  -22782.3921123
# Bars Completed:
#  1219 2005-11-07 00:00:00+00:00 Pos Value:  75198.9927 PnL:  -25487.675946
# Bars Completed:
#  1242 2005-12-09 00:00:00+00:00 Pos Value:  76349.2539 PnL:  -23264.4760292
# Bars Completed:
#  1265 2006-01-13 00:00:00+00:00 Pos Value:  78026.8522 PnL:  -22361.40683
# Bars Completed:
#  1288 2006-02-16 00:00:00+00:00 Pos Value:  84304.264 PnL:  -15746.7424573
# Bars Completed:
#  1311 2006-03-22 00:00:00+00:00 Pos Value:  88762.7185 PnL:  -11990.5026547
# Bars Completed:
#  1334 2006-04-25 00:00:00+00:00 Pos Value:  86287.4864 PnL:  -14464.6773674
# Bars Completed:
#  1357 2006-05-26 00:00:00+00:00 Pos Value:  90015.1251 PnL:  -9807.13660471
# Bars Completed:
#  1380 2006-06-29 00:00:00+00:00 Pos Value:  89439.3925 PnL:  -10581.5675695
# Bars Completed:
#  1403 2006-08-02 00:00:00+00:00 Pos Value:  97783.4764 PnL:  -2340.11476613
# Bars Completed:
#  1426 2006-09-05 00:00:00+00:00 Pos Value:  96917.632 PnL:  -3719.60135727
# Bars Completed:
#  1449 2006-10-06 00:00:00+00:00 Pos Value:  97189.6006 PnL:  -2892.01763595
# Bars Completed:
#  1472 2006-11-08 00:00:00+00:00 Pos Value:  97957.3761 PnL:  -2212.2468883
# Bars Completed:
#  1495 2006-12-12 00:00:00+00:00 Pos Value:  99225.8244 PnL:  -2072.55385926
# Bars Completed:
#  1518 2007-01-18 00:00:00+00:00 Pos Value:  103068.3856 PnL:  3263.21432093
# Bars Completed:
#  1541 2007-02-21 00:00:00+00:00 Pos Value:  102269.9513 PnL:  2235.62702427
# Bars Completed:
#  1564 2007-03-26 00:00:00+00:00 Pos Value:  102195.7572 PnL:  1661.43690685
# Bars Completed:
#  1587 2007-04-27 00:00:00+00:00 Pos Value:  110381.8477 PnL:  10855.7324902
# Bars Completed:
#  1610 2007-05-31 00:00:00+00:00 Pos Value:  114043.9807 PnL:  13869.8972277
# Bars Completed:
#  1633 2007-07-03 00:00:00+00:00 Pos Value:  113973.3776 PnL:  13055.0607897
# Bars Completed:
#  1656 2007-08-06 00:00:00+00:00 Pos Value:  111788.072 PnL:  10570.7744643
# Bars Completed:
#  1679 2007-09-07 00:00:00+00:00 Pos Value:  106660.1676 PnL:  7078.07973254
# Bars Completed:
#  1702 2007-10-10 00:00:00+00:00 Pos Value:  109331.6725 PnL:  9023.34687573
# Bars Completed:
#  1725 2007-11-12 00:00:00+00:00 Pos Value:  104241.8056 PnL:  4110.90182379
# Bars Completed:
#  1748 2007-12-14 00:00:00+00:00 Pos Value:  107865.5626 PnL:  9276.79042702
# Bars Completed:
#  1771 2008-01-18 00:00:00+00:00 Pos Value:  104050.0939 PnL:  3035.9584
# Bars Completed:
#  1794 2008-02-22 00:00:00+00:00 Pos Value:  108488.1215 PnL:  11148.6594553
# Bars Completed:
#  1817 2008-03-27 00:00:00+00:00 Pos Value:  111988.9914 PnL:  11335.9705236
# Bars Completed:
#  1840 2008-04-29 00:00:00+00:00 Pos Value:  108058.4937 PnL:  7392.9995754
# Bars Completed:
#  1863 2008-06-02 00:00:00+00:00 Pos Value:  105976.5433 PnL:  5956.31194752
# Bars Completed:
#  1886 2008-07-03 00:00:00+00:00 Pos Value:  108265.0933 PnL:  7472.40716659
# Bars Completed:
#  1909 2008-08-06 00:00:00+00:00 Pos Value:  121100.2857 PnL:  22088.1134353
# Bars Completed:
#  1932 2008-09-09 00:00:00+00:00 Pos Value:  116141.0981 PnL:  14733.9935213
# Bars Completed:
#  1955 2008-10-10 00:00:00+00:00 Pos Value:  97762.5834 PnL:  -2606.36280223
# Bars Completed:
#  1978 2008-11-12 00:00:00+00:00 Pos Value:  96923.3513 PnL:  4948.14483164
# Bars Completed:
#  2645 2011-07-08 00:00:00+00:00 Pos Value:  190771.9658 PnL:  89408.9046693
# Bars Completed:
#  2668 2011-08-10 00:00:00+00:00 Pos Value:  170951.2749 PnL:  68092.0850025
# Bars Completed:
#  2691 2011-09-13 00:00:00+00:00 Pos Value:  179249.68 PnL:  78679.9669833
# Bars Completed:
#  2714 2011-10-14 00:00:00+00:00 Pos Value:  183352.5919 PnL:  80502.5641148
# Bars Completed:
#  2737 2011-11-16 00:00:00+00:00 Pos Value:  171177.3738 PnL:  67341.3457721
# Bars Completed:
#  2760 2011-12-20 00:00:00+00:00 Pos Value:  170739.9706 PnL:  70937.3880564
# Bars Completed:
#  2783 2012-01-25 00:00:00+00:00 Pos Value:  167388.7497 PnL:  67019.3408261
# Bars Completed:
#  2806 2012-02-28 00:00:00+00:00 Pos Value:  173370.8263 PnL:  71216.0849522
# Bars Completed:
#  2829 2012-03-30 00:00:00+00:00 Pos Value:  171077.1467 PnL:  72025.02778
# Bars Completed:
#  2852 2012-05-03 00:00:00+00:00 Pos Value:  169860.053 PnL:  68585.452307
# Bars Completed:
#  2875 2012-06-06 00:00:00+00:00 Pos Value:  172656.2478 PnL:  71553.7648009
# Bars Completed:
#  2898 2012-07-10 00:00:00+00:00 Pos Value:  178832.1846 PnL:  76270.9505375
# Bars Completed:
#  2921 2012-08-10 00:00:00+00:00 Pos Value:  172053.8985 PnL:  73110.536454
# Bars Completed:
#  2944 2012-09-13 00:00:00+00:00 Pos Value:  175375.4447 PnL:  74022.8301378
# Bars Completed:
#  2967 2012-10-16 00:00:00+00:00 Pos Value:  181866.2989 PnL:  78217.0700854
# Bars Completed:
#  2990 2012-11-20 00:00:00+00:00 Pos Value:  173526.606 PnL:  72127.2380781
# Bars Completed:
#  3013 2012-12-24 00:00:00+00:00 Pos Value:  173431.8123 PnL:  72974.1867162
# Bars Completed:
#  3036 2013-01-29 00:00:00+00:00 Pos Value:  186451.848 PnL:  86163.1526527
# Bars Completed:
#  3059 2013-03-04 00:00:00+00:00 Pos Value:  193136.2186 PnL:  90533.5113955
# Bars Completed:
#  3082 2013-04-05 00:00:00+00:00 Pos Value:  204329.1634 PnL:  104130.671835
# Bars Completed:
#  3105 2013-05-08 00:00:00+00:00 Pos Value:  218681.9267 PnL:  117455.700183
# Bars Completed:
#  3128 2013-06-11 00:00:00+00:00 Pos Value:  214042.8067 PnL:  112375.258161
# Bars Completed:
#  3151 2013-07-15 00:00:00+00:00 Pos Value:  218881.3179 PnL:  118571.424022
# Bars Completed:
#  3174 2013-08-15 00:00:00+00:00 Pos Value:  209507.5641 PnL:  109853.0818
# Bars Completed:
#  3197 2013-09-18 00:00:00+00:00 Pos Value:  211819.5407 PnL:  113611.109336
# Bars Completed:
#  3220 2013-10-21 00:00:00+00:00 Pos Value:  214524.5895 PnL:  114836.66609
# Bars Completed:
#  3243 2013-11-21 00:00:00+00:00 Pos Value:  214564.306 PnL:  110509.06098
# Bars Completed:
#  3266 2013-12-26 00:00:00+00:00 Pos Value:  220762.341 PnL:  112491.283612
# Bars Completed:
#  3289 2014-01-30 00:00:00+00:00 Pos Value:  200852.5147 PnL:  99396.7269478
# Bars Completed:
#  3312 2014-03-05 00:00:00+00:00 Pos Value:  205170.7654 PnL:  103425.463507
# Bars Completed:
#  3335 2014-04-07 00:00:00+00:00 Pos Value:  209601.7816 PnL:  109136.003284
# Bars Completed:
#  3358 2014-05-09 00:00:00+00:00 Pos Value:  216045.9204 PnL:  114637.170476
# Bars Completed:
#  3381 2014-06-12 00:00:00+00:00 Pos Value:  210767.4149 PnL:  111542.871875
# Bars Completed:
#  3404 2014-07-16 00:00:00+00:00 Pos Value:  227502.9315 PnL:  124369.066031
# Bars Completed:
#  3427 2014-08-18 00:00:00+00:00 Pos Value:  225983.0413 PnL:  123222.851787
# Bars Completed:
#  3450 2014-09-19 00:00:00+00:00 Pos Value:  228400.6187 PnL:  130058.838743
# Bars Completed:
# [2014-11-20 22:25] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-20 22:25] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-20 22:25] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3473 2014-10-22 00:00:00+00:00 Pos Value:  223111.54 PnL:  125420.526227

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 100000.0/data['SPY']['price'][23]*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-weight']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  4272.582

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.135586                 0.090637 -0.026163
# 2013-10              0.141790                 0.246506  0.077953
# 2012-10              0.123488                 0.045645 -0.003513
# 2011-10              0.192975                -0.073577 -0.096650
# 2010-10              0.150629                 0.443851  0.383520
# 2009-10              0.231241                 0.177391  0.160882
# 2008-10              0.230450                -0.030322  0.097625
# 2007-10              0.120165                 0.136977  0.050637
# 2006-10              0.099334                 0.293966  0.205152
# 2005-10              0.133874                -0.013331 -0.077654
# 2004-10              0.133517                -0.073735 -0.126745
# 2003-10              0.192241                 0.045086 -0.067482
# 2002-10              0.248779                -0.115250 -0.044366
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.789509
# 2013-10                      0.243868              0.117836  0.689892
# 2012-10                      0.126753              0.153977  0.378979
# 2011-10                      0.059192              0.215031  0.377174
# 2010-10                      0.141933              0.181490  0.416011
# 2009-10                      0.069615              0.358120  0.194321
# 2008-10                     -0.374750              0.346362  0.364217
# 2007-10                      0.124418              0.135401  0.546797
# 2006-10                      0.141614              0.100152  0.424298
# 2005-10                      0.067961              0.105708  0.853631
# 2004-10                      0.075654              0.112001  0.571072
# 2003-10                      0.186224              0.185829  0.574551
# 2002-10                     -0.164204              0.254499  0.478084
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.089537    -0.028294      0.133006  0.660372  0.912540
# 2013-10            0.245506     0.002685      0.068920  1.731471  3.166108
# 2012-10            0.043840    -0.034384      0.071082  0.355016  0.545599
# 2011-10           -0.074777    -0.039467      0.185413 -0.387496 -0.464189
# 2010-10            0.441651     0.086307      0.096562  2.932048  4.434410
# 2009-10            0.173691     0.010198      0.180112  0.751128  1.143071
# 2008-10           -0.043759     0.086951      0.202268 -0.189885 -0.269681
# 2007-10            0.096577     0.005132      0.089432  0.803706  1.062079
# 2006-10            0.244066     0.073960      0.032033  2.457014  4.294330
# 2005-10           -0.056431    -0.047625      0.106210 -0.421526 -0.670372
# 2004-10           -0.096597    -0.073328      0.227729 -0.723481 -0.926599
# 2003-10            0.031986    -0.044330      0.158594  0.166385  0.280842
# 2002-10           -0.129850     0.013739      0.274632 -0.521948 -0.795554
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
