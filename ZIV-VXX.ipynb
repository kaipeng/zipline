# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2009, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['ZIV', 'XIV', 'VXX', 'VXZ']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=[]
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# http://10.8.84.65/api/bdh {'startDate': '20090101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'ZIV EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20090101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'XIV EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20090101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'VXX EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20090101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'VXZ EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 4 (items) x 1451 (major_axis) x 6 (minor_axis)
# Items axis: ZIV to VXZ
# Major_axis axis: 2009-01-29 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data_name = 'bbg-vol-etfs-12yr'
data.to_pickle(data_name+'.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Vol-ETFs"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(50, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0.0
        if sec == 'VXX':
            target = -1
        if sec == 'VXZ':
            target = 1

        target=target*(context.portfolio.portfolio_value)/2
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
        

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle(data_name+'.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2009-11-11 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2010-04-08 00:00:00+00:00 Pos Value:  71.67 PnL:  29756.2433707
# Bars Completed:
#  400 2010-08-30 00:00:00+00:00 Pos Value:  -611.42 PnL:  37541.5368611
# Bars Completed:
#  500 2011-01-21 00:00:00+00:00 Pos Value:  -1118.92 PnL:  79537.3566587
# Bars Completed:
#  600 2011-06-15 00:00:00+00:00 Pos Value:  -4266.25 PnL:  87027.8735436
# Bars Completed:
#  700 2011-11-04 00:00:00+00:00 Pos Value:  -860.36 PnL:  41610.5217468
# Bars Completed:
#  800 2012-03-30 00:00:00+00:00 Pos Value:  1675.488 PnL:  86088.7003859
# Bars Completed:
#  900 2012-08-22 00:00:00+00:00 Pos Value:  -1140.75 PnL:  102502.013217
# Bars Completed:
#  1000 2013-01-17 00:00:00+00:00 Pos Value:  -1005.4 PnL:  103987.967565
# Bars Completed:
#  1100 2013-06-12 00:00:00+00:00 Pos Value:  -3701.2 PnL:  108549.213871
# Bars Completed:
#  1200 2013-11-01 00:00:00+00:00 Pos Value:  1721.04 PnL:  135323.15544
# Bars Completed:
#  1300 2014-03-28 00:00:00+00:00 Pos Value:  1055.25 PnL:  129874.172028
# Bars Completed:
# [2014-11-13 15:59] INFO: Performance: Simulated 1451 trading days out of 1451.
# [2014-11-13 15:59] INFO: Performance: first open: 2009-01-29 14:31:00+00:00
# [2014-11-13 15:59] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  1400 2014-08-20 00:00:00+00:00 Pos Value:  -937.17 PnL:  149889.169146

# %%
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1000*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 180)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
# Out:
# Total Commish:  3727.44

# %%
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(6)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.152279                -0.012379  0.001589
# 2013-10              0.171983                 0.184137  0.175642
# 2012-10              0.185276                 0.460872  0.451460
# 2011-10              0.199121                -0.167682 -0.160775
# 2010-10              0.166876                 0.593276  0.595459
# 2014-09              0.153029                 0.014126  0.032980
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.100474              0.098827 -0.151622
# 2013-10                      0.243868              0.117836  0.030859
# 2012-10                      0.126753              0.153977  0.060879
# 2011-10                      0.059192              0.215031 -0.139795
# 2010-10                      0.141933              0.181490 -0.031365
# 2014-09                      0.172900              0.102981 -0.117449
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10           -0.013479    -0.035013      0.120664 -0.088512 -0.111104
# 2013-10            0.183137    -0.012640      0.087989  1.064852  1.392247
# 2012-10            0.459067     0.071294      0.124116  2.477744  3.714689
# 2011-10           -0.168882    -0.048835      0.301224 -0.848135 -0.988974
# 2010-10            0.591076     0.083329      0.148386  3.542015  4.322933
# 2014-09            0.012826    -0.045852      0.120664  0.083812  0.106119
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                234                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2014-09                252                0.001300
