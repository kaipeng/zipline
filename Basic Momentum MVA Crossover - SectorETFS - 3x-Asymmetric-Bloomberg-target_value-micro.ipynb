# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['TLT','IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=[]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))

# %%
data.to_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg-target_value-micro"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(5, '1d', 'price')
    add_history(10, '1d', 'price')
    add_history(20, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(5, '1d', 'price').mean()
    med_mavg = history(10, '1d', 'price').mean()
    long_mavg = history(20, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0.0
        if short_mavg[sec] > med_mavg[sec]:
            target += .2
        if short_mavg[sec] > long_mavg[sec]:
            target += .3
        if med_mavg[sec] > long_mavg[sec]:
            target += .5

        if short_mavg[sec] < med_mavg[sec]:
            target -= .2
        if short_mavg[sec] < long_mavg[sec]:
            target -= .1
        if med_mavg[sec] < long_mavg[sec]:
            target -= 0
            
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
        

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  74511.0199 PnL:  429.387098448
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  17826.6365 PnL:  -2162.6840121
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  947.6712 PnL:  -3917.70698131
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  44940.4933 PnL:  -6839.89684603
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  57058.2129 PnL:  -6650.56662741
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  45165.252 PnL:  -5541.88835954
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  26068.6035 PnL:  -6451.96101014
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  79969.8631 PnL:  -3714.39121411
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  50066.937 PnL:  -5791.56923328
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  -27276.2938 PnL:  -8225.3728629
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  66511.4766 PnL:  -7459.67746309
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  31999.395 PnL:  -11162.9868438
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  63729.2871 PnL:  -3802.70424922
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  53816.9471 PnL:  -844.812291512
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  95058.0282 PnL:  3.47564618297
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  59064.7658 PnL:  -7506.84934569
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  33841.9991 PnL:  -7297.28409501
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  80865.3817 PnL:  -14838.2929263
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  79182.2095 PnL:  -8754.09403326
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  61139.0704 PnL:  -9485.31827122
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  71492.9506 PnL:  -12790.851594
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  73251.2528 PnL:  -15004.0220149
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  78860.3158 PnL:  -9484.47801848
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  88123.1161 PnL:  -7175.09944306
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  4142.7829 PnL:  -12002.9039498
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  68515.353 PnL:  -8777.74990852
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  73479.4264 PnL:  -12926.6121205
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  79405.8297 PnL:  -12643.8005745
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  73147.2678 PnL:  -8458.65928467
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  90804.2588 PnL:  -4419.99280012
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  36980.7033 PnL:  -5257.93557402
# Bars Completed:
# [2014-11-12 20:50] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-12 20:50] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-12 20:50] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  76960.8945 PnL:  -2613.37013055

# %%
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 180)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
# Out:
# Total Commish:  20731.77

# %%
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.054711                 0.024586 -0.010617
# 2013-10              0.060916                 0.087270  0.014041
# 2012-10              0.085723                -0.024854 -0.067820
# 2011-10              0.106279                 0.004517 -0.002213
# 2010-10              0.094551                 0.016755 -0.010189
# 2009-10              0.183431                -0.051696 -0.070312
# 2008-10              0.103494                -0.062293 -0.103869
# 2007-10              0.076432                 0.048013 -0.022785
# 2006-10              0.054638                 0.029905 -0.052117
# 2005-10              0.051917                -0.008239 -0.058198
# 2004-10              0.057874                -0.002797 -0.042873
# 2003-10              0.099158                -0.036383 -0.109494
# 2002-10              0.093180                -0.019893 -0.027789
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.232710
# 2013-10                      0.243868              0.117836  0.297397
# 2012-10                      0.126753              0.153977  0.329429
# 2011-10                      0.059192              0.215031  0.095362
# 2010-10                      0.141933              0.181490  0.177080
# 2009-10                      0.069615              0.358120  0.226285
# 2008-10                     -0.374750              0.346362 -0.072490
# 2007-10                      0.124418              0.135401  0.361799
# 2006-10                      0.141614              0.100152  0.350245
# 2005-10                      0.067961              0.105708  0.275884
# 2004-10                      0.075654              0.112001  0.326083
# 2003-10                      0.186224              0.185829  0.346635
# 2002-10                     -0.164204              0.254499  0.037495
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.023486    -0.076338      0.029791  0.429279  0.617352
# 2013-10            0.086270    -0.091079      0.025115  1.416196  2.167651
# 2012-10           -0.026659    -0.077554      0.070854 -0.310984 -0.449728
# 2011-10            0.003317    -0.020093      0.102652  0.031212  0.039816
# 2010-10            0.014555    -0.046519      0.114252  0.153943  0.203026
# 2009-10           -0.055396    -0.032855      0.161840 -0.302000 -0.461163
# 2008-10           -0.075729     0.057280      0.093311 -0.731725 -0.934535
# 2007-10            0.007613    -0.046310      0.058197  0.099602  0.115760
# 2006-10           -0.019995    -0.086697      0.072893 -0.365954 -0.520780
# 2005-10           -0.051339    -0.056051      0.057185 -0.988873 -1.314197
# 2004-10           -0.025659    -0.057842      0.053615 -0.443365 -0.651834
# 2003-10           -0.049483    -0.097042      0.125994 -0.499032 -0.635858
# 2002-10           -0.034493     0.031607      0.078984 -0.370182 -0.489499
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
