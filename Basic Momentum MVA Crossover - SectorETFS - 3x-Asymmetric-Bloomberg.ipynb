# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['TLT','IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=[]
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'TLT EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYE EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYF EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYC EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYK EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 10 (items) x 3480 (major_axis) x 6 (minor_axis)
# Items axis: TLT to IYK
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history
import numpy as np

from collections import deque

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, 'Data: ', data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(50, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0
        if short_mavg[sec] > med_mavg[sec]:
            target += 40
        if short_mavg[sec] > long_mavg[sec]:
            target += 80
        if med_mavg[sec] > long_mavg[sec]:
            target += 100

        if short_mavg[sec] < med_mavg[sec]:
            target -= 40
        if short_mavg[sec] < long_mavg[sec]:
            target -= 20
            

        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
        

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 Data:  2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 Data:  2002-03-18 00:00:00+00:00 Pos Value:  22329.67 PnL:  -1476.43145342
# Bars Completed:
#  400 Data:  2002-08-08 00:00:00+00:00 Pos Value:  -9803.018 PnL:  -6189.46499875
# Bars Completed:
#  500 Data:  2002-12-31 00:00:00+00:00 Pos Value:  5954.006 PnL:  -6377.21526951
# Bars Completed:
#  600 Data:  2003-05-27 00:00:00+00:00 Pos Value:  51314.234 PnL:  -5568.94319105
# Bars Completed:
#  700 Data:  2003-10-16 00:00:00+00:00 Pos Value:  72469.924 PnL:  262.416093198
# Bars Completed:
#  800 Data:  2004-03-11 00:00:00+00:00 Pos Value:  93353.612 PnL:  5543.80799362
# Bars Completed:
#  900 Data:  2004-08-04 00:00:00+00:00 Pos Value:  45129.44 PnL:  4173.53859612
# Bars Completed:
#  1000 Data:  2004-12-27 00:00:00+00:00 Pos Value:  78580.474 PnL:  7790.8871344
# Bars Completed:
#  1100 Data:  2005-05-19 00:00:00+00:00 Pos Value:  62050.002 PnL:  6707.17938454
# Bars Completed:
#  1200 Data:  2005-10-11 00:00:00+00:00 Pos Value:  84468.032 PnL:  5920.14135228
# Bars Completed:
#  1300 Data:  2006-03-07 00:00:00+00:00 Pos Value:  103624.468 PnL:  10747.4805115
# Bars Completed:
#  1400 Data:  2006-07-28 00:00:00+00:00 Pos Value:  32047.364 PnL:  9840.12708139
# Bars Completed:
#  1500 Data:  2006-12-19 00:00:00+00:00 Pos Value:  116585.386 PnL:  14961.6589269
# Bars Completed:
#  1600 Data:  2007-05-16 00:00:00+00:00 Pos Value:  122122.83 PnL:  22425.3149261
# Bars Completed:
#  1700 Data:  2007-10-08 00:00:00+00:00 Pos Value:  59826.698 PnL:  22150.3749466
# Bars Completed:
#  1800 Data:  2008-03-03 00:00:00+00:00 Pos Value:  20513.27 PnL:  20792.0928603
# Bars Completed:
#  1900 Data:  2008-07-24 00:00:00+00:00 Pos Value:  10485.148 PnL:  17812.3679486
# Bars Completed:
#  2000 Data:  2008-12-15 00:00:00+00:00 Pos Value:  2310.922 PnL:  23080.3370121
# Bars Completed:
#  2100 Data:  2009-05-11 00:00:00+00:00 Pos Value:  2263.278 PnL:  18868.7566709
# Bars Completed:
#  2200 Data:  2009-10-01 00:00:00+00:00 Pos Value:  85695.09 PnL:  27402.6299744
# Bars Completed:
#  2300 Data:  2010-02-25 00:00:00+00:00 Pos Value:  88575.506 PnL:  34876.0499158
# Bars Completed:
#  2400 Data:  2010-07-20 00:00:00+00:00 Pos Value:  44894.018 PnL:  32909.4781141
# Bars Completed:
#  2500 Data:  2010-12-09 00:00:00+00:00 Pos Value:  106462.408 PnL:  38234.9415956
# Bars Completed:
#  2600 Data:  2011-05-04 00:00:00+00:00 Pos Value:  113565.77 PnL:  48442.0445641
# Bars Completed:
#  2700 Data:  2011-09-26 00:00:00+00:00 Pos Value:  17309.19 PnL:  43274.0820205
# Bars Completed:
#  2800 Data:  2012-02-17 00:00:00+00:00 Pos Value:  100772.488 PnL:  45498.8578235
# Bars Completed:
#  2900 Data:  2012-07-12 00:00:00+00:00 Pos Value:  102666.172 PnL:  44200.5823558
# Bars Completed:
#  3000 Data:  2012-12-05 00:00:00+00:00 Pos Value:  114403.394 PnL:  48105.9682502
# Bars Completed:
#  3100 Data:  2013-05-01 00:00:00+00:00 Pos Value:  119416.008 PnL:  61087.2134444
# Bars Completed:
#  3200 Data:  2013-09-23 00:00:00+00:00 Pos Value:  146286.168 PnL:  73787.8259146
# Bars Completed:
#  3300 Data:  2014-02-14 00:00:00+00:00 Pos Value:  160273.57 PnL:  87806.2039145
# Bars Completed:
# [2014-11-11 21:07] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-11 21:07] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-11 21:07] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 Data:  2014-07-10 00:00:00+00:00 Pos Value:  202324.474 PnL:  100056.336775

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 180)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
# Out:
# Total Commish:  1653.0
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.095381                 0.146751  0.020894
# 2013-10              0.096612                 0.217265  0.021512
# 2012-10              0.069535                 0.046889  0.021132
# 2011-10              0.099605                 0.040207  0.024238
# 2010-10              0.105550                 0.061531 -0.010409
# 2009-10              0.092514                 0.088688  0.090552
# 2008-10              0.077860                -0.059209 -0.089695
# 2007-10              0.107765                 0.109788  0.006043
# 2006-10              0.071929                 0.051520 -0.060197
# 2005-10              0.065407                 0.011576 -0.045954
# 2004-10              0.070446                 0.046548 -0.005914
# 2003-10              0.066298                 0.073628  0.041394
# 2002-10              0.050044                -0.064825 -0.077290
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.851310
# 2013-10                      0.243868              0.117836  0.801891
# 2012-10                      0.126753              0.153977  0.191694
# 2011-10                      0.059192              0.215031  0.254668
# 2010-10                      0.141933              0.181490  0.499093
# 2009-10                      0.069615              0.358120 -0.084414
# 2008-10                     -0.374750              0.346362 -0.043920
# 2007-10                      0.124418              0.135401  0.753950
# 2006-10                      0.141614              0.100152  0.674020
# 2005-10                      0.067961              0.105708  0.580412
# 2004-10                      0.075654              0.112001  0.560690
# 2003-10                      0.186224              0.185829  0.110520
# 2002-10                     -0.164204              0.254499  0.011941
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.145651    -0.006114      0.057077  1.527052  2.016085
# 2013-10            0.216265    -0.048843      0.051563  2.238488  3.057643
# 2012-10            0.045084    -0.037526      0.060647  0.648359  0.907482
# 2011-10            0.039007    -0.012637      0.096503  0.391619  0.513683
# 2010-10            0.059331    -0.050041      0.097805  0.562110  0.682848
# 2009-10            0.084988    -0.006678      0.068438  0.918650  1.350067
# 2008-10           -0.072646     0.059807      0.069302 -0.933032 -1.364341
# 2007-10            0.069388    -0.021645      0.091510  0.643883  0.732171
# 2006-10            0.001620    -0.129992      0.074361  0.022528  0.031452
# 2005-10           -0.031524    -0.072806      0.053387 -0.481964 -0.738341
# 2004-10            0.023685    -0.033657      0.061556  0.336218  0.458780
# 2003-10            0.060528    -0.040866      0.041971  0.912967  1.097072
# 2002-10           -0.079425     0.020003      0.071461 -1.587103 -2.372504
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
