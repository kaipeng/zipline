# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=[]
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))data.to_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission, zipline
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg-target_value"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    '''
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
    '''
    set_commission(zipline.finance.commission.PerShare(cost=0.001))
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(10, '1d', 'price').mean()
    med_mavg = history(40, '1d', 'price').mean()
    long_mavg = history(100, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0.0
        if short_mavg[sec] > med_mavg[sec]:
            target += .2
        if short_mavg[sec] > long_mavg[sec]:
            target += .3
        if med_mavg[sec] > long_mavg[sec]:
            target += .5

        if short_mavg[sec] < med_mavg[sec]:
            target -= .2
        if short_mavg[sec] < long_mavg[sec]:
            target -= .1
        if med_mavg[sec] < long_mavg[sec]:
            target -= 0
            
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    '''
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
    '''    

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  76155.2098 PnL:  2173.47149274
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  -32506.273 PnL:  3325.42125158
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  49060.078 PnL:  -1965.72685924
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  97690.3512 PnL:  -2255.9785481
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  75459.8809 PnL:  5994.54916324
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  97911.3882 PnL:  13158.9533305
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  20814.2717 PnL:  10640.9091015
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  118648.5787 PnL:  18606.8637454
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  3978.901 PnL:  16444.2758814
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  24579.3565 PnL:  15991.6695657
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  107681.921 PnL:  18205.2711249
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  1096.1704 PnL:  18391.3570837
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  127077.7837 PnL:  27054.4089299
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  125147.2825 PnL:  32606.4119849
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  69345.2037 PnL:  32794.6363927
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  -3991.1609 PnL:  25109.5996388
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  1478.1275 PnL:  19724.4408329
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  -26262.3908 PnL:  25670.9950403
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  115367.068 PnL:  28947.1899469
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  143373.1844 PnL:  43534.384961
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  74815.3715 PnL:  49599.0594053
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  -25379.556 PnL:  48567.7449237
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  154483.858 PnL:  61643.5417106
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  165027.9006 PnL:  74800.623243
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  -20536.1013 PnL:  60972.9739665
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  170325.085 PnL:  70443.663952
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  47538.5495 PnL:  65738.9391414
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  65772.8776 PnL:  68919.2404559
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  124541.5098 PnL:  84153.0606943
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  192048.9617 PnL:  91966.4767554
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  104753.0245 PnL:  104281.017363
# Bars Completed:
# [2014-11-14 15:51] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-14 15:51] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-14 15:51] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  216336.9734 PnL:  116401.141815

# %%
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 180)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
# Out:
# Total Commish:  279.172

# %%
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.088263                 0.058612 -0.048534
# 2013-10              0.097650                 0.170904 -0.023312
# 2012-10              0.091853                 0.075947  0.015642
# 2011-10              0.100398                 0.026635  0.018341
# 2010-10              0.115371                 0.074595  0.009471
# 2009-10              0.167458                 0.162539  0.158594
# 2008-10              0.091647                -0.074568 -0.122919
# 2007-10              0.095029                 0.085132 -0.003170
# 2006-10              0.064100                 0.072063 -0.020653
# 2005-10              0.064426                 0.017796 -0.036818
# 2004-10              0.075263                 0.061178  0.009392
# 2003-10              0.111802                 0.055909 -0.033699
# 2002-10              0.075990                 0.007217 -0.022772
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.723629
# 2013-10                      0.243868              0.117836  0.795558
# 2012-10                      0.126753              0.153977  0.468192
# 2011-10                      0.059192              0.215031  0.122328
# 2010-10                      0.141933              0.181490  0.450313
# 2009-10                      0.069615              0.358120  0.003725
# 2008-10                     -0.374750              0.346362 -0.089942
# 2007-10                      0.124418              0.135401  0.570133
# 2006-10                      0.141614              0.100152  0.466833
# 2005-10                      0.067961              0.105708  0.463164
# 2004-10                      0.075654              0.112001  0.547887
# 2003-10                      0.186224              0.185829  0.441925
# 2002-10                     -0.164204              0.254499 -0.086066
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.057512    -0.107627      0.051743  0.651593  0.817542
# 2013-10            0.169904    -0.108326      0.052475  1.739919  2.346311
# 2012-10            0.074142    -0.034019      0.060363  0.807174  1.208509
# 2011-10            0.025435    -0.014629      0.108340  0.253341  0.353198
# 2010-10            0.072395    -0.034597      0.105806  0.627498  0.746056
# 2009-10            0.158839     0.005328      0.101234  0.948531  1.296787
# 2008-10           -0.088004     0.054594      0.113369 -0.960257 -1.185317
# 2007-10            0.044732    -0.031584      0.065292  0.470714  0.497349
# 2006-10            0.022163    -0.060015      0.054178  0.345751  0.454609
# 2005-10           -0.025304    -0.046011      0.053574 -0.392756 -0.550496
# 2004-10            0.038315    -0.016075      0.069391  0.509083  0.727743
# 2003-10            0.042809    -0.062442      0.105099  0.382902  0.536846
# 2002-10           -0.007383     0.034656      0.064587 -0.097158 -0.132560
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
