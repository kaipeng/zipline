# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK','SPY']
fields=['CALL_IMP_VOL_30D','CALL_IMP_VOL_60D','CALL_IMP_VOL_90D']

algo_name = "Minimum Variance Portfolio - Sector ETFs"
data_name = 'bbg_sector_vol_data-12yr'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle(data_name+'.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYE EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYF EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYC EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYK EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'SPY EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 10 (items) x 3480 (major_axis) x 9 (minor_axis)
# Items axis: IYE to SPY
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to CALL_IMP_VOL_90D

# %%
import pandas as pd
data = pd.read_pickle(data_name+'.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

# Define algorithm
def initialize(context):                  
    # Register 3 histories that maintain windows of trailing data
    context.windows = [60]
    
    for t in context.windows:
        add_history(t, '1d', 'price')
        
    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.002))

def handle_data(context, data):
    # Skip first 60 days to get full windows
    context.i += 1
    if context.i < context.windows[-1] or (context.i % context.windows[-1] != 0):
        return
    
    # Progess report
    if context.i % 1 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    hist_used = history(context.windows[-1], '1d', 'price')
    minvarport = zip(hist_used.keys().values, minvar(hist_used.values))
    
    for sec, weight in minvarport:
        target=weight*(context.portfolio.portfolio_value)
        order_target_value(sec, target)
        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-weight', weight)

        
def minvar(prices):
    cov = np.cov((prices[1:] / prices[:-1] - 1).transpose())
    vu = np.array(cov.shape[1] * [1], float)
    num = np.dot(np.linalg.inv(cov), vu)
    den = np.dot(vu, num)
    return num / den  

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle(data_name+'.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  60 2001-03-28 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  120 2001-06-22 00:00:00+00:00 Pos Value:  103289.3565 PnL:  3318.79139682
# Bars Completed:
#  180 2001-09-24 00:00:00+00:00 Pos Value:  95661.2361 PnL:  -3946.62905728
# Bars Completed:
#  240 2001-12-18 00:00:00+00:00 Pos Value:  95851.3474 PnL:  -5042.50638692
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  97146.2323 PnL:  -1481.69510573
# Bars Completed:
#  360 2002-06-12 00:00:00+00:00 Pos Value:  97307.9785 PnL:  -3014.12490898
# Bars Completed:
#  420 2002-09-06 00:00:00+00:00 Pos Value:  88166.1257 PnL:  -11442.6591652
# Bars Completed:
#  480 2002-12-02 00:00:00+00:00 Pos Value:  85068.882 PnL:  -15950.516327
# Bars Completed:
#  540 2003-02-28 00:00:00+00:00 Pos Value:  79073.8437 PnL:  -20265.2138032
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  88046.2268 PnL:  -12064.8883839
# Bars Completed:
#  660 2003-08-20 00:00:00+00:00 Pos Value:  86629.5318 PnL:  -12899.0748755
# Bars Completed:
#  720 2003-11-13 00:00:00+00:00 Pos Value:  94432.2725 PnL:  -5695.36434987
# Bars Completed:
#  780 2004-02-11 00:00:00+00:00 Pos Value:  107341.37 PnL:  7089.74456285
# Bars Completed:
#  840 2004-05-07 00:00:00+00:00 Pos Value:  111701.5857 PnL:  11953.4745908
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  101126.5594 PnL:  1601.310294
# Bars Completed:
#  960 2004-10-28 00:00:00+00:00 Pos Value:  102873.2247 PnL:  3171.33745898
# Bars Completed:
#  1020 2005-01-25 00:00:00+00:00 Pos Value:  109486.7315 PnL:  9034.07231014
# Bars Completed:
#  1080 2005-04-21 00:00:00+00:00 Pos Value:  108892.8185 PnL:  9243.20104799
# Bars Completed:
#  1140 2005-07-18 00:00:00+00:00 Pos Value:  114476.3638 PnL:  14782.0760799
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  110714.3062 PnL:  10599.6602729
# Bars Completed:
#  1260 2006-01-06 00:00:00+00:00 Pos Value:  119358.3853 PnL:  18809.7266703
# Bars Completed:
#  1320 2006-04-04 00:00:00+00:00 Pos Value:  123710.055 PnL:  23724.7574543
# Bars Completed:
#  1380 2006-06-29 00:00:00+00:00 Pos Value:  126053.2511 PnL:  25534.5023051
# Bars Completed:
#  1440 2006-09-25 00:00:00+00:00 Pos Value:  132545.4855 PnL:  32321.6256059
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  140365.6642 PnL:  40129.4647358
# Bars Completed:
#  1560 2007-03-20 00:00:00+00:00 Pos Value:  141240.5966 PnL:  41168.9157656
# Bars Completed:
#  1620 2007-06-14 00:00:00+00:00 Pos Value:  152778.0679 PnL:  53480.4412319
# Bars Completed:
#  1680 2007-09-10 00:00:00+00:00 Pos Value:  150322.9682 PnL:  50436.9919009
# Bars Completed:
#  1740 2007-12-04 00:00:00+00:00 Pos Value:  162437.4175 PnL:  62228.7192096
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  150286.6571 PnL:  48936.5958314
# Bars Completed:
#  1860 2008-05-28 00:00:00+00:00 Pos Value:  148885.8377 PnL:  48934.3214567
# Bars Completed:
#  1920 2008-08-21 00:00:00+00:00 Pos Value:  160056.2536 PnL:  60503.4344567
# Bars Completed:
#  1980 2008-11-14 00:00:00+00:00 Pos Value:  129362.2516 PnL:  30193.1938507
# Bars Completed:
#  2040 2009-02-12 00:00:00+00:00 Pos Value:  143564.4111 PnL:  43034.5232591
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  129779.07 PnL:  29159.2735243
# Bars Completed:
#  2160 2009-08-05 00:00:00+00:00 Pos Value:  152773.9214 PnL:  52769.3760112
# Bars Completed:
#  2220 2009-10-29 00:00:00+00:00 Pos Value:  158993.941 PnL:  59522.2171995
# Bars Completed:
#  2280 2010-01-27 00:00:00+00:00 Pos Value:  171997.6353 PnL:  71198.8564133
# Bars Completed:
#  2340 2010-04-23 00:00:00+00:00 Pos Value:  179435.721 PnL:  78122.164058
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  172661.9953 PnL:  71670.4488765
# Bars Completed:
#  2460 2010-10-13 00:00:00+00:00 Pos Value:  189540.6687 PnL:  88837.5288333
# Bars Completed:
#  2520 2011-01-07 00:00:00+00:00 Pos Value:  195817.7434 PnL:  93784.780068
# Bars Completed:
#  2580 2011-04-05 00:00:00+00:00 Pos Value:  198717.3965 PnL:  98852.3069983
# Bars Completed:
#  2640 2011-06-30 00:00:00+00:00 Pos Value:  217368.7512 PnL:  118622.90725
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  213194.835 PnL:  112791.569649
# Bars Completed:
#  2760 2011-12-20 00:00:00+00:00 Pos Value:  201905.0276 PnL:  101416.895973
# Bars Completed:
#  2820 2012-03-19 00:00:00+00:00 Pos Value:  212578.0047 PnL:  109014.675957
# Bars Completed:
#  2880 2012-06-13 00:00:00+00:00 Pos Value:  217543.134 PnL:  117364.698342
# Bars Completed:
#  2940 2012-09-07 00:00:00+00:00 Pos Value:  236135.1324 PnL:  135505.436998
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  241580.6243 PnL:  141603.289912
# Bars Completed:
#  3060 2013-03-05 00:00:00+00:00 Pos Value:  267917.3565 PnL:  166667.016813
# Bars Completed:
#  3120 2013-05-30 00:00:00+00:00 Pos Value:  297421.6793 PnL:  195653.385989
# Bars Completed:
#  3180 2013-08-23 00:00:00+00:00 Pos Value:  297920.3009 PnL:  193369.731241
# Bars Completed:
#  3240 2013-11-18 00:00:00+00:00 Pos Value:  320560.2374 PnL:  218574.135045
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  328628.2241 PnL:  228295.255113
# Bars Completed:
#  3360 2014-05-13 00:00:00+00:00 Pos Value:  350008.3327 PnL:  251052.869586
# Bars Completed:
#  3420 2014-08-07 00:00:00+00:00 Pos Value:  349416.8072 PnL:  250004.678683
# Bars Completed:
# [2014-11-20 20:27] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-20 20:27] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-20 20:27] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3480 2014-10-31 00:00:00+00:00 Pos Value:  380235.72 PnL:  281208.658559

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 100000.0/data['SPY']['price'][60]*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-weight']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  1157.222

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.098369                 0.209285  0.103217
# 2013-10              0.124083                 0.325180  0.141794
# 2012-10              0.114503                 0.185409  0.141712
# 2011-10              0.155273                 0.041702  0.015237
# 2010-10              0.130587                 0.224984  0.150505
# 2009-10              0.247112                 0.159142  0.145103
# 2008-10              0.267059                -0.120176  0.097975
# 2007-10              0.108295                 0.136091  0.047057
# 2006-10              0.094393                 0.214568  0.103697
# 2005-10              0.098794                 0.089253  0.026916
# 2004-10              0.102066                 0.109961  0.053895
# 2003-10              0.145028                 0.091382 -0.011996
# 2002-10              0.197080                -0.109355 -0.013291
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.716275
# 2013-10                      0.243868              0.117836  0.750970
# 2012-10                      0.126753              0.153977  0.335274
# 2011-10                      0.059192              0.215031  0.435670
# 2010-10                      0.141933              0.181490  0.517262
# 2009-10                      0.069615              0.358120  0.156850
# 2008-10                     -0.374750              0.346362  0.596589
# 2007-10                      0.124418              0.135401  0.578858
# 2006-10                      0.141614              0.100152  0.664802
# 2005-10                      0.067961              0.105708  0.773763
# 2004-10                      0.075654              0.112001  0.628962
# 2003-10                      0.186224              0.185829  0.521463
# 2002-10                     -0.164204              0.254499  0.618915
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.208185     0.048417      0.041603  2.116376  2.969594
# 2013-10            0.324180     0.044012      0.074205  2.612608  3.807807
# 2012-10            0.183604     0.019861      0.059587  1.603490  2.692668
# 2011-10            0.040502    -0.010065      0.115072  0.260846  0.324022
# 2010-10            0.222784     0.031187      0.100874  1.706025  2.501453
# 2009-10            0.155442     0.007659      0.161042  0.629034  0.920398
# 2008-10           -0.133613     0.090720      0.234320 -0.500313 -0.704271
# 2007-10            0.095691     0.004726      0.058137  0.883615  1.116013
# 2006-10            0.164668     0.051694      0.038158  1.744494  2.742517
# 2005-10            0.046153     0.019837      0.075213  0.467159  0.726447
# 2004-10            0.087098     0.022650      0.127709  0.853351  1.322648
# 2003-10            0.078282    -0.040581      0.113153  0.539771  0.936947
# 2002-10           -0.123955     0.020853      0.235864 -0.628961 -0.982043
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
