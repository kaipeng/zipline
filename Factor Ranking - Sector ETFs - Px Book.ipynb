# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pandas as pd

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
#secs=['S5TELS INDEX','S5ENRS INDEX']

secs=['S5TELS INDEX','S5ENRS INDEX','S5FINL INDEX','S5HLTH INDEX','S5UTIL INDEX','S5COND INDEX','S5INFT INDEX','S5INDU INDEX','S5CONS INDEX','S5MATR INDEX']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=['BEST_PE_RATIO', 'BEST_CUR_EV_TO_EBITDA', 'BEST_PX_BPS_RATIO']
options={"OVERRIDE-BEST_FPERIOD_OVERRIDE":"BF"}
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, options=options, start=startdate, end=enddate)
print data
data.to_pickle('bbg_sector_index_data-12yr.pickle')

# %%
for sym in data.items:
    data[sym].ix[:,1:4].plot(title=sym, figsize=(15, 2))
    data[sym].ix[:,6:].plot(figsize=(15, 2))

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Factor Ranking - Sector ETFs - Px to Book"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    add_history(50, '1d', 'BEST_PX_BPS_RATIO')
    add_history(100, '1d', 'BEST_PX_BPS_RATIO')
    add_history(200, '1d', 'BEST_PX_BPS_RATIO')

    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.001))

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200 or (context.i % 20 != 0):
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    rank_value = history(200, '1d', 'BEST_PX_BPS_RATIO').mean()
    for k,v in data.items():
        rank_value[k] = data[k].BEST_PX_BPS_RATIO / rank_value[k]

    #print short_return, med_return
    rank = rank_value.rank()
    
    for sec in rank.keys():
        ##### Trading logic ######
        target = 0
        if(rank[sec] > len(rank.keys())/2.0+2):
            target = -1
        elif(rank[sec] < len(rank.keys())/2.0-1):
            target = 1
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-rank', rank[sec])


# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_index_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-08 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-02-25 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  400 2002-07-15 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  500 2002-12-02 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  600 2003-04-21 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  700 2003-09-08 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  800 2004-01-26 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  900 2004-06-14 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  1000 2004-11-01 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  1100 2005-03-21 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  1200 2005-08-08 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  1300 2005-12-26 00:00:00+00:00 Pos Value:  20362.89 PnL:  851.629
# Bars Completed:
#  1400 2006-05-15 00:00:00+00:00 Pos Value:  329.49 PnL:  4185.91099993
# Bars Completed:
#  1500 2006-10-02 00:00:00+00:00 Pos Value:  2817.45 PnL:  8335.92599992
# Bars Completed:
#  1600 2007-02-19 00:00:00+00:00 Pos Value:  281.58 PnL:  9756.41699991
# Bars Completed:
#  1700 2007-07-09 00:00:00+00:00 Pos Value:  -722.33 PnL:  10267.7659998
# Bars Completed:
#  1800 2007-11-26 00:00:00+00:00 Pos Value:  -899.88 PnL:  8291.38399982
# Bars Completed:
#  1900 2008-04-14 00:00:00+00:00 Pos Value:  -150.94 PnL:  7485.41099978
# Bars Completed:
#  2000 2008-09-01 00:00:00+00:00 Pos Value:  20.194 PnL:  11975.0689997
# Bars Completed:
#  2100 2009-01-19 00:00:00+00:00 Pos Value:  1302.33 PnL:  7737.18999972
# Bars Completed:
#  2200 2009-06-08 00:00:00+00:00 Pos Value:  -71.13 PnL:  5156.97299968
# Bars Completed:
#  2300 2009-10-26 00:00:00+00:00 Pos Value:  -245.54 PnL:  3059.25699966
# Bars Completed:
#  2400 2010-03-15 00:00:00+00:00 Pos Value:  -596.8 PnL:  3778.68599956
# Bars Completed:
#  2500 2010-08-02 00:00:00+00:00 Pos Value:  505.6896 PnL:  2711.76009951
# Bars Completed:
#  2600 2010-12-20 00:00:00+00:00 Pos Value:  -332.7792 PnL:  3246.55409948
# Bars Completed:
#  2700 2011-05-09 00:00:00+00:00 Pos Value:  1111.0944 PnL:  4760.93829944
# Bars Completed:
#  2800 2011-09-26 00:00:00+00:00 Pos Value:  -3060.9575 PnL:  496.689899425
# Bars Completed:
#  2900 2012-02-13 00:00:00+00:00 Pos Value:  2326.7024 PnL:  3947.48019942
# Bars Completed:
#  3000 2012-07-02 00:00:00+00:00 Pos Value:  227.46 PnL:  2150.10539921
# Bars Completed:
#  3100 2012-11-19 00:00:00+00:00 Pos Value:  41.6448 PnL:  4590.11399912
# Bars Completed:
#  3200 2013-04-08 00:00:00+00:00 Pos Value:  849.28 PnL:  4434.69059908
# Bars Completed:
#  3300 2013-08-26 00:00:00+00:00 Pos Value:  276.96 PnL:  4838.090599
# Bars Completed:
#  3400 2014-01-13 00:00:00+00:00 Pos Value:  -1285.14 PnL:  2062.56359889
# Bars Completed:
#  3500 2014-06-02 00:00:00+00:00 Pos Value:  -296.038 PnL:  2548.08759866
# Bars Completed:
# [2014-11-14 16:28] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-14 16:28] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-14 16:28] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3600 2014-10-20 00:00:00+00:00 Pos Value:  -794.3 PnL:  2390.92009864

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-rank']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  16.292

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.021394                -0.016742 -0.016821
# 2013-10              0.022802                -0.002466 -0.002411
# 2012-10              0.034411                 0.020212  0.002777
# 2011-10              0.038160                -0.005574 -0.013089
# 2010-10              0.028996                -0.007862 -0.009385
# 2009-10              0.071299                -0.043592 -0.051662
# 2008-10              0.073876                -0.000171  0.019767
# 2007-10              0.022888                -0.002470 -0.041146
# 2006-10              0.029913                 0.091181  0.030705
# 2005-10              0.003583                -0.001122 -0.044512
# 2004-10              0.000000                 0.000000 -0.022862
# 2003-10              0.000000                 0.000000 -0.013100
# 2002-10              0.000000                 0.000000 -0.014600
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213 -0.006962
# 2013-10                      0.243868              0.117836 -0.004343
# 2012-10                      0.126753              0.153977  0.125096
# 2011-10                      0.059192              0.215031  0.108893
# 2010-10                      0.141933              0.181490 -0.004849
# 2009-10                      0.069615              0.358120  0.066293
# 2008-10                     -0.374750              0.346362  0.085976
# 2007-10                      0.124418              0.135401 -0.020526
# 2006-10                      0.141614              0.100152  0.115308
# 2005-10                      0.067961              0.105708  0.011671
# 2004-10                      0.075654              0.112001  0.000000
# 2003-10                      0.186224              0.185829  0.000000
# 2002-10                     -0.164204              0.254499  0.000000
#
#               excess_return  information  max_drawdown     sharpe   sortino  \
# period_label
# 2014-10           -0.017842    -0.089439      0.034497  -0.833938 -1.432330
# 2013-10           -0.003466    -0.118882      0.021964  -0.151991 -0.237960
# 2012-10            0.018408    -0.050678      0.026124   0.534935  1.002031
# 2011-10           -0.006774    -0.027725      0.053528  -0.177507 -0.258430
# 2010-10           -0.010062    -0.053546      0.033786  -0.347027 -0.592326
# 2009-10           -0.047292    -0.032089      0.063249  -0.663293 -1.045928
# 2008-10           -0.013608     0.080032      0.055191  -0.184199 -0.329502
# 2007-10           -0.042870    -0.057994      0.028167  -1.873020 -3.241989
# 2006-10            0.041281    -0.033769      0.014466   1.380030  2.322453
# 2005-10           -0.044222    -0.043570      0.003945 -12.342762 -6.195034
# 2004-10           -0.022862    -0.044715      0.000000   0.000000  0.000000
# 2003-10           -0.013100    -0.063731      0.000000   0.000000  0.000000
# 2002-10           -0.014600     0.036429      0.000000   0.000000  0.000000
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
