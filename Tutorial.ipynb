# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.utils.factory import load_bars_from_yahoo

# Load data manually from Yahoo! finance
start = datetime(2005, 1, 1, 0, 0, 0, 0, pytz.utc)
end = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['SPY','GOOGL','AAPL','YHOO','MSFT','TSLA','FB','TWTR']
data = load_bars_from_yahoo(stocks=secs, start=start,
                            end=end)
print data
for sym in data.items:
    data[sym].ix[:,:-2].plot(title=sym, figsize=(15, 3))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# SPY
# GOOGL
# AAPL
# YHOO
# MSFT
# TSLA
# FB
# TWTR
# <class 'pandas.core.panel.Panel'>
# Dimensions: 8 (items) x 2476 (major_axis) x 6 (minor_axis)
# Items axis: SPY to TWTR
# Major_axis axis: 2005-01-03 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target, record, symbol, history, add_history
import numpy as np

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    add_history(100, '1d', 'price')
    add_history(300, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
        
    

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 300:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, 'Data: ', data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(300, '1d', 'price').mean()
    
    for sec in data.keys():
        # Trading logic
        if short_mavg[sec] > long_mavg[sec]:
            # order_target orders as many shares as needed to
            # achieve the desired number of shares.
            order_target(sec, 100)
        elif short_mavg[sec] < long_mavg[sec]:
            order_target(sec, 0)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
perf_manual = algo_obj.run(data)
perf_manual.to_pickle('tutorial_perf.pickle')
# Out:
# Bars Completed:  300 Data:  2006-03-13 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  400 Data:  2006-08-03 00:00:00+00:00 Pos Value:  30554.0 PnL:  837.999999967
# Bars Completed:
#  500 Data:  2006-12-26 00:00:00+00:00 Pos Value:  38559.0 PnL:  6396.99999997
# Bars Completed:
#  600 Data:  2007-05-22 00:00:00+00:00 Pos Value:  43853.0 PnL:  8649.99999996
# Bars Completed:
#  700 Data:  2007-10-12 00:00:00+00:00 Pos Value:  50192.0 PnL:  17366.0
# Bars Completed:
#  800 Data:  2008-03-07 00:00:00+00:00 Pos Value:  25711.0 PnL:  4640.99999996
# Bars Completed:
#  900 Data:  2008-07-30 00:00:00+00:00 Pos Value:  2163.0 PnL:  12196.9999997
# Bars Completed:
#  1000 Data:  2008-12-19 00:00:00+00:00 Pos Value:  0.0 PnL:  11362.9999997
# Bars Completed:
#  1100 Data:  2009-05-15 00:00:00+00:00 Pos Value:  0.0 PnL:  11362.9999997
# Bars Completed:
#  1200 Data:  2009-10-07 00:00:00+00:00 Pos Value:  41991.0 PnL:  15431.9999984
# Bars Completed:
#  1300 Data:  2010-03-03 00:00:00+00:00 Pos Value:  44407.0 PnL:  17847.9999984
# Bars Completed:
#  1400 Data:  2010-07-26 00:00:00+00:00 Pos Value:  41945.0 PnL:  15385.9999984
# Bars Completed:
#  1500 Data:  2010-12-15 00:00:00+00:00 Pos Value:  18730.0 PnL:  17601.9999686
# Bars Completed:
#  1600 Data:  2011-05-10 00:00:00+00:00 Pos Value:  51542.0 PnL:  16792.9999657
# Bars Completed:
#  1700 Data:  2011-09-30 00:00:00+00:00 Pos Value:  18232.0 PnL:  17583.9999649
# Bars Completed:
#  1800 Data:  2012-02-24 00:00:00+00:00 Pos Value:  43898.0 PnL:  19769.9999637
# Bars Completed:
#  1900 Data:  2012-07-18 00:00:00+00:00 Pos Value:  58022.0 PnL:  19302.9999637
# Bars Completed:
#  2000 Data:  2012-12-11 00:00:00+00:00 Pos Value:  60586.0 PnL:  24669.9999515
# Bars Completed:
#  2100 Data:  2013-05-07 00:00:00+00:00 Pos Value:  69540.0 PnL:  35872.9999492
# Bars Completed:
#  2200 Data:  2013-09-27 00:00:00+00:00 Pos Value:  91235.0 PnL:  54183.9999492
# Bars Completed:
#  2300 Data:  2014-02-21 00:00:00+00:00 Pos Value:  121075.0 PnL:  76308.9999492
# Bars Completed:
# [2014-11-07 19:14] INFO: Performance: Simulated 2476 trading days out of 2476.
# [2014-11-07 19:14] INFO: Performance: first open: 2005-01-03 14:31:00+00:00
# [2014-11-07 19:14] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  2400 Data:  2014-07-16 00:00:00+00:00 Pos Value:  124398.0 PnL:  78688.9999492

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
buys = perf_trans.ix[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
perf.ix[buys.index][0:5]
# Out:
#                       AAPL  AAPL-l_ma  AAPL-s_ma  FB  FB-l_ma  FB-s_ma  \
# 2006-03-14 21:00:00   9.11   6.886667     9.3524 NaN      NaN      NaN
# 2006-11-13 21:00:00  11.41   8.979200     9.3957 NaN      NaN      NaN
# 2007-05-07 20:00:00  14.06  10.288133    12.1343 NaN      NaN      NaN
# 2008-06-03 20:00:00  25.08  19.566867    20.4560 NaN      NaN      NaN
# 2009-07-29 20:00:00  21.65  17.216033    17.3366 NaN      NaN      NaN
#
#                       GOOGL  GOOGL-l_ma  GOOGL-s_ma   MSFT  ...    \
# 2006-03-14 21:00:00  175.76  149.001100    199.1231  22.49  ...
# 2006-11-13 21:00:00  240.76  195.660800    205.6664  24.43  ...
# 2007-05-07 20:00:00  233.87  214.323200    235.2901  25.73  ...
# 2008-06-03 20:00:00  283.93  274.160900    260.0211  23.29  ...
# 2009-07-29 20:00:00  218.34  201.522767    197.2541  20.79  ...
#
#                                                                 orders  \
# 2006-03-14 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2006-11-13 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2007-05-07 20:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2008-06-03 20:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2009-07-29 20:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
#
#                                   period_close                period_open  \
# 2006-03-14 21:00:00  2006-03-14 21:00:00+00:00  2006-03-14 14:31:00+00:00
# 2006-11-13 21:00:00  2006-11-13 21:00:00+00:00  2006-11-13 14:31:00+00:00
# 2007-05-07 20:00:00  2007-05-07 20:00:00+00:00  2007-05-07 13:31:00+00:00
# 2008-06-03 20:00:00  2008-06-03 20:00:00+00:00  2008-06-03 13:31:00+00:00
# 2009-07-29 20:00:00  2009-07-29 20:00:00+00:00  2009-07-29 13:31:00+00:00
#
#                      pnl  portfolio_value  \
# 2006-03-14 21:00:00  -15            99985
# 2006-11-13 21:00:00  418           107231
# 2007-05-07 20:00:00 -140           108103
# 2008-06-03 20:00:00  -13           113121
# 2009-07-29 20:00:00   -3           111360
#
#                                                              positions  \
# 2006-03-14 21:00:00  [{u'amount': 100, u'last_sale_price': 108.82, ...
# 2006-11-13 21:00:00  [{u'amount': 100, u'last_sale_price': 117.33, ...
# 2007-05-07 20:00:00  [{u'amount': 100, u'last_sale_price': 129.02, ...
# 2008-06-03 20:00:00  [{u'amount': 100, u'last_sale_price': 25.08, u...
# 2009-07-29 20:00:00  [{u'amount': 100, u'last_sale_price': 21.65, u...
#
#                       returns  starting_cash  starting_value  \
# 2006-03-14 21:00:00 -0.000150         100000               0
# 2006-11-13 21:00:00  0.003913          70284           36529
# 2007-05-07 20:00:00 -0.001293          67838           40405
# 2008-06-03 20:00:00 -0.000115         110616            2518
# 2009-07-29 20:00:00 -0.000027         111363               0
#
#                                                           transactions
# 2006-03-14 21:00:00  [{u'commission': 3.0, u'amount': 100, u'sid': ...
# 2006-11-13 21:00:00  [{u'commission': 3.0, u'amount': 100, u'sid': ...
# 2007-05-07 20:00:00  [{u'commission': 3.0, u'amount': 100, u'sid': ...
# 2008-06-03 20:00:00  [{u'commission': 3.0, u'amount': 100, u'sid': ...
# 2009-07-29 20:00:00  [{u'commission': 3.0, u'amount': 100, u'sid': ...
#
# [5 rows x 37 columns]

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,5*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)

    ax1.set_ylabel('portfolio value in $')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]
        #print [(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]
        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]
        #sells = perf_trans.ix[[t[0]['amount'] < 0 for t in perf_trans.transactions]]
        ax2.plot(buys.index, perf[sec].ix[buys.index],
                 '^', markersize=10, color='g')
        ax2.plot(sells.index, perf[sec].ix[sells.index],
                 'v', markersize=10, color='r')
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()

file_analyze('tutorial_perf.pickle', 0)
