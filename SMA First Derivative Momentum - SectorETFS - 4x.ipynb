# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.utils.factory import load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2005, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
data = load_bars_from_yahoo(stocks=secs, start=startdate,
                            end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,:-2].plot(title=sym, figsize=(15, 3))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# IYE
# IYW
# IYH
# IYF
# IYJ
# IYZ
# IYC
# IYM
# IYK
# <class 'pandas.core.panel.Panel'>
# Dimensions: 9 (items) x 2476 (major_axis) x 6 (minor_axis)
# Items axis: IYE to IYK
# Major_axis axis: 2005-01-03 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target, record, symbol, history, add_history
import numpy as np

from collections import deque

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    add_history(10, '1d', 'price')
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, 'Data: ', data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    xshort_mavg = history(20, '1d', 'price').mean()
    short_mavg = history(50, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0
#         if (xshort_mavg[sec] > context.cache['xs_ma'][sec][-1]) and (context.cache['xs_ma'][sec][-1] <= context.cache['xs_ma'][sec][-2]):
#             target += 20
#         if (xshort_mavg[sec] < context.cache['xs_ma'][sec][-1]) and (context.cache['xs_ma'][sec][-1] >= context.cache['xs_ma'][sec][-2]):
#             target -= 50
        
        try:
            if (xshort_mavg[sec] > context.cache['xs_ma'][-1][sec]) and (context.cache['xs_ma'][-1][sec] <= context.cache['xs_ma'][-2][sec]):
                order_target(sec, 100)
            if (xshort_mavg[sec] < context.cache['xs_ma'][-1][sec]) and (context.cache['xs_ma'][-1][sec] >= context.cache['xs_ma'][-2][sec]):
                order_target(sec, -100)
            
            ##### Trading logic ######

            # order_target orders as many shares as needed to
            # achieve the desired number of shares.
            #order_target(sec, target)
        except:
            pass

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-xs_ma', xshort_mavg[sec])
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    
    context.cache['xs_ma'].append(xshort_mavg)
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
        

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
perf_manual = algo_obj.run(data)
perf_manual.to_pickle('tutorial_perf.pickle')
print "FINISHED"
# Out:
# Bars Completed:  200 Data:  2005-10-17 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 Data:  2006-03-13 00:00:00+00:00 Pos Value:  29110.0 PnL:  -1285.63612867
# Bars Completed:
#  400 Data:  2006-08-03 00:00:00+00:00 Pos Value:  4735.0 PnL:  -4327.39131997
# Bars Completed:
#  500 Data:  2006-12-26 00:00:00+00:00 Pos Value:  16575.0 PnL:  -930.861079281
# Bars Completed:
#  600 Data:  2007-05-22 00:00:00+00:00 Pos Value:  53106.0 PnL:  341.290847446
# Bars Completed:
#  700 Data:  2007-10-12 00:00:00+00:00 Pos Value:  54919.0 PnL:  -1252.46723351
# Bars Completed:
#  800 Data:  2008-03-07 00:00:00+00:00 Pos Value:  -15185.0 PnL:  -3401.90689678
# Bars Completed:
#  900 Data:  2008-07-30 00:00:00+00:00 Pos Value:  10402.0 PnL:  -4242.07083995
# Bars Completed:
#  1000 Data:  2008-12-19 00:00:00+00:00 Pos Value:  31062.0 PnL:  393.604522243
# Bars Completed:
#  1100 Data:  2009-05-15 00:00:00+00:00 Pos Value:  24403.0 PnL:  642.452454543
# Bars Completed:
#  1200 Data:  2009-10-07 00:00:00+00:00 Pos Value:  39267.0 PnL:  1605.91187968
# Bars Completed:
#  1300 Data:  2010-03-03 00:00:00+00:00 Pos Value:  42536.0 PnL:  -1040.01100194
# Bars Completed:
#  1400 Data:  2010-07-26 00:00:00+00:00 Pos Value:  31357.0 PnL:  221.658507929
# Bars Completed:
#  1500 Data:  2010-12-15 00:00:00+00:00 Pos Value:  48449.0 PnL:  1463.86437732
# Bars Completed:
#  1600 Data:  2011-05-10 00:00:00+00:00 Pos Value:  19143.0 PnL:  2205.84655854
# Bars Completed:
#  1700 Data:  2011-09-30 00:00:00+00:00 Pos Value:  -43953.0 PnL:  -3980.92645464
# Bars Completed:
#  1800 Data:  2012-02-24 00:00:00+00:00 Pos Value:  53959.0 PnL:  -3514.35122221
# Bars Completed:
#  1900 Data:  2012-07-18 00:00:00+00:00 Pos Value:  14586.0 PnL:  -4709.26965113
# Bars Completed:
#  2000 Data:  2012-12-11 00:00:00+00:00 Pos Value:  56853.0 PnL:  -4814.60117899
# Bars Completed:
#  2100 Data:  2013-05-07 00:00:00+00:00 Pos Value:  65016.0 PnL:  -2627.07302986
# Bars Completed:
#  2200 Data:  2013-09-27 00:00:00+00:00 Pos Value:  69061.0 PnL:  -4094.32670177
# Bars Completed:
#  2300 Data:  2014-02-21 00:00:00+00:00 Pos Value:  6703.0 PnL:  -7074.32249896
# Bars Completed:
# [2014-11-10 22:14] INFO: Performance: Simulated 2476 trading days out of 2476.
# [2014-11-10 22:14] INFO: Performance: first open: 2005-01-03 14:31:00+00:00
# [2014-11-10 22:14] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  2400 Data:  2014-07-16 00:00:00+00:00 Pos Value:  81215.0 PnL:  -7535.8791339

# %%
#perf = perf_manual
#perf_trans = perf.ix[[t != [] for t in perf.transactions]]
#buys = perf_trans.ix[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#perf.ix[buys.index][0:5]

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1000*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-xs_ma', sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]
        #print [(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]
        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]
        #sells = perf_trans.ix[[t[0]['amount'] < 0 for t in perf_trans.transactions]]
        #print [(trade['amount']/10 if trade['sid']==sec else 0) for trade in perf.ix[buys.index]]
        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze('tutorial_perf.pickle', 1000,1400)
# Out:
# SPY
