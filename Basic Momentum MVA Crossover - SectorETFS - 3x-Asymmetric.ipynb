# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['TLT','IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,:-2].plot(title=sym, figsize=(15, 3))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# http://10.8.84.65/api/bdh {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'TLT EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYE EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYW EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYH EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYF EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYJ EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYZ EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYC EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYM EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# http://10.8.84.65/api/bdh
#  {'fields': 'OPEN,HIGH,LOW,PX_LAST,VOLUME,LAST_PRICE', 'security': 'IYK EQUITY', 'endDate': '20141101', 'startDate': '20010101'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 10 (items) x 3480 (major_axis) x 6 (minor_axis)
# Items axis: TLT to IYK
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price
# WARNING: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target, record, symbol, history, add_history
import numpy as np

from collections import deque

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, 'Data: ', data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(50, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0
        if short_mavg[sec] > med_mavg[sec]:
            target += 40
        if short_mavg[sec] > long_mavg[sec]:
            target += 80
        if med_mavg[sec] > long_mavg[sec]:
            target += 100

        if short_mavg[sec] < med_mavg[sec]:
            target -= 40
        if short_mavg[sec] < long_mavg[sec]:
            target -= 20
            

        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
        

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 Data:  2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 Data:  2002-03-18 00:00:00+00:00 Pos Value:  21098.6 PnL:  -2106.76805255
# Bars Completed:
#  400 Data:  2002-08-08 00:00:00+00:00 Pos Value:  -12726.2 PnL:  -7313.00196223
# Bars Completed:
#  500 Data:  2002-12-31 00:00:00+00:00 Pos Value:  1258.534 PnL:  -7990.09560678
# Bars Completed:
#  600 Data:  2003-05-27 00:00:00+00:00 Pos Value:  60658.0 PnL:  -7518.30543002
# Bars Completed:
#  700 Data:  2003-10-16 00:00:00+00:00 Pos Value:  78001.274 PnL:  -2245.23138183
# Bars Completed:
#  800 Data:  2004-03-11 00:00:00+00:00 Pos Value:  105507.4 PnL:  3492.69231424
# Bars Completed:
#  900 Data:  2004-08-04 00:00:00+00:00 Pos Value:  53327.926 PnL:  862.708147652
# Bars Completed:
#  1000 Data:  2004-12-27 00:00:00+00:00 Pos Value:  96096.726 PnL:  4110.79748115
# Bars Completed:
#  1100 Data:  2005-05-19 00:00:00+00:00 Pos Value:  68333.64 PnL:  2289.63006882
# Bars Completed:
#  1200 Data:  2005-10-11 00:00:00+00:00 Pos Value:  92590.6 PnL:  -51.1687709509
# Bars Completed:
#  1300 Data:  2006-03-07 00:00:00+00:00 Pos Value:  106782.6 PnL:  4042.94629102
# Bars Completed:
#  1400 Data:  2006-07-28 00:00:00+00:00 Pos Value:  31650.738 PnL:  2497.27696078
# Bars Completed:
#  1500 Data:  2006-12-19 00:00:00+00:00 Pos Value:  129884.526 PnL:  7351.41564622
# Bars Completed:
#  1600 Data:  2007-05-16 00:00:00+00:00 Pos Value:  140787.674 PnL:  14285.5083901
# Bars Completed:
#  1700 Data:  2007-10-08 00:00:00+00:00 Pos Value:  61165.474 PnL:  13170.4763443
# Bars Completed:
#  1800 Data:  2008-03-03 00:00:00+00:00 Pos Value:  25587.4 PnL:  10819.773136
# Bars Completed:
#  1900 Data:  2008-07-24 00:00:00+00:00 Pos Value:  3062.8 PnL:  7465.13206682
# Bars Completed:
#  2000 Data:  2008-12-15 00:00:00+00:00 Pos Value:  4971.904 PnL:  14602.034398
# Bars Completed:
#  2100 Data:  2009-05-11 00:00:00+00:00 Pos Value:  3673.4 PnL:  9645.92997569
# Bars Completed:
#  2200 Data:  2009-10-01 00:00:00+00:00 Pos Value:  92827.16 PnL:  18666.8458541
# Bars Completed:
#  2300 Data:  2010-02-25 00:00:00+00:00 Pos Value:  86503.0 PnL:  26166.6858233
# Bars Completed:
#  2400 Data:  2010-07-20 00:00:00+00:00 Pos Value:  49562.8 PnL:  23009.5487756
# Bars Completed:
#  2500 Data:  2010-12-09 00:00:00+00:00 Pos Value:  108568.2 PnL:  27446.1697151
# Bars Completed:
#  2600 Data:  2011-05-04 00:00:00+00:00 Pos Value:  120323.6 PnL:  37287.3668733
# Bars Completed:
#  2700 Data:  2011-09-26 00:00:00+00:00 Pos Value:  19338.0 PnL:  32273.681581
# Bars Completed:
#  2800 Data:  2012-02-17 00:00:00+00:00 Pos Value:  105860.0 PnL:  33779.1521885
# Bars Completed:
#  2900 Data:  2012-07-12 00:00:00+00:00 Pos Value:  100682.8 PnL:  31023.5282663
# Bars Completed:
#  3000 Data:  2012-12-05 00:00:00+00:00 Pos Value:  118556.754 PnL:  33912.2387923
# Bars Completed:
#  3100 Data:  2013-05-01 00:00:00+00:00 Pos Value:  114566.606 PnL:  46410.0656621
# Bars Completed:
#  3200 Data:  2013-09-23 00:00:00+00:00 Pos Value:  148769.6 PnL:  58952.8581512
# Bars Completed:
#  3300 Data:  2014-02-14 00:00:00+00:00 Pos Value:  161812.8 PnL:  71871.258151
# Bars Completed:
# [2014-11-11 20:54] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-11 20:54] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-11 20:54] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 Data:  2014-07-10 00:00:00+00:00 Pos Value:  203172.2 PnL:  82038.6793038

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
# Out:
# 1715.3999999999999

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 180)
# Out:
# SPY
