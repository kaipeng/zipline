# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pandas as pd

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
#secs=['S5TELS INDEX','S5ENRS INDEX']

secs=['S5TELS INDEX','S5ENRS INDEX','S5FINL INDEX','S5HLTH INDEX','S5UTIL INDEX','S5COND INDEX','S5INFT INDEX','S5INDU INDEX','S5CONS INDEX','S5MATR INDEX']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=['BEST_PE_RATIO', 'BEST_CUR_EV_TO_EBITDA', 'BEST_PX_BPS_RATIO']
options={"OVERRIDE-BEST_FPERIOD_OVERRIDE":"BF"}
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, options=options, start=startdate, end=enddate)
print data
data.to_pickle('bbg_sector_index_data-12yr.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5TELS INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5ENRS INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5FINL INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5HLTH INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5UTIL INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5COND INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5INFT INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5INDU INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5CONS INDEX'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,BEST_PE_RATIO,BEST_CUR_EV_TO_EBITDA,BEST_PX_BPS_RATIO', 'adjustmentSplit': 'true', 'endDate': '20141101', 'OVERRIDE-BEST_FPERIOD_OVERRIDE': 'BF', 'security': 'S5MATR INDEX'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 10 (items) x 3609 (major_axis) x 9 (minor_axis)
# Items axis: S5TELS INDEX to S5MATR INDEX
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to BEST_PX_BPS_RATIO

# %%
for sym in data.items:
    data[sym].ix[:,1:4].plot(title=sym, figsize=(15, 2))
    data[sym].ix[:,6:].plot(figsize=(15, 2))

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline

import numpy as np
import math

from collections import deque

algo_name = "Bloomberg Data + Fundamentals - PE Ratio longer-frequent"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(50, '1d', 'BEST_PE_RATIO')
    add_history(100, '1d', 'BEST_PE_RATIO')
    add_history(200, '1d', 'BEST_PE_RATIO')

    context.i = 0

    set_commission(zipline.finance.commission.PerShare(cost=0.001))
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 400:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, 'Data: ', data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    s_hist = history(50, '1d', 'BEST_PE_RATIO')
    m_hist = history(100, '1d', 'BEST_PE_RATIO')
    l_hist = history(200, '1d', 'BEST_PE_RATIO')
    
    short_mavg = s_hist.mean()
    med_mavg = m_hist.mean()
    long_mavg = l_hist.mean()
    
    short_std = s_hist.std()* math.sqrt(50/250.)
    med_std = m_hist.std()* math.sqrt(100/250.)
    long_std = l_hist.std()* math.sqrt(200/250.)

    short_z = {}
    med_z = {}
    long_z = {}
    
    threshold_lower = -3
    threshold_upper = 4
    threshold_lower2 = -4
    threshold_upper2 = 5
    for sec in data.keys():
        short_z[sec] = (data[sec].BEST_PE_RATIO - short_mavg[sec]) / short_std[sec] 
        med_z[sec] = (data[sec].BEST_PE_RATIO - med_mavg[sec]) / med_std[sec] 
        long_z[sec] = (data[sec].BEST_PE_RATIO - long_mavg[sec]) / long_std[sec] 
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0
        if short_z[sec] > threshold_upper:
            target -= 5
        if med_z[sec] > threshold_upper:
            target -= 10
        if long_z[sec] > threshold_upper:
            target -= 15
        if short_z[sec] < threshold_lower:
            target += 20
        if med_z[sec] < threshold_lower:
            target += 30
        if long_z[sec] < threshold_lower:
            target += 40

        if short_z[sec] > threshold_upper2:
            target -= 5
        if med_z[sec] > threshold_upper2:
            target -= 10
        if long_z[sec] > threshold_upper2:
            target -= 15
        if short_z[sec] < threshold_lower2:
            target += 20
        if med_z[sec] < threshold_lower2:
            target += 30
        if long_z[sec] < threshold_lower2:
            target += 40            

        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        target=target/100*(context.portfolio.portfolio_value)/len(data)
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-factor', data[sec].BEST_PE_RATIO)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
        

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_index_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  400 Data:  2002-07-15 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  500 Data:  2002-12-02 00:00:00+00:00 Pos Value:  -19441.5 PnL:  -1476.08700007
# Bars Completed:
#  600 Data:  2003-04-21 00:00:00+00:00 Pos Value:  -29929.47 PnL:  -838.078000125
# Bars Completed:
#  700 Data:  2003-09-08 00:00:00+00:00 Pos Value:  0.0 PnL:  -168.95400021
# Bars Completed:
#  800 Data:  2004-01-26 00:00:00+00:00 Pos Value:  -9929.25 PnL:  -4228.48300039
# Bars Completed:
#  900 Data:  2004-06-14 00:00:00+00:00 Pos Value:  0.0 PnL:  -2183.61200043
# Bars Completed:
#  1000 Data:  2004-11-01 00:00:00+00:00 Pos Value:  -29371.1 PnL:  -1473.9590006
# Bars Completed:
#  1100 Data:  2005-03-21 00:00:00+00:00 Pos Value:  0.0 PnL:  -3049.42400064
# Bars Completed:
#  1200 Data:  2005-08-08 00:00:00+00:00 Pos Value:  0.0 PnL:  -1253.12600068
# Bars Completed:
#  1300 Data:  2005-12-26 00:00:00+00:00 Pos Value:  -9728.94 PnL:  -1838.40000079
# Bars Completed:
#  1400 Data:  2006-05-15 00:00:00+00:00 Pos Value:  0.0 PnL:  -975.916000831
# Bars Completed:
#  1500 Data:  2006-10-02 00:00:00+00:00 Pos Value:  -19582.66 PnL:  785.430999109
# Bars Completed:
#  1600 Data:  2007-02-19 00:00:00+00:00 Pos Value:  -20141.91 PnL:  876.194999042
# Bars Completed:
#  1700 Data:  2007-07-09 00:00:00+00:00 Pos Value:  -9958.75 PnL:  1408.170999
# Bars Completed:
#  1800 Data:  2007-11-26 00:00:00+00:00 Pos Value:  9959.04 PnL:  1585.41069895
# Bars Completed:
#  1900 Data:  2008-04-14 00:00:00+00:00 Pos Value:  0.0 PnL:  5116.79669892
# Bars Completed:
#  2000 Data:  2008-09-01 00:00:00+00:00 Pos Value:  0.0 PnL:  6475.28269886
# Bars Completed:
#  2100 Data:  2009-01-19 00:00:00+00:00 Pos Value:  0.0 PnL:  14439.8126987
# Bars Completed:
#  2200 Data:  2009-06-08 00:00:00+00:00 Pos Value:  -23724.97 PnL:  19148.3446985
# Bars Completed:
#  2300 Data:  2009-10-26 00:00:00+00:00 Pos Value:  0.0 PnL:  20321.4386982
# Bars Completed:
#  2400 Data:  2010-03-15 00:00:00+00:00 Pos Value:  0.0 PnL:  20550.8126981
# Bars Completed:
#  2500 Data:  2010-08-02 00:00:00+00:00 Pos Value:  0.0 PnL:  23948.8526979
# Bars Completed:
#  2600 Data:  2010-12-20 00:00:00+00:00 Pos Value:  -12182.0 PnL:  23278.0724975
# Bars Completed:
#  2700 Data:  2011-05-09 00:00:00+00:00 Pos Value:  -66.46 PnL:  25685.7266973
# Bars Completed:
#  2800 Data:  2011-09-26 00:00:00+00:00 Pos Value:  0.0 PnL:  25676.0461972
# Bars Completed:
#  2900 Data:  2012-02-13 00:00:00+00:00 Pos Value:  -12855.28 PnL:  28312.6559965
# Bars Completed:
#  3000 Data:  2012-07-02 00:00:00+00:00 Pos Value:  -52001.59 PnL:  30126.6974962
# Bars Completed:
#  3100 Data:  2012-11-19 00:00:00+00:00 Pos Value:  39672.35 PnL:  31088.0824958
# Bars Completed:
#  3200 Data:  2013-04-08 00:00:00+00:00 Pos Value:  -38984.65 PnL:  29035.347895
# Bars Completed:
#  3300 Data:  2013-08-26 00:00:00+00:00 Pos Value:  0.0 PnL:  27722.4235945
# Bars Completed:
#  3400 Data:  2014-01-13 00:00:00+00:00 Pos Value:  -12387.81 PnL:  27272.0280942
# Bars Completed:
#  3500 Data:  2014-06-02 00:00:00+00:00 Pos Value:  -12436.2 PnL:  27732.9420937
# Bars Completed:
# [2014-11-14 17:26] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-14 17:26] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-14 17:26] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3600 Data:  2014-10-20 00:00:00+00:00 Pos Value:  38447.11 PnL:  28578.2118931

# %%
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, color='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-factor', sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 300)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  111.695

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.023481                 0.009795  0.004570
# 2013-10              0.024871                -0.031568 -0.015293
# 2012-10              0.031387                 0.034800  0.040982
# 2011-10              0.090338                 0.036091  0.024146
# 2010-10              0.026212                 0.023146  0.017355
# 2009-10              0.081317                 0.116752  0.117586
# 2008-10              0.139818                 0.050420  0.124848
# 2007-10              0.027490                 0.023483 -0.020022
# 2006-10              0.025363                 0.006084 -0.046706
# 2005-10              0.023958                 0.006443 -0.036449
# 2004-10              0.022016                -0.014594 -0.035768
# 2003-10              0.029145                 0.016027  0.013203
# 2002-10              0.067436                -0.015342 -0.011727
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.028144
# 2013-10                      0.243868              0.117836 -0.071132
# 2012-10                      0.126753              0.153977 -0.063921
# 2011-10                      0.059192              0.215031  0.185277
# 2010-10                      0.141933              0.181490  0.025701
# 2009-10                      0.069615              0.358120 -0.068784
# 2008-10                     -0.374750              0.346362  0.226347
# 2007-10                      0.124418              0.135401  0.036955
# 2006-10                      0.141614              0.100152  0.031510
# 2005-10                      0.067961              0.105708 -0.008357
# 2004-10                      0.075654              0.112001 -0.031991
# 2003-10                      0.186224              0.185829 -0.059354
# 2002-10                     -0.164204              0.254499  0.101871
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.008695    -0.076891      0.023762  0.370271  0.436054
# 2013-10           -0.032568    -0.126118      0.040352 -1.309496 -1.364413
# 2012-10            0.032995    -0.036566      0.019847  1.051240  1.450235
# 2011-10            0.034891    -0.013396      0.071600  0.386228  0.475211
# 2010-10            0.020946    -0.044489      0.020272  0.799110  1.166227
# 2009-10            0.113052    -0.002854      0.038103  1.390272  2.603537
# 2008-10            0.036983     0.100801      0.097424  0.264508  0.517740
# 2007-10           -0.016917    -0.048755      0.012715 -0.615375 -0.931443
# 2006-10           -0.043816    -0.082404      0.015142 -1.727575 -3.061512
# 2005-10           -0.036657    -0.037185      0.027077 -1.530068 -1.781291
# 2004-10           -0.037456    -0.050360      0.046374 -1.701347 -1.776962
# 2003-10            0.002927    -0.054428      0.013932  0.100443  0.143063
# 2002-10           -0.029942     0.035621      0.084207 -0.444009 -0.183477
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
