# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=[]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history
import numpy as np

from collections import deque

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg-target_value"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    '''
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
    '''
    set_commission(zipline.finance.commission.PerShare(cost=0.001))
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(50, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0.0
        if short_mavg[sec] > med_mavg[sec]:
            target += .2
        if short_mavg[sec] > long_mavg[sec]:
            target += .3
        if med_mavg[sec] > long_mavg[sec]:
            target += .5

        if short_mavg[sec] < med_mavg[sec]:
            target -= .1
        if short_mavg[sec] < long_mavg[sec]:
            target -= .05
        if med_mavg[sec] < long_mavg[sec]:
            target -= 0
            
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    '''
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
    '''    

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  30122.6935 PnL:  -11.7626889147
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  1403.2982 PnL:  -6643.40234612
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  10618.3586 PnL:  -7364.59924812
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  60343.8129 PnL:  -5431.42307576
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  88826.6566 PnL:  1414.83740013
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  108825.2505 PnL:  8798.92186187
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  67116.255 PnL:  9107.75907522
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  90106.022 PnL:  14896.2167255
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  78504.404 PnL:  14301.8781971
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  98122.4734 PnL:  14692.8520922
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  114663.5405 PnL:  20794.2887076
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  49831.0904 PnL:  20785.2789412
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  120605.3273 PnL:  26750.9740322
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  131885.2098 PnL:  35948.1082879
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  78726.1888 PnL:  38370.9041289
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  31898.037 PnL:  34903.6342035
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  24722.229 PnL:  31459.4919308
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  -4137.0622 PnL:  30955.6877751
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  7212.2224 PnL:  27255.1605052
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  128151.2378 PnL:  40444.0174804
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  132409.9178 PnL:  51110.4771276
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  70525.7699 PnL:  49298.2504692
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  138286.7645 PnL:  58936.6701671
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  153161.5224 PnL:  73011.4902153
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  26609.3722 PnL:  61947.1146107
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  104331.3342 PnL:  65303.1926328
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  116711.7615 PnL:  62281.8886233
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  135442.9353 PnL:  68097.1820783
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  147983.6457 PnL:  84191.9936965
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  175754.2524 PnL:  98602.2896363
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  189575.9983 PnL:  114138.296933
# Bars Completed:
# [2014-11-12 23:56] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-12 23:56] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-12 23:56] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  228949.7303 PnL:  129055.914577

# %%
import pandas as pd
from zipline.data.loader import load_bars_from_yahoo

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg-target_value"

def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 150)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
# Out:
# Total Commish:  2886.81

# %%
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.096482                 0.131866  0.004817
# 2013-10              0.101302                 0.224511  0.018256
# 2012-10              0.077348                 0.050040  0.010707
# 2011-10              0.120437                 0.036204  0.011117
# 2010-10              0.140500                 0.099806 -0.001211
# 2009-10              0.107928                 0.105048  0.104006
# 2008-10              0.078439                -0.094874 -0.099962
# 2007-10              0.106629                 0.132788  0.028735
# 2006-10              0.079269                 0.072952 -0.044867
# 2005-10              0.076100                 0.034751 -0.025209
# 2004-10              0.084945                 0.093365  0.034191
# 2003-10              0.074772                 0.096591  0.046257
# 2002-10              0.057451                -0.071065 -0.071045
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.859447
# 2013-10                      0.243868              0.117836  0.845132
# 2012-10                      0.126753              0.153977  0.300347
# 2011-10                      0.059192              0.215031  0.411897
# 2010-10                      0.141933              0.181490  0.707188
# 2009-10                      0.069615              0.358120 -0.040329
# 2008-10                     -0.374750              0.346362  0.021507
# 2007-10                      0.124418              0.135401  0.757607
# 2006-10                      0.141614              0.100152  0.740551
# 2005-10                      0.067961              0.105708  0.678147
# 2004-10                      0.075654              0.112001  0.687844
# 2003-10                      0.186224              0.185829  0.215073
# 2002-10                     -0.164204              0.254499  0.081767
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.130766    -0.040056      0.066035  1.355343  1.767100
# 2013-10            0.223511    -0.042347      0.057307  2.206381  3.031325
# 2012-10            0.048235    -0.040292      0.075643  0.623610  0.843339
# 2011-10            0.035004    -0.015809      0.127475  0.290639  0.348464
# 2010-10            0.097606    -0.035731      0.123159  0.694708  0.852953
# 2009-10            0.101348    -0.004177      0.070090  0.939033  1.288263
# 2008-10           -0.108311     0.056573      0.092520 -1.380832 -2.042396
# 2007-10            0.092388     0.005678      0.088543  0.866442  0.994869
# 2006-10            0.023052    -0.105449      0.080134  0.290804  0.411450
# 2005-10           -0.008349    -0.050650      0.060449 -0.109716 -0.164876
# 2004-10            0.070503     0.017300      0.061989  0.829984  1.166261
# 2003-10            0.083491    -0.036853      0.043639  1.116614  1.348216
# 2002-10           -0.085665     0.019736      0.088494 -1.491092 -2.202734
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
