# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2015, 1, 15, 0, 0, 0, 0, pytz.utc)
secs=['TLT','SPY','QQQ', 'LQD', 'AGG', 'GLD', 'IWM', 'DIA','JNK','IYR','XOP', 'EWA','EWZ','EWJ','EWY','EEM','EWW','EZU','TUR','EWH','EWI','EWP','EWU','EWC']
fields=['CALL_IMP_VOL_30D','CALL_IMP_VOL_60D','CALL_IMP_VOL_90D']

algo_name = "Minimum Variance Portfolio - Assets"
data_name = 'bbg_assets_etf_data-12yr'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, start=startdate, end=enddate)
print data
data.to_pickle(data_name+'.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'TLT EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'SPY EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'QQQ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'LQD EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'AGG EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'GLD EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'IWM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'DIA EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'JNK EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'IYR EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'XOP EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWA EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWY EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EEM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EZU EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'TUR EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWI EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWP EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWU EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20150115', 'security': 'EWC EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 24 (items) x 3531 (major_axis) x 9 (minor_axis)
# Items axis: TLT to EWC
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2015-01-15 00:00:00+00:00
# Minor_axis axis: open to CALL_IMP_VOL_90D

# %%
import pandas as pd
data = pd.read_pickle(data_name+'.pickle')
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
# Out:
# C:\Python27\lib\site-packages\matplotlib\pyplot.py:423: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

# Define algorithm
def initialize(context):                  
    # Register 3 histories that maintain windows of trailing data
    context.windows = [253]
    
    for t in context.windows:
        add_history(t, '1d', 'price')
        
    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.002))

def handle_data(context, data):
    # Skip first 60 days to get full windows
    context.i += 1
    if context.i < context.windows[-1] or (context.i % 22 != 0):
        return
    
    # Progess report
    if context.i % 1 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    hist_used = history(context.windows[-1], '1d', 'price')
    for sec in hist_used.keys().values:
        if np.isnan(np.sum(hist_used[sec].values)):
            del hist_used[sec]
    minvarport = zip(hist_used.keys().values, minvar(hist_used.values))

    #print minvarport
    for sec, weight in minvarport:
        target=weight*(context.portfolio.portfolio_value)
        order_target_value(sec, target)
        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-weight', weight)
        

        
def minvar(prices):
    cov = np.cov((prices[1:] / prices[:-1] - 1).transpose())
    vu = np.array(cov.shape[1] * [1], float)
    num = np.dot(np.linalg.inv(cov), vu)
    den = np.dot(vu, num)
    return num / den  

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle(data_name+'.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  264 2002-01-24 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  286 2002-02-26 00:00:00+00:00 Pos Value:  101552.4632 PnL:  1212.44050732
# Bars Completed:
#  308 2002-03-28 00:00:00+00:00 Pos Value:  106640.4431 PnL:  6644.9105949
# Bars Completed:
#  330 2002-04-30 00:00:00+00:00 Pos Value:  107286.75 PnL:  7154.36122976
# Bars Completed:
#  352 2002-05-31 00:00:00+00:00 Pos Value:  109406.4558 PnL:  9326.07098271
# Bars Completed:
#  374 2002-07-02 00:00:00+00:00 Pos Value:  104490.6104 PnL:  5787.90577293
# Bars Completed:
#  396 2002-08-02 00:00:00+00:00 Pos Value:  98003.805 PnL:  -1867.21004132
# Bars Completed:
#  418 2002-09-04 00:00:00+00:00 Pos Value:  99938.1428 PnL:  -455.242341101
# Bars Completed:
#  440 2002-10-04 00:00:00+00:00 Pos Value:  93861.3459 PnL:  -6268.98991733
# Bars Completed:
#  462 2002-11-05 00:00:00+00:00 Pos Value:  94012.984 PnL:  -6741.74079667
# Bars Completed:
#  484 2002-12-06 00:00:00+00:00 Pos Value:  94816.413 PnL:  -5289.13819801
# Bars Completed:
#  506 2003-01-09 00:00:00+00:00 Pos Value:  97451.3343 PnL:  -2504.96219804
# Bars Completed:
#  528 2003-02-11 00:00:00+00:00 Pos Value:  94549.7713 PnL:  -5448.07497749
# Bars Completed:
#  550 2003-03-14 00:00:00+00:00 Pos Value:  95871.2392 PnL:  -4134.52862047
# Bars Completed:
#  572 2003-04-15 00:00:00+00:00 Pos Value:  99419.3582 PnL:  -538.283529308
# Bars Completed:
#  594 2003-05-16 00:00:00+00:00 Pos Value:  104347.7925 PnL:  4403.06311739
# Bars Completed:
#  616 2003-06-18 00:00:00+00:00 Pos Value:  108096.4967 PnL:  8129.19683977
# Bars Completed:
#  638 2003-07-21 00:00:00+00:00 Pos Value:  110432.7775 PnL:  10419.0706309
# Bars Completed:
#  660 2003-08-20 00:00:00+00:00 Pos Value:  114265.1836 PnL:  14276.8154125
# Bars Completed:
#  682 2003-09-22 00:00:00+00:00 Pos Value:  117542.5588 PnL:  17753.3085086
# Bars Completed:
#  704 2003-10-22 00:00:00+00:00 Pos Value:  119278.7032 PnL:  19259.2292928
# Bars Completed:
#  726 2003-11-21 00:00:00+00:00 Pos Value:  120080.394 PnL:  20148.2598443
# Bars Completed:
#  748 2003-12-24 00:00:00+00:00 Pos Value:  122333.4097 PnL:  22400.2121706
# Bars Completed:
#  770 2004-01-28 00:00:00+00:00 Pos Value:  124748.7204 PnL:  24775.0595603
# Bars Completed:
#  792 2004-03-01 00:00:00+00:00 Pos Value:  127635.4513 PnL:  27695.9265761
# Bars Completed:
#  814 2004-03-31 00:00:00+00:00 Pos Value:  128919.4737 PnL:  28996.5910753
# Bars Completed:
#  836 2004-05-03 00:00:00+00:00 Pos Value:  123112.1935 PnL:  23075.5969493
# Bars Completed:
#  858 2004-06-03 00:00:00+00:00 Pos Value:  121791.6664 PnL:  21910.8130689
# Bars Completed:
#  880
# 2004-07-07 00:00:00+00:00 Pos Value:  123038.0156 PnL:  23013.9861263
# Bars Completed:
#  902 2004-08-06 00:00:00+00:00 Pos Value:  123121.6965 PnL:  23154.3123466
# Bars Completed:
#  924 2004-09-08 00:00:00+00:00 Pos Value:  126273.9584 PnL:  26232.7677167
# Bars Completed:
#  946 2004-10-08 00:00:00+00:00 Pos Value:  125273.3446 PnL:  25456.2565634
# Bars Completed:
#  968 2004-11-09 00:00:00+00:00 Pos Value:  126429.6198 PnL:  26207.3182947
# Bars Completed:
#  990 2004-12-10 00:00:00+00:00 Pos Value:  126493.8936 PnL:  26553.6332702
# Bars Completed:
#  1012 2005-01-12 00:00:00+00:00 Pos Value:  125834.8805 PnL:  25967.0627995
# Bars Completed:
#  1034 2005-02-14 00:00:00+00:00 Pos Value:  125053.6781 PnL:  25006.5647767
# Bars Completed:
#  1056 2005-03-17 00:00:00+00:00 Pos Value:  123615.0955 PnL:  23579.0849397
# Bars Completed:
#  1078 2005-04-19 00:00:00+00:00 Pos Value:  123761.6766 PnL:  23612.4129531
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  123778.3869 PnL:  23896.1996097
# Bars Completed:
#  1122 2005-06-21 00:00:00+00:00 Pos Value:  124675.2689 PnL:  24742.0853936
# Bars Completed:
#  1144 2005-07-22 00:00:00+00:00 Pos Value:  125129.1858 PnL:  25056.7775721
# Bars Completed:
#  1166 2005-08-23 00:00:00+00:00 Pos Value:  125179.158 PnL:  25307.1960223
# Bars Completed:
#  1188 2005-09-23 00:00:00+00:00 Pos Value:  125839.4293 PnL:  25755.2327629
# Bars Completed:

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    (4*perf.portfolio_value-300000).plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 100000.0/data['SPY']['price'][66]*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-weight']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(14)]]
