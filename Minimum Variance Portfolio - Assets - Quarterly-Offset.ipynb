# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['TLT','SPY','QQQ', 'LQD', 'AGG', 'GLD', 'IWM', 'DIA','JNK','IYR','XOP', 'EWA','EWZ','EWJ','EWY','EEM','EWW','EZU','TUR','EWH','EWI','EWP','EWU','EWC']
fields=['CALL_IMP_VOL_30D','CALL_IMP_VOL_60D','CALL_IMP_VOL_90D']

algo_name = "Minimum Variance Portfolio - Assets"
data_name = 'bbg_assets_etf_data-12yr'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, start=startdate, end=enddate)
print data
data.to_pickle(data_name+'.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'TLT EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'SPY EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'QQQ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'LQD EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'AGG EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'GLD EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IWM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'DIA EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'JNK EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYR EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'XOP EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWA EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWY EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EEM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EZU EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'TUR EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWI EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWP EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWU EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'EWC EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 24 (items) x 3480 (major_axis) x 9 (minor_axis)
# Items axis: TLT to EWC
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to CALL_IMP_VOL_90D

# %%
import pandas as pd
data = pd.read_pickle(data_name+'.pickle')
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
# Out:
# C:\Python27\lib\site-packages\matplotlib\pyplot.py:423: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

# Define algorithm
def initialize(context):                  
    # Register 3 histories that maintain windows of trailing data
    context.windows = [253]
    
    for t in context.windows:
        add_history(t, '1d', 'price')
        
    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.002))

def handle_data(context, data):
    # Skip first 60 days to get full windows
    context.i += 1
    if context.i < context.windows[-1] or (context.i % 22 != 0):
        return
    
    # Progess report
    if context.i % 1 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    hist_used = history(context.windows[-1], '1d', 'price')
    for sec in hist_used.keys().values:
        if np.isnan(np.sum(hist_used[sec].values)):
            del hist_used[sec]
    minvarport = zip(hist_used.keys().values, minvar(hist_used.values))

    #print minvarport
    for sec, weight in minvarport:
        target=weight*(context.portfolio.portfolio_value)
        order_target_value(sec, target)
        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-weight', weight)
        

        
def minvar(prices):
    cov = np.cov((prices[1:] / prices[:-1] - 1).transpose())
    vu = np.array(cov.shape[1] * [1], float)
    num = np.dot(np.linalg.inv(cov), vu)
    den = np.dot(vu, num)
    return num / den  

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle(data_name+'.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  264 2002-01-24 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  286 2002-02-26 00:00:00+00:00 Pos Value:  101557.3695 PnL:  1217.17301303
# Bars Completed:
#  308 2002-03-28 00:00:00+00:00 Pos Value:  106622.7658 PnL:  6648.48103249
# Bars Completed:
#  330 2002-04-30 00:00:00+00:00 Pos Value:  107209.3021 PnL:  7162.83758318
# Bars Completed:
#  352 2002-05-31 00:00:00+00:00 Pos Value:  109361.4698 PnL:  9336.35279151
# Bars Completed:
#  374 2002-07-02 00:00:00+00:00 Pos Value:  104490.3001 PnL:  5799.59490368
# Bars Completed:
#  396 2002-08-02 00:00:00+00:00 Pos Value:  98027.6385 PnL:  -1858.3414219
# Bars Completed:
#  418 2002-09-04 00:00:00+00:00 Pos Value:  99927.9639 PnL:  -448.782701604
# Bars Completed:
#  440 2002-10-04 00:00:00+00:00 Pos Value:  93906.4749 PnL:  -6265.8232084
# Bars Completed:
#  462 2002-11-05 00:00:00+00:00 Pos Value:  94056.682 PnL:  -6733.94077807
# Bars Completed:
#  484 2002-12-06 00:00:00+00:00 Pos Value:  94872.1225 PnL:  -5280.80802492
# Bars Completed:
#  506 2003-01-09 00:00:00+00:00 Pos Value:  97537.9868 PnL:  -2495.42464907
# Bars Completed:
#  528 2003-02-11 00:00:00+00:00 Pos Value:  94567.7541 PnL:  -5440.52928274
# Bars Completed:
#  550 2003-03-14 00:00:00+00:00 Pos Value:  95900.6135 PnL:  -4127.30671005
# Bars Completed:
#  572 2003-04-15 00:00:00+00:00 Pos Value:  99368.7045 PnL:  -532.987363979
# Bars Completed:
#  594 2003-05-16 00:00:00+00:00 Pos Value:  104351.196 PnL:  4409.29698652
# Bars Completed:
#  616 2003-06-18 00:00:00+00:00 Pos Value:  108051.5295 PnL:  8131.03188934
# Bars Completed:
#  638 2003-07-21 00:00:00+00:00 Pos Value:  110333.1726 PnL:  10421.5418545
# Bars Completed:
#  660 2003-08-20 00:00:00+00:00 Pos Value:  114288.1338 PnL:  14278.6745477
# Bars Completed:
#  682 2003-09-22 00:00:00+00:00 Pos Value:  117521.25 PnL:  17756.4779635
# Bars Completed:
#  704 2003-10-22 00:00:00+00:00 Pos Value:  119302.691 PnL:  19261.5792716
# Bars Completed:
#  726 2003-11-21 00:00:00+00:00 Pos Value:  120179.3716 PnL:  20151.4762873
# Bars Completed:
#  748 2003-12-24 00:00:00+00:00 Pos Value:  122297.5962 PnL:  22403.1991685
# Bars Completed:
#  770 2004-01-28 00:00:00+00:00 Pos Value:  124813.5605 PnL:  24777.6886097
# Bars Completed:
#  792 2004-03-01 00:00:00+00:00 Pos Value:  127651.1186 PnL:  27699.5785018
# Bars Completed:
#  814 2004-03-31 00:00:00+00:00 Pos Value:  129048.4723 PnL:  28997.9282858
# Bars Completed:
#  836 2004-05-03 00:00:00+00:00 Pos Value:  123151.3467 PnL:  23076.0481603
# Bars Completed:
#  858 2004-06-03 00:00:00+00:00 Pos Value:  121732.8688 PnL:  21911.6530485
# Bars Completed:
#  880 2004-07-07 00:00:00+00:00 Pos Value:  123016.1449 PnL:  23014.4233496
# Bars Completed:
#  902 2004-08-06 00:00:00+00:00 Pos Value:  123121.8415 PnL:  23151.0802987
# Bars Completed:
#  924 2004-09-08 00:00:00+00:00 Pos Value:  126293.7773 PnL:  26227.5185876
# Bars Completed:
#  946 2004-10-08 00:00:00+00:00 Pos Value:  125350.3378 PnL:  25449.777077
# Bars Completed:
#  968 2004-11-09 00:00:00+00:00 Pos Value:  126392.922 PnL:  26200.1162419
# Bars Completed:
#  990 2004-12-10 00:00:00+00:00 Pos Value:  126613.4343 PnL:  26548.8605914
# Bars Completed:
#  1012 2005-01-12 00:00:00+00:00 Pos Value:  125893.5275 PnL:  25960.9561421
# Bars Completed:
#  1034 2005-02-14 00:00:00+00:00 Pos Value:  125010.4289 PnL:  25000.1135939
# Bars Completed:
#  1056 2005-03-17 00:00:00+00:00 Pos Value:  123552.7274 PnL:  23573.2611914
# Bars Completed:
#  1078 2005-04-19 00:00:00+00:00 Pos Value:  123690.7825 PnL:  23609.8497091
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  123885.4304 PnL:  23895.1166722
# Bars Completed:
#  1122 2005-06-21 00:00:00+00:00 Pos Value:  124537.0017 PnL:  24737.7213896
# Bars Completed:
#  1144 2005-07-22 00:00:00+00:00 Pos Value:  124963.6993 PnL:  25049.4795462
# Bars Completed:
#  1166 2005-08-23 00:00:00+00:00 Pos Value:  125118.1568 PnL:  25297.8397746
# Bars Completed:
#  1188 2005-09-23 00:00:00+00:00 Pos Value:  125699.6925 PnL:  25745.6935186
# Bars Completed:
#  1210 2005-10-25 00:00:00+00:00 Pos Value:  124956.3935 PnL:  24972.1134382
# Bars Completed:
#  1232 2005-11-25 00:00:00+00:00 Pos Value:  126119.6127 PnL:  26091.7225858
# Bars Completed:
#  1254 2005-12-28 00:00:00+00:00 Pos Value:  126016.3991 PnL:  25998.9965059
# Bars Completed:
#  1276 2006-01-31 00:00:00+00:00 Pos Value:  126352.8989 PnL:  26333.0699565
# Bars Completed:
#  1298 2006-03-03 00:00:00+00:00 Pos Value:  126195.8459 PnL:  26133.3083081
# Bars Completed:
#  1320 2006-04-04 00:00:00+00:00 Pos Value:  126957.8586 PnL:  26761.68525
# Bars Completed:
#  1342 2006-05-05 00:00:00+00:00 Pos Value:  128411.9943 PnL:  28281.6791383
# Bars Completed:
#  1364 2006-06-07 00:00:00+00:00 Pos Value:  127316.9924 PnL:  27271.0042886
# Bars Completed:
#  1386 2006-07-10 00:00:00+00:00 Pos Value:  126969.6013 PnL:  26881.8216924
# Bars Completed:
#  1408 2006-08-09 00:00:00+00:00 Pos Value:  128587.155 PnL:  28684.9994355
# Bars Completed:
#  1430 2006-09-11 00:00:00+00:00 Pos Value:  129821.9459 PnL:  29774.5472093
# Bars Completed:
#  1452 2006-10-11 00:00:00+00:00 Pos Value:  129876.89 PnL:  29945.3424009
# Bars Completed:
#  1474 2006-11-10 00:00:00+00:00 Pos Value:  131708.625 PnL:  31537.5775466
# Bars Completed:
#  1496 2006-12-13 00:00:00+00:00 Pos Value:  132017.0862 PnL:  32073.1901861
# Bars Completed:
#  1518 2007-01-18 00:00:00+00:00 Pos Value:  133052.5417 PnL:  33063.4202391
# Bars Completed:
#  1540 2007-02-20 00:00:00+00:00 Pos Value:  134156.2838 PnL:  33991.0154143
# Bars Completed:
#  1562 2007-03-22 00:00:00+00:00 Pos Value:  134061.7268 PnL:  34083.4428898
# Bars Completed:
#  1584 2007-04-24 00:00:00+00:00 Pos Value:  135164.8669 PnL:  35049.6653711
# Bars Completed:
#  1606 2007-05-24 00:00:00+00:00 Pos Value:  135922.9832 PnL:  35956.1699064
# Bars Completed:
#  1628 2007-06-26 00:00:00+00:00 Pos Value:  134633.8456 PnL:  34606.6620013
# Bars Completed:
#  1650 2007-07-27 00:00:00+00:00 Pos Value:  134046.7065 PnL:  34126.0841616
# Bars Completed:
#  1672 2007-08-28 00:00:00+00:00 Pos Value:  135740.8063 PnL:  35911.9774299
# Bars Completed:
#  1694 2007-09-28 00:00:00+00:00 Pos Value:  137045.2948 PnL:  36988.3779714
# Bars Completed:
#  1716 2007-10-30 00:00:00+00:00 Pos Value:  137457.5932 PnL:  37473.6358317
# Bars Completed:
#  1738 2007-11-30 00:00:00+00:00 Pos Value:  137718.5261 PnL:  37722.7227576
# Bars Completed:
#  1760 2008-01-03 00:00:00+00:00 Pos Value:  138614.8264 PnL:  38521.8552688
# Bars Completed:
#  1782 2008-02-05 00:00:00+00:00 Pos Value:  140020.1541 PnL:  40198.5904429
# Bars Completed:
#  1804 2008-03-07 00:00:00+00:00 Pos Value:  138196.7322 PnL:  38212.7346206
# Bars Completed:
#  1826 2008-04-09 00:00:00+00:00 Pos Value:  139984.8384 PnL:  40218.4495992
# Bars Completed:
#  1848 2008-05-09 00:00:00+00:00 Pos Value:  140048.8779 PnL:  40222.6314892
# Bars Completed:
#  1870 2008-06-11 00:00:00+00:00 Pos Value:  137547.7093 PnL:  37385.8909474
# Bars Completed:
#  1892 2008-07-14 00:00:00+00:00 Pos Value:  136355.789 PnL:  36050.803245
# Bars Completed:
#  1914 2008-08-13 00:00:00+00:00 Pos Value:  137427.121 PnL:  37583.6798124
# Bars Completed:
#  1936 2008-09-15 00:00:00+00:00 Pos Value:  138080.7559 PnL:  37982.7175672
# Bars Completed:
#  1958 2008-10-15 00:00:00+00:00 Pos Value:  126436.0137 PnL:  26343.1592941
# Bars Completed:
#  1980 2008-11-14 00:00:00+00:00 Pos Value:  122728.4086 PnL:  21996.0275776
# Bars Completed:
#  2002 2008-12-17 00:00:00+00:00 Pos Value:  138284.4855 PnL:  38127.3015636
# Bars Completed:
#  2024 2009-01-21 00:00:00+00:00 Pos Value:  136934.5304 PnL:  36911.0360864
# Bars Completed:
#  2046 2009-02-23 00:00:00+00:00 Pos Value:  137719.3331 PnL:  37703.1073347
# Bars Completed:
#  2068 2009-03-25 00:00:00+00:00 Pos Value:  133565.109 PnL:  33430.8589169
# Bars Completed:
#  2090 2009-04-27 00:00:00+00:00 Pos Value:  136636.7084 PnL:  36836.4664785
# Bars Completed:
#  2112 2009-05-28 00:00:00+00:00 Pos Value:  133598.3307 PnL:  33778.0145715
# Bars Completed:
#  2134 2009-06-29 00:00:00+00:00 Pos Value:  137370.0936 PnL:  37281.6622489
# Bars Completed:
#  2156 2009-07-30 00:00:00+00:00 Pos Value:  140425.4458 PnL:  40507.4884557
# Bars Completed:
#  2178 2009-08-31 00:00:00+00:00 Pos Value:  141539.7302 PnL:  41589.1311525
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  145102.7418 PnL:  45144.8616521
# Bars Completed:
#  2222 2009-11-02 00:00:00+00:00 Pos Value:  145337.49 PnL:  45338.8276876
# Bars Completed:
#  2244 2009-12-03 00:00:00+00:00 Pos Value:  150235.7181 PnL:  50372.4053553
# Bars Completed:
#  2266 2010-01-06 00:00:00+00:00 Pos Value:  149360.3588 PnL:  49090.0462446
# Bars Completed:
#  2288 2010-02-08 00:00:00+00:00 Pos Value:  150723.9129 PnL:  50562.3438924
# Bars Completed:
#  2310 2010-03-11 00:00:00+00:00 Pos Value:  151952.4551 PnL:  51987.6023378
# Bars Completed:
#  2332 2010-04-13 00:00:00+00:00 Pos Value:  152889.9639 PnL:  52765.793707
# Bars Completed:
#  2354 2010-05-13 00:00:00+00:00 Pos Value:  155239.1802 PnL:  55121.2440678
# Bars Completed:
#  2376 2010-06-15 00:00:00+00:00 Pos Value:  155373.0141 PnL:  55250.5259981
# Bars Completed:
#  2398 2010-07-16 00:00:00+00:00 Pos Value:  156550.7022 PnL:  56787.1278943
# Bars Completed:
#  2420 2010-08-17 00:00:00+00:00 Pos Value:  157885.2345 PnL:  57925.9133737
# Bars Completed:
#  2442 2010-09-17 00:00:00+00:00 Pos Value:  158695.6727 PnL:  58798.6012056
# Bars Completed:
#  2464 2010-10-19 00:00:00+00:00 Pos Value:  159771.9343 PnL:  59901.4546033
# Bars Completed:
#  2486 2010-11-18 00:00:00+00:00 Pos Value:  159792.4921 PnL:  59697.4516951
# Bars Completed:
#  2508 2010-12-21 00:00:00+00:00 Pos Value:  159541.3036 PnL:  59436.4903871
# Bars Completed:
#  2530 2011-01-24 00:00:00+00:00 Pos Value:  160871.1358 PnL:  60780.5065838
# Bars Completed:
#  2552 2011-02-24 00:00:00+00:00 Pos Value:  159879.5923 PnL:  59785.37618
# Bars Completed:
#  2574 2011-03-28 00:00:00+00:00 Pos Value:  159828.3487 PnL:  59583.3934777
# Bars Completed:
#  2596 2011-04-28 00:00:00+00:00 Pos Value:  161378.764 PnL:  61369.7179709
# Bars Completed:
#  2618 2011-05-31 00:00:00+00:00 Pos Value:  162842.3245 PnL:  63041.7913674
# Bars Completed:
#  2640 2011-06-30 00:00:00+00:00 Pos Value:  162677.0248 PnL:  62791.4609186
# Bars Completed:
#  2662 2011-08-02 00:00:00+00:00 Pos Value:  164094.4801 PnL:  64001.0038365
# Bars Completed:
#  2684 2011-09-01 00:00:00+00:00 Pos Value:  164286.2627 PnL:  64180.441636
# Bars Completed:
#  2706 2011-10-04 00:00:00+00:00 Pos Value:  161384.1675 PnL:  61294.6048295
# Bars Completed:
#  2728 2011-11-03 00:00:00+00:00 Pos Value:  161858.8875 PnL:  61921.0557251
# Bars Completed:
#  2750 2011-12-06 00:00:00+00:00 Pos Value:  162761.8862 PnL:  62923.7065124
# Bars Completed:
#  2772 2012-01-09 00:00:00+00:00 Pos Value:  164356.4502 PnL:  64049.5755693
# Bars Completed:
#  2794 2012-02-09 00:00:00+00:00 Pos Value:  164539.1078 PnL:  64395.8126519
# Bars Completed:
#  2816 2012-03-13 00:00:00+00:00 Pos Value:  165128.3608 PnL:  64867.6913391
# Bars Completed:
#  2838 2012-04-13 00:00:00+00:00 Pos Value:  165297.4828 PnL:  65176.3337369
# Bars Completed:
#  2860 2012-05-15 00:00:00+00:00 Pos Value:  165365.2617 PnL:  65193.4381358
# Bars Completed:
#  2882 2012-06-15 00:00:00+00:00 Pos Value:  165708.2109 PnL:  65798.5206351
# Bars Completed:
#  2904 2012-07-18 00:00:00+00:00 Pos Value:  166589.5718 PnL:  66595.6337323
# Bars Completed:
#  2926 2012-08-17 00:00:00+00:00 Pos Value:  166772.9817 PnL:  66642.7910712
# Bars Completed:
#  2948 2012-09-19 00:00:00+00:00 Pos Value:  168169.1685 PnL:  68222.3334823
# Bars Completed:
#  2970 2012-10-19 00:00:00+00:00 Pos Value:  168535.46 PnL:  68372.1817756
# Bars Completed:
#  2992 2012-11-23 00:00:00+00:00 Pos Value:  168590.1436 PnL:  68649.2746535
# Bars Completed:
#  3014 2012-12-26 00:00:00+00:00 Pos Value:  168741.8849 PnL:  68984.3688414
# Bars Completed:
#  3036 2013-01-29 00:00:00+00:00 Pos Value:  168793.6073 PnL:  68832.3719407
# Bars Completed:
#  3058 2013-03-01 00:00:00+00:00 Pos Value:  169739.8435 PnL:  69634.7921388
# Bars Completed:
#  3080 2013-04-03 00:00:00+00:00 Pos Value:  170419.5661 PnL:  70152.9896355
# Bars Completed:
#  3102 2013-05-03 00:00:00+00:00 Pos Value:  170656.1412 PnL:  70585.406632
# Bars Completed:
#  3124 2013-06-05 00:00:00+00:00 Pos Value:  168391.0747 PnL:  68068.8841296
# Bars Completed:
#  3146 2013-07-08 00:00:00+00:00 Pos Value:  166997.1424 PnL:  67086.8221267
# Bars Completed:
#  3168 2013-08-07 00:00:00+00:00 Pos Value:  168335.321 PnL:  68307.3467727
# Bars Completed:
#  3190 2013-09-09 00:00:00+00:00 Pos Value:  166282.5239 PnL:  66485.2686694
# Bars Completed:
#  3212 2013-10-09 00:00:00+00:00 Pos Value:  168811.3174 PnL:  68511.5195665
# Bars Completed:
#  3234 2013-11-08 00:00:00+00:00 Pos Value:  170131.7738 PnL:  70182.6453637
# Bars Completed:
#  3256 2013-12-11 00:00:00+00:00 Pos Value:  170707.6551 PnL:  70902.7361588
# Bars Completed:
#  3278 2014-01-14 00:00:00+00:00 Pos Value:  171344.9849 PnL:  71173.4175561
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  172077.6725 PnL:  71987.0273558
# Bars Completed:
#  3322 2014-03-19 00:00:00+00:00 Pos Value:  172393.1058 PnL:  72482.8670239
# Bars Completed:
#  3344 2014-04-21 00:00:00+00:00 Pos Value:  172017.863 PnL:  71855.6981219
# Bars Completed:
#  3366 2014-05-21 00:00:00+00:00 Pos Value:  172763.9259 PnL:  72994.5232213
# Bars Completed:
#  3388 2014-06-23 00:00:00+00:00 Pos Value:  172770.1624 PnL:  72961.4195093
# Bars Completed:
#  3410 2014-07-24 00:00:00+00:00 Pos Value:  172908.4205 PnL:  72795.6796484
# Bars Completed:
#  3432 2014-08-25 00:00:00+00:00 Pos Value:  173497.4705 PnL:  73659.944738
# Bars Completed:
#  3454 2014-09-25 00:00:00+00:00 Pos Value:  173174.2808 PnL:  73563.1907273
# Bars Completed:
# [2014-11-21 16:00] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-21 16:00] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-21 16:00] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3476 2014-10-27 00:00:00+00:00 Pos Value:  174872.2237 PnL:  74933.3874261

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    (4*perf.portfolio_value-300000).plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 100000.0/data['SPY']['price'][66]*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-weight']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  441.694

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(14)]]
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.017956                 0.032899  0.030061
# 2013-10              0.023128                 0.004773 -0.006690
# 2012-10              0.017683                 0.041555  0.037151
# 2011-10              0.030548                 0.009445  0.005713
# 2010-10              0.029651                 0.102008  0.094957
# 2009-10              0.086041                 0.176878  0.170632
# 2008-10              0.111189                -0.100013 -0.064395
# 2007-10              0.028481                 0.047570  0.005767
# 2006-10              0.026272                 0.053913 -0.003682
# 2005-10              0.027129                -0.007333 -0.052335
# 2004-10              0.056401                 0.051705  0.018926
# 2003-10              0.097157                 0.294885  0.243263
# 2002-10              0.136754                -0.079115 -0.035169
# 2014-09              0.017535                 0.032112  0.029883
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.011863
# 2013-10                      0.243868              0.117836  0.043082
# 2012-10                      0.126753              0.153977  0.020806
# 2011-10                      0.059192              0.215031  0.043674
# 2010-10                      0.141933              0.181490  0.034717
# 2009-10                      0.069615              0.358120  0.038625
# 2008-10                     -0.374750              0.346362  0.126368
# 2007-10                      0.124418              0.135401  0.016702
# 2006-10                      0.141614              0.100152  0.083903
# 2005-10                      0.067961              0.105708  0.076512
# 2004-10                      0.075654              0.112001  0.187834
# 2003-10                      0.186224              0.185829  0.222513
# 2002-10                     -0.164204              0.254499  0.327433
# 2014-09                      0.172900              0.102981  0.005412
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.031799    -0.063515      0.008337  1.770921  3.093426
# 2013-10            0.003773    -0.120633      0.028957  0.163133  0.202701
# 2012-10            0.039750    -0.037547      0.006834  2.247970  3.715724
# 2011-10            0.008245    -0.021435      0.022063  0.269921  0.395607
# 2010-10            0.099808    -0.018337      0.017370  3.366064  4.176579
# 2009-10            0.173178     0.006271      0.073100  2.012727  3.284510
# 2008-10           -0.113449     0.061107      0.164397 -1.020330 -1.044397
# 2007-10            0.007170    -0.036894      0.014969  0.251750  0.355466
# 2006-10            0.004013    -0.056065      0.017693  0.152767  0.233592
# 2005-10           -0.050433    -0.048752      0.030455 -1.859039 -3.017528
# 2004-10            0.028842    -0.016382      0.078823  0.511375  0.663781
# 2003-10            0.281785     0.028027      0.046320  2.900292  4.646974
# 2002-10           -0.093715     0.023033      0.197763 -0.685283 -0.888400
# 2014-09            0.030812    -0.080663      0.008337  1.757127  3.130311
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
# 2014-09                252                0.001300
