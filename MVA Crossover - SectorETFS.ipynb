# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.utils.factory import load_bars_from_yahoo

# Load data manually from Yahoo! finance
start = datetime(2005, 1, 1, 0, 0, 0, 0, pytz.utc)
end = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
data = load_bars_from_yahoo(stocks=secs, start=start,
                            end=end)
print data
for sym in data.items:
    data[sym].ix[:,:-2].plot(title=sym, figsize=(15, 3))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# IYE
# IYW
# IYH
# IYF
# IYJ
# IYZ
# IYC
# IYM
# IYK
# <class 'pandas.core.panel.Panel'>
# Dimensions: 9 (items) x 2476 (major_axis) x 6 (minor_axis)
# Items axis: IYE to IYK
# Major_axis axis: 2005-01-03 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target, record, symbol, history, add_history
import numpy as np

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    add_history(10, '1d', 'price')
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
        
    

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, 'Data: ', data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    xshort_mavg = history(10, '1d', 'price').mean()
    short_mavg = history(50, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0
        if short_mavg[sec] > long_mavg[sec]:
            target += 50
        if short_mavg[sec] > med_mavg[sec]:
            target += 20
        if med_mavg[sec] > long_mavg[sec]:
            target += 100
        if short_mavg[sec] < med_mavg[sec]:
            target -= 20
        if short_mavg[sec] < long_mavg[sec]:
            target -= 50
            
        if xshort_mavg[sec] > short_mavg[sec]:
            target += 10
        if xshort_mavg[sec] < short_mavg[sec]:
            target -= 10
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-xs_ma', xshort_mavg[sec])
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
perf_manual = algo_obj.run(data)
perf_manual.to_pickle('tutorial_perf.pickle')
# Out:
# Bars Completed:  200 Data:  2005-10-17 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 Data:  2006-03-13 00:00:00+00:00 Pos Value:  77598.8 PnL:  4752.57403216
# Bars Completed:
#  400 Data:  2006-08-03 00:00:00+00:00 Pos Value:  32177.6 PnL:  3638.56383623
# Bars Completed:
#  500 Data:  2006-12-26 00:00:00+00:00 Pos Value:  87665.4 PnL:  6239.62190481
# Bars Completed:
#  600 Data:  2007-05-22 00:00:00+00:00 Pos Value:  91408.8 PnL:  13396.2194555
# Bars Completed:
#  700 Data:  2007-10-12 00:00:00+00:00 Pos Value:  48266.6 PnL:  13938.9607378
# Bars Completed:
#  800 Data:  2008-03-07 00:00:00+00:00 Pos Value:  -650.2 PnL:  11413.5035954
# Bars Completed:
#  900 Data:  2008-07-30 00:00:00+00:00 Pos Value:  -6673.2 PnL:  11334.0942028
# Bars Completed:
#  1000 Data:  2008-12-19 00:00:00+00:00 Pos Value:  -23798.4 PnL:  15107.2936251
# Bars Completed:
#  1100 Data:  2009-05-15 00:00:00+00:00 Pos Value:  -12467.8 PnL:  14161.49353
# Bars Completed:
#  1200 Data:  2009-10-07 00:00:00+00:00 Pos Value:  70680.6 PnL:  22760.8739998
# Bars Completed:
#  1300 Data:  2010-03-03 00:00:00+00:00 Pos Value:  73321.8 PnL:  27959.2737232
# Bars Completed:
#  1400 Data:  2010-07-26 00:00:00+00:00 Pos Value:  16598.2 PnL:  26125.6459276
# Bars Completed:
#  1500 Data:  2010-12-15 00:00:00+00:00 Pos Value:  81960.2 PnL:  29101.4893295
# Bars Completed:
#  1600 Data:  2011-05-10 00:00:00+00:00 Pos Value:  94304.6 PnL:  38177.6877051
# Bars Completed:
#  1700 Data:  2011-09-30 00:00:00+00:00 Pos Value:  -13794.0 PnL:  29464.8768306
# Bars Completed:
#  1800 Data:  2012-02-24 00:00:00+00:00 Pos Value:  69701.2 PnL:  28187.0765275
# Bars Completed:
#  1900 Data:  2012-07-18 00:00:00+00:00 Pos Value:  67080.4 PnL:  27515.6708041
# Bars Completed:
#  2000 Data:  2012-12-11 00:00:00+00:00 Pos Value:  86988.4 PnL:  30984.8277968
# Bars Completed:
#  2100 Data:  2013-05-07 00:00:00+00:00 Pos Value:  106879.8 PnL:  44689.2262185
# Bars Completed:
#  2200 Data:  2013-09-27 00:00:00+00:00 Pos Value:  124309.8 PnL:  50670.221481
# Bars Completed:
#  2300 Data:  2014-02-21 00:00:00+00:00 Pos Value:  129637.4 PnL:  62277.4202053
# Bars Completed:
# [2014-11-10 16:47] INFO: Performance: Simulated 2476 trading days out of 2476.
# [2014-11-10 16:47] INFO: Performance: first open: 2005-01-03 14:31:00+00:00
# [2014-11-10 16:47] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  2400 Data:  2014-07-16 00:00:00+00:00 Pos Value:  146187.0 PnL:  71592.8060674

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
buys = perf_trans.ix[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
perf.ix[buys.index][0:5]
# Out:
#                        IYC  IYC-l_ma  IYC-m_ma  IYC-s_ma  IYC-xs_ma    IYE  \
# 2005-10-18 20:00:00  51.48  53.85670   54.3289   53.6578     51.908  23.43
# 2005-10-31 21:00:00  52.42  53.74480   54.1413   53.0190     51.968  24.37
# 2005-11-08 21:00:00  53.64  53.72965   54.0707   52.9046     52.783  24.50
# 2005-11-10 21:00:00  54.54  53.73485   54.0539   52.9096     53.339  23.60
# 2005-11-11 21:00:00  54.66  53.74110   54.0500   52.9286     53.637  23.77
#
#                      IYE-l_ma  IYE-m_ma  IYE-s_ma  IYE-xs_ma    ...      \
# 2005-10-18 20:00:00  22.51850   24.2253   25.3420     24.420    ...
# 2005-10-31 21:00:00  22.76815   24.4247   25.1950     23.801    ...
# 2005-11-08 21:00:00  22.94405   24.5492   25.2386     24.467    ...
# 2005-11-10 21:00:00  22.99095   24.5649   25.1936     24.475    ...
# 2005-11-11 21:00:00  23.01400   24.5722   25.1496     24.433    ...
#
#                                                                 orders  \
# 2005-10-18 20:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-10-31 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-11-08 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-11-10 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-11-11 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
#
#                                   period_close                period_open  \
# 2005-10-18 20:00:00  2005-10-18 20:00:00+00:00  2005-10-18 13:31:00+00:00
# 2005-10-31 21:00:00  2005-10-31 21:00:00+00:00  2005-10-31 14:31:00+00:00
# 2005-11-08 21:00:00  2005-11-08 21:00:00+00:00  2005-11-08 14:31:00+00:00
# 2005-11-10 21:00:00  2005-11-10 21:00:00+00:00  2005-11-10 14:31:00+00:00
# 2005-11-11 21:00:00  2005-11-11 21:00:00+00:00  2005-11-11 14:31:00+00:00
#
#                             pnl  portfolio_value  \
# 2005-10-18 20:00:00  -33.281486     99966.718514
# 2005-10-31 21:00:00  290.999998    100760.876772
# 2005-11-08 21:00:00 -111.406599    101235.070093
# 2005-11-10 21:00:00  383.199982    101700.270074
# 2005-11-11 21:00:00  105.999999    101806.270074
#
#                                                              positions  \
# 2005-10-18 20:00:00  [{u'amount': 160, u'last_sale_price': 23.43, u...
# 2005-10-31 21:00:00  [{u'amount': 160, u'last_sale_price': 24.37, u...
# 2005-11-08 21:00:00  [{u'amount': 160, u'last_sale_price': 24.5, u'...
# 2005-11-10 21:00:00  [{u'amount': 160, u'last_sale_price': 23.6, u'...
# 2005-11-11 21:00:00  [{u'amount': 160, u'last_sale_price': 23.77, u...
#
#                       returns  starting_cash  starting_value  \
# 2005-10-18 20:00:00 -0.000333  100000.000000             0.0
# 2005-10-31 21:00:00  0.002896   62653.476774         37816.4
# 2005-11-08 21:00:00 -0.001099   62038.076692         39308.4
# 2005-11-10 21:00:00  0.003782   58204.870093         43112.2
# 2005-11-11 21:00:00  0.001042   57113.470074         44586.8
#
#                                                           transactions
# 2005-10-18 20:00:00  [{u'commission': 4.8, u'amount': 160, u'sid': ...
# 2005-10-31 21:00:00  [{u'commission': 0.6, u'amount': 20, u'sid': u...
# 2005-11-08 21:00:00  [{u'commission': 0.6, u'amount': 20, u'sid': u...
# 2005-11-10 21:00:00  [{u'commission': 0.6, u'amount': 20, u'sid': u...
# 2005-11-11 21:00:00  [{u'commission': 0.6, u'amount': 20, u'sid': u...
#
# [5 rows x 58 columns]

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)

    ax1.set_ylabel('portfolio value vs cash balance')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-xs_ma', sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]
        #print [(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]
        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]
        #sells = perf_trans.ix[[t[0]['amount'] < 0 for t in perf_trans.transactions]]
        ax2.plot(buys.index, perf[sec].ix[buys.index],
                 '^', markersize=10, color='g')
        ax2.plot(sells.index, perf[sec].ix[sells.index],
                 'v', markersize=10, color='r')
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze('tutorial_perf.pickle', 0)
