# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.utils.factory import load_bars_from_yahoo

# Load data manually from Yahoo! finance
start = datetime(2005, 1, 1, 0, 0, 0, 0, pytz.utc)
end = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
data = load_bars_from_yahoo(stocks=secs, start=start,
                            end=end)
print data
for sym in data.items:
    data[sym].ix[:,:-2].plot(title=sym, figsize=(15, 3))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# IYE
# IYW
# IYH
# IYF
# IYJ
# IYZ
# IYC
# IYM
# IYK
# <class 'pandas.core.panel.Panel'>
# Dimensions: 9 (items) x 2476 (major_axis) x 6 (minor_axis)
# Items axis: IYE to IYK
# Major_axis axis: 2005-01-03 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to price
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target, record, symbol, history, add_history
import numpy as np

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    add_history(50, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
        
    

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, 'Data: ', data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(50, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        # Trading logic
        target = 0
        if short_mavg[sec] > long_mavg[sec]:
            # order_target orders as many shares as needed to
            # achieve the desired number of shares.
            target += 50
        if short_mavg[sec] > med_mavg[sec]:
            target += 20
        if med_mavg[sec] > long_mavg[sec]:
            target += 100
        if short_mavg[sec] < med_mavg[sec]:
            target -= 20
        if short_mavg[sec] < long_mavg[sec]:
            target -= 50
            
        order_target(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
perf_manual = algo_obj.run(data)
perf_manual.to_pickle('tutorial_perf.pickle')
# Out:
# Bars Completed:  200 Data:  2005-10-17 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 Data:  2006-03-13 00:00:00+00:00 Pos Value:  74687.8 PnL:  4773.02265778
# Bars Completed:
#  400 Data:  2006-08-03 00:00:00+00:00 Pos Value:  31704.1 PnL:  3651.11400188
# Bars Completed:
#  500 Data:  2006-12-26 00:00:00+00:00 Pos Value:  82795.1 PnL:  5876.37323767
# Bars Completed:
#  600 Data:  2007-05-22 00:00:00+00:00 Pos Value:  86098.2 PnL:  13003.8717982
# Bars Completed:
#  700 Data:  2007-10-12 00:00:00+00:00 Pos Value:  42774.7 PnL:  13496.5140809
# Bars Completed:
#  800 Data:  2008-03-07 00:00:00+00:00 Pos Value:  1882.1 PnL:  11245.8570725
# Bars Completed:
#  900 Data:  2008-07-30 00:00:00+00:00 Pos Value:  -3176.4 PnL:  11213.5487338
# Bars Completed:
#  1000 Data:  2008-12-19 00:00:00+00:00 Pos Value:  -21743.4 PnL:  13963.5482185
# Bars Completed:
#  1100 Data:  2009-05-15 00:00:00+00:00 Pos Value:  -15679.5 PnL:  13027.848176
# Bars Completed:
#  1200 Data:  2009-10-07 00:00:00+00:00 Pos Value:  66753.9 PnL:  21200.2286514
# Bars Completed:
#  1300 Data:  2010-03-03 00:00:00+00:00 Pos Value:  71086.8 PnL:  26669.9286443
# Bars Completed:
#  1400 Data:  2010-07-26 00:00:00+00:00 Pos Value:  17217.7 PnL:  24579.4010903
# Bars Completed:
#  1500 Data:  2010-12-15 00:00:00+00:00 Pos Value:  77115.3 PnL:  27437.6449195
# Bars Completed:
#  1600 Data:  2011-05-10 00:00:00+00:00 Pos Value:  88918.9 PnL:  36288.444853
# Bars Completed:
#  1700 Data:  2011-09-30 00:00:00+00:00 Pos Value:  -10545.1 PnL:  27950.2343709
# Bars Completed:
#  1800 Data:  2012-02-24 00:00:00+00:00 Pos Value:  64305.3 PnL:  26929.6353763
# Bars Completed:
#  1900 Data:  2012-07-18 00:00:00+00:00 Pos Value:  63084.4 PnL:  26015.1311979
# Bars Completed:
#  2000 Data:  2012-12-11 00:00:00+00:00 Pos Value:  86918.7 PnL:  29334.9905688
# Bars Completed:
#  2100 Data:  2013-05-07 00:00:00+00:00 Pos Value:  100378.2 PnL:  42556.2890976
# Bars Completed:
#  2200 Data:  2013-09-27 00:00:00+00:00 Pos Value:  117403.7 PnL:  49237.588554
# Bars Completed:
#  2300 Data:  2014-02-21 00:00:00+00:00 Pos Value:  128967.1 PnL:  60800.988554
# Bars Completed:
# [2014-11-07 20:18] INFO: Performance: Simulated 2476 trading days out of 2476.
# [2014-11-07 20:18] INFO: Performance: first open: 2005-01-03 14:31:00+00:00
# [2014-11-07 20:18] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  2400 Data:  2014-07-16 00:00:00+00:00 Pos Value:  138065.5 PnL:  69736.1747435

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
buys = perf_trans.ix[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
perf.ix[buys.index][0:5]
# Out:
#                        IYC  IYC-l_ma  IYC-m_ma  IYC-s_ma    IYE  IYE-l_ma  \
# 2005-10-18 20:00:00  51.48  53.85670   54.3289   53.6578  23.43  22.51850
# 2005-11-08 21:00:00  53.64  53.72965   54.0707   52.9046  24.50  22.94405
# 2005-11-18 21:00:00  54.96  53.75165   54.0739   52.9392  24.56  23.12400
# 2005-12-02 21:00:00  55.47  53.79965   54.1406   53.2872  25.55  23.32470
# 2005-12-05 21:00:00  55.17  53.80490   54.1373   53.3384  25.70  23.34485
#
#                      IYE-m_ma  IYE-s_ma    IYF  IYF-l_ma    ...     \
# 2005-10-18 20:00:00   24.2253   25.3420  77.67  78.35435    ...
# 2005-11-08 21:00:00   24.5492   25.2386  82.35  78.51515    ...
# 2005-11-18 21:00:00   24.6397   24.9984  85.10  78.74175    ...
# 2005-12-02 21:00:00   24.7993   24.8020  86.18  79.02830    ...
# 2005-12-05 21:00:00   24.8252   24.7904  85.99  79.06530    ...
#
#                                                                 orders  \
# 2005-10-18 20:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-11-08 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-11-18 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-12-02 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
# 2005-12-05 21:00:00  [{u'status': 1, u'limit_reached': False, u'cre...
#
#                                   period_close                period_open  \
# 2005-10-18 20:00:00  2005-10-18 20:00:00+00:00  2005-10-18 13:31:00+00:00
# 2005-11-08 21:00:00  2005-11-08 21:00:00+00:00  2005-11-08 14:31:00+00:00
# 2005-11-18 21:00:00  2005-11-18 21:00:00+00:00  2005-11-18 14:31:00+00:00
# 2005-12-02 21:00:00  2005-12-02 21:00:00+00:00  2005-12-02 14:31:00+00:00
# 2005-12-05 21:00:00  2005-12-05 21:00:00+00:00  2005-12-05 14:31:00+00:00
#
#                             pnl  portfolio_value  \
# 2005-10-18 20:00:00  -35.440329     99964.559671
# 2005-11-08 21:00:00 -114.401951    101377.715914
# 2005-11-18 21:00:00  209.499763    102419.415101
# 2005-12-02 21:00:00   63.099861    103007.514949
# 2005-12-05 21:00:00 -121.900087    102885.614862
#
#                                                              positions  \
# 2005-10-18 20:00:00  [{u'amount': 170, u'last_sale_price': 23.43, u...
# 2005-11-08 21:00:00  [{u'amount': 170, u'last_sale_price': 24.5, u'...
# 2005-11-18 21:00:00  [{u'amount': 170, u'last_sale_price': 24.56, u...
# 2005-12-02 21:00:00  [{u'amount': 170, u'last_sale_price': 25.55, u...
# 2005-12-05 21:00:00  [{u'amount': 170, u'last_sale_price': 25.7, u'...
#
#                       returns  starting_cash  starting_value  \
# 2005-10-18 20:00:00 -0.000354  100000.000000             0.0
# 2005-11-08 21:00:00 -0.001127   60537.117865         40955.0
# 2005-11-18 21:00:00  0.002050   62956.315338         39253.6
# 2005-12-02 21:00:00  0.000613   61352.115088         41592.3
# 2005-12-05 21:00:00 -0.001183   59515.114949         43492.4
#
#                                                           transactions
# 2005-10-18 20:00:00  [{u'commission': 5.1, u'amount': 170, u'sid': ...
# 2005-11-08 21:00:00  [{u'commission': 1.2, u'amount': 40, u'sid': u...
# 2005-11-18 21:00:00  [{u'commission': 1.2, u'amount': 40, u'sid': u...
# 2005-12-02 21:00:00  [{u'commission': 3.0, u'amount': 100, u'sid': ...
# 2005-12-05 21:00:00  [{u'commission': 1.2, u'amount': 40, u'sid': u...
#
# [5 rows x 49 columns]

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)

    ax1.set_ylabel('portfolio value in $')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]
        #print [(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]
        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]
        #sells = perf_trans.ix[[t[0]['amount'] < 0 for t in perf_trans.transactions]]
        ax2.plot(buys.index, perf[sec].ix[buys.index],
                 '^', markersize=10, color='g')
        ax2.plot(sells.index, perf[sec].ix[sells.index],
                 'v', markersize=10, color='r')
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze('tutorial_perf.pickle', 0)
