# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pandas as pd

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
#secs=['S5TELS INDEX','S5ENRS INDEX']

secs=['S5TELS INDEX','S5ENRS INDEX','S5FINL INDEX','S5HLTH INDEX','S5UTIL INDEX','S5COND INDEX','S5INFT INDEX','S5INDU INDEX','S5CONS INDEX','S5MATR INDEX']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=['BEST_PE_RATIO', 'BEST_CUR_EV_TO_EBITDA', 'BEST_PX_BPS_RATIO']
options={"OVERRIDE-BEST_FPERIOD_OVERRIDE":"BF"}
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, options=options, start=startdate, end=enddate)
print data
data.to_pickle('bbg_sector_index_data-12yr.pickle')

# %%
for sym in data.items:
    data[sym].ix[:,1:4].plot(title=sym, figsize=(15, 2))
    data[sym].ix[:,6:].plot(figsize=(15, 2))

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Factor Ranking - Sector ETFs - PE Ratio"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    add_history(50, '1d', 'BEST_PE_RATIO')
    add_history(10, '1d', 'BEST_PE_RATIO')
    add_history(500, '1d', 'BEST_PE_RATIO')

    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.001))

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200 or (context.i % 20 != 0):
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    rank_value = history(100, '1d', 'BEST_PE_RATIO').mean()
    for k,v in data.items():
        rank_value[k] = data[k].BEST_PE_RATIO / rank_value[k]

    #print short_return, med_return
    rank = rank_value.rank()
    
    for sec in rank.keys():
        ##### Trading logic ######
        target = 0
        if(rank[sec] > len(rank.keys())/2.0+2):
            target = -1
        elif(rank[sec] < len(rank.keys())/2.0-1):
            target = 1
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-rank', rank[sec])


# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_index_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-08 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-02-25 00:00:00+00:00 Pos Value:  -2847.1 PnL:  -2493.16090002
# Bars Completed:
#  400 2002-07-15 00:00:00+00:00 Pos Value:  -84.77 PnL:  -5926.46290005
# Bars Completed:
#  500 2002-12-02 00:00:00+00:00 Pos Value:  -809.18 PnL:  614.690099887
# Bars Completed:
#  600 2003-04-21 00:00:00+00:00 Pos Value:  -1554.97 PnL:  2509.11609985
# Bars Completed:
#  700 2003-09-08 00:00:00+00:00 Pos Value:  287.59 PnL:  5113.49109976
# Bars Completed:
#  800 2004-01-26 00:00:00+00:00 Pos Value:  -219.84 PnL:  4878.23109966
# Bars Completed:
#  900 2004-06-14 00:00:00+00:00 Pos Value:  418.1 PnL:  6236.78209964
# Bars Completed:
#  1000 2004-11-01 00:00:00+00:00 Pos Value:  -959.11 PnL:  6710.43409963
# Bars Completed:
#  1100 2005-03-21 00:00:00+00:00 Pos Value:  454.99 PnL:  7263.62709958
# Bars Completed:
#  1200 2005-08-08 00:00:00+00:00 Pos Value:  741.6 PnL:  8686.03109955
# Bars Completed:
#  1300 2005-12-26 00:00:00+00:00 Pos Value:  -202.65 PnL:  8758.35109949
# Bars Completed:
#  1400 2006-05-15 00:00:00+00:00 Pos Value:  1289.94 PnL:  13286.8510994
# Bars Completed:
#  1500 2006-10-02 00:00:00+00:00 Pos Value:  2050.89 PnL:  15920.5320994
# Bars Completed:
#  1600 2007-02-19 00:00:00+00:00 Pos Value:  -115.65 PnL:  18848.7680993
# Bars Completed:
#  1700 2007-07-09 00:00:00+00:00 Pos Value:  -1606.58 PnL:  18235.4570993
# Bars Completed:
#  1800 2007-11-26 00:00:00+00:00 Pos Value:  -1188.12 PnL:  17317.6420992
# Bars Completed:
#  1900 2008-04-14 00:00:00+00:00 Pos Value:  -746.25 PnL:  17028.6020992
# Bars Completed:
#  2000 2008-09-01 00:00:00+00:00 Pos Value:  845.484 PnL:  24590.565099
# Bars Completed:
#  2100 2009-01-19 00:00:00+00:00 Pos Value:  -2856.48 PnL:  14746.360099
# Bars Completed:
#  2200 2009-06-08 00:00:00+00:00 Pos Value:  121.65 PnL:  9173.23509896
# Bars Completed:
#  2300 2009-10-26 00:00:00+00:00 Pos Value:  2062.36 PnL:  11817.3120989
# Bars Completed:
#  2400 2010-03-15 00:00:00+00:00 Pos Value:  2270.89 PnL:  14322.6820989
# Bars Completed:
#  2500 2010-08-02 00:00:00+00:00 Pos Value:  605.24 PnL:  12505.8366988
# Bars Completed:
#  2600 2010-12-20 00:00:00+00:00 Pos Value:  -622.1736 PnL:  10534.8632987
# Bars Completed:
#  2700 2011-05-09 00:00:00+00:00 Pos Value:  -1728.76 PnL:  8072.96329869
# Bars Completed:
#  2800 2011-09-26 00:00:00+00:00 Pos Value:  -2585.72 PnL:  3486.25829866
# Bars Completed:
#  2900 2012-02-13 00:00:00+00:00 Pos Value:  3990.104 PnL:  9996.85579862
# Bars Completed:
#  3000 2012-07-02 00:00:00+00:00 Pos Value:  -24.68 PnL:  7559.59829841
# Bars Completed:
#  3100 2012-11-19 00:00:00+00:00 Pos Value:  -411.01 PnL:  9071.09129802
# Bars Completed:
#  3200 2013-04-08 00:00:00+00:00 Pos Value:  1166.27 PnL:  8348.80199798
# Bars Completed:
#  3300 2013-08-26 00:00:00+00:00 Pos Value:  -1691.1 PnL:  6272.05569789
# Bars Completed:
#  3400 2014-01-13 00:00:00+00:00 Pos Value:  -693.45 PnL:  4130.94369788
# Bars Completed:
#  3500 2014-06-02 00:00:00+00:00 Pos Value:  -7.6114 PnL:  5727.3995978
# Bars Completed:
# [2014-11-14 14:44] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-14 14:44] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-14 14:44] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3600 2014-10-20 00:00:00+00:00 Pos Value:  -1130.4 PnL:  6860.80499719

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-rank']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  34.0

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.025951                 0.004171  0.006362
# 2013-10              0.026180                -0.031981 -0.019560
# 2012-10              0.032484                 0.035291  0.026740
# 2011-10              0.042929                -0.051901 -0.060372
# 2010-10              0.036824                 0.002061 -0.015921
# 2009-10              0.065219                -0.072593 -0.073838
# 2008-10              0.060450                 0.019691  0.017056
# 2007-10              0.026068                 0.007363 -0.033366
# 2006-10              0.033353                 0.076905  0.018473
# 2005-10              0.023942                 0.015701 -0.027328
# 2004-10              0.025434                 0.009452 -0.016217
# 2003-10              0.035900                 0.047344  0.040992
# 2002-10              0.062910                 0.001947  0.006929
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213 -0.022453
# 2013-10                      0.243868              0.117836 -0.055263
# 2012-10                      0.126753              0.153977  0.053987
# 2011-10                      0.059192              0.215031  0.125370
# 2010-10                      0.141933              0.181490  0.112945
# 2009-10                      0.069615              0.358120 -0.037250
# 2008-10                     -0.374750              0.346362  0.027827
# 2007-10                      0.124418              0.135401  0.003922
# 2006-10                      0.141614              0.100152  0.093020
# 2005-10                      0.067961              0.105708 -0.002876
# 2004-10                      0.075654              0.112001  0.053162
# 2003-10                      0.186224              0.185829 -0.038981
# 2002-10                     -0.164204              0.254499  0.109516
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.003071    -0.075910      0.027042  0.118345  0.199678
# 2013-10           -0.032981    -0.127769      0.036477 -1.259811 -2.200529
# 2012-10            0.033486    -0.040643      0.035220  1.030831  1.707843
# 2011-10           -0.053101    -0.043790      0.087151 -1.236965 -1.853697
# 2010-10           -0.000139    -0.056406      0.040726 -0.003764 -0.005994
# 2009-10           -0.076293    -0.034263      0.101523 -1.169798 -1.672169
# 2008-10            0.006254     0.079213      0.053103  0.103455  0.149650
# 2007-10           -0.033037    -0.054579      0.020463 -1.267325 -2.389898
# 2006-10            0.027005    -0.041082      0.023633  0.809663  1.459226
# 2005-10           -0.027399    -0.032081      0.015293 -1.144400 -1.795296
# 2004-10           -0.013411    -0.040341      0.018998 -0.527287 -0.819219
# 2003-10            0.034244    -0.045292      0.026592  0.953861  1.259460
# 2002-10           -0.012653     0.040753      0.093758 -0.201129 -0.448730
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
