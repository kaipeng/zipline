# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK','SPY']
fields=['CALL_IMP_VOL_30D','CALL_IMP_VOL_60D','CALL_IMP_VOL_90D']

algo_name = "Minimum Variance Portfolio - Sector ETFs"
data_name = 'bbg_sector_vol_data-12yr'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime', 'record']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = load_bars_from_bloomberg(securities=secs, fields=fields, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle(data_name+'.pickle')
# Out:
# http://10.8.84.65/api/bdh {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYE EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYW EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYH EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYF EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYJ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYZ EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYC EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYM EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'IYK EQUITY'}
# http://10.8.84.65/api/bdh
#  {'startDate': '20010101', 'adjustmentNormal': 'true', 'adjustmentAbnormal': 'true', 'fields': 'PX_OPEN,PX_HIGH,PX_LOW,PX_LAST,PX_VOLUME,LAST_PRICE,CALL_IMP_VOL_30D,CALL_IMP_VOL_60D,CALL_IMP_VOL_90D', 'adjustmentSplit': 'true', 'endDate': '20141101', 'security': 'SPY EQUITY'}
# <class 'pandas.core.panel.Panel'>
# Dimensions: 10 (items) x 3480 (major_axis) x 9 (minor_axis)
# Items axis: IYE to SPY
# Major_axis axis: 2001-01-02 00:00:00+00:00 to 2014-10-31 00:00:00+00:00
# Minor_axis axis: open to CALL_IMP_VOL_90D

# %%
import pandas as pd
data = pd.read_pickle(data_name+'.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

# Define algorithm
def initialize(context):                  
    # Register 3 histories that maintain windows of trailing data
    context.windows = [66]
    
    for t in context.windows:
        add_history(t, '1d', 'price')
        
    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.002))

def handle_data(context, data):
    # Skip first 60 days to get full windows
    context.i += 1
    if context.i < context.windows[-1] or (context.i % 22 != 0):
        return
    
    # Progess report
    if context.i % 1 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    hist_used = history(context.windows[-1], '1d', 'price')
    del hist_used['SPY']
    minvarport = zip(hist_used.keys().values, minvar(hist_used.values))
    
    for sec, weight in minvarport:
        target=weight*(context.portfolio.portfolio_value)
        order_target_value(sec, target)
        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-weight', weight)
        

        
def minvar(prices):
    cov = np.cov((prices[1:] / prices[:-1] - 1).transpose())
    vu = np.array(cov.shape[1] * [1], float)
    num = np.dot(np.linalg.inv(cov), vu)
    den = np.dot(vu, num)
    return num / den  

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle(data_name+'.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  66 2001-04-05 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  88 2001-05-08 00:00:00+00:00 Pos Value:  106503.0102 PnL:  7191.14467978
# Bars Completed:
#  110 2001-06-08 00:00:00+00:00 Pos Value:  108976.8069 PnL:  8590.27171376
# Bars Completed:
#  132 2001-07-11 00:00:00+00:00 Pos Value:  105512.9567 PnL:  4766.86314593
# Bars Completed:
#  154 2001-08-10 00:00:00+00:00 Pos Value:  106021.2874 PnL:  5874.74683229
# Bars Completed:
#  176 2001-09-18 00:00:00+00:00 Pos Value:  101101.1214 PnL:  908.253448217
# Bars Completed:
#  198 2001-10-18 00:00:00+00:00 Pos Value:  98718.7213 PnL:  -2288.09444946
# Bars Completed:
#  220 2001-11-19 00:00:00+00:00 Pos Value:  99776.8044 PnL:  -921.991017594
# Bars Completed:
#  242 2001-12-20 00:00:00+00:00 Pos Value:  99799.4737 PnL:  -477.64127953
# Bars Completed:
#  264 2002-01-24 00:00:00+00:00 Pos Value:  98816.9652 PnL:  -1343.37638539
# Bars Completed:
#  286 2002-02-26 00:00:00+00:00 Pos Value:  101388.0686 PnL:  882.50635619
# Bars Completed:
#  308 2002-03-28 00:00:00+00:00 Pos Value:  103291.6405 PnL:  3330.64108862
# Bars Completed:
#  330 2002-04-30 00:00:00+00:00 Pos Value:  104087.6456 PnL:  4146.78026015
# Bars Completed:
#  352 2002-05-31 00:00:00+00:00 Pos Value:  103825.0039 PnL:  3761.05613079
# Bars Completed:
#  374 2002-07-02 00:00:00+00:00 Pos Value:  96948.5204 PnL:  -2834.11128149
# Bars Completed:
#  396 2002-08-02 00:00:00+00:00 Pos Value:  88453.0816 PnL:  -11966.1694811
# Bars Completed:
#  418 2002-09-04 00:00:00+00:00 Pos Value:  90736.3807 PnL:  -9731.28115745
# Bars Completed:
#  440 2002-10-04 00:00:00+00:00 Pos Value:  82371.4006 PnL:  -17665.3253125
# Bars Completed:
#  462 2002-11-05 00:00:00+00:00 Pos Value:  88662.7867 PnL:  -11367.9728921
# Bars Completed:
#  484 2002-12-06 00:00:00+00:00 Pos Value:  86621.2743 PnL:  -14645.7015606
# Bars Completed:
#  506 2003-01-09 00:00:00+00:00 Pos Value:  85666.3226 PnL:  -14139.3631651
# Bars Completed:
#  528 2003-02-11 00:00:00+00:00 Pos Value:  80175.8127 PnL:  -19831.0437471
# Bars Completed:
#  550 2003-03-14 00:00:00+00:00 Pos Value:  80268.1816 PnL:  -20180.6087811
# Bars Completed:
#  572 2003-04-15 00:00:00+00:00 Pos Value:  83441.0881 PnL:  -16113.7602903
# Bars Completed:
#  594 2003-05-16 00:00:00+00:00 Pos Value:  88079.7009 PnL:  -12339.1089398
# Bars Completed:
#  616 2003-06-18 00:00:00+00:00 Pos Value:  93430.4071 PnL:  -6636.69303643
# Bars Completed:
#  638 2003-07-21 00:00:00+00:00 Pos Value:  89527.9857 PnL:  -10370.4324581
# Bars Completed:
#  660 2003-08-20 00:00:00+00:00 Pos Value:  88585.7963 PnL:  -11510.5431788
# Bars Completed:
#  682 2003-09-22 00:00:00+00:00 Pos Value:  90130.9922 PnL:  -10357.5877321
# Bars Completed:
#  704 2003-10-22 00:00:00+00:00 Pos Value:  90646.7991 PnL:  -9440.32512901
# Bars Completed:
#  726 2003-11-21 00:00:00+00:00 Pos Value:  93018.4556 PnL:  -6859.23131152
# Bars Completed:
#  748 2003-12-24 00:00:00+00:00 Pos Value:  101090.1651 PnL:  1001.79706421
# Bars Completed:
#  770 2004-01-28 00:00:00+00:00 Pos Value:  102400.1676 PnL:  2397.39064911
# Bars Completed:
#  792 2004-03-01 00:00:00+00:00 Pos Value:  108954.5451 PnL:  9108.17070823
# Bars Completed:
#  814 2004-03-31 00:00:00+00:00 Pos Value:  107222.772 PnL:  7620.2416186
# Bars Completed:
#  836 2004-05-03 00:00:00+00:00 Pos Value:  112541.2077 PnL:  12693.2843348
# Bars Completed:
#  858 2004-06-03 00:00:00+00:00 Pos Value:  110873.327 PnL:  11026.6603306
# Bars Completed:
#  880 2004-07-07 00:00:00+00:00 Pos Value:  106907.1654 PnL:  6720.81903607
# Bars Completed:
#  902 2004-08-06 00:00:00+00:00 Pos Value:  101655.8886 PnL:  1493.32995948
# Bars Completed:
#  924 2004-09-08 00:00:00+00:00 Pos Value:  107920.7181 PnL:  7884.81790438
# Bars Completed:
#  946 2004-10-08 00:00:00+00:00 Pos Value:  106062.534 PnL:  5851.43550548
# Bars Completed:
#  968 2004-11-09 00:00:00+00:00 Pos Value:  106664.6256 PnL:  6956.73852682
# Bars Completed:
#  990 2004-12-10 00:00:00+00:00 Pos Value:  109770.736 PnL:  10031.7303835
# Bars Completed:
#  1012 2005-01-12 00:00:00+00:00 Pos Value:  111070.4374 PnL:  10826.5471592
# Bars Completed:
#  1034 2005-02-14 00:00:00+00:00 Pos Value:  112185.5878 PnL:  12422.2396074
# Bars Completed:
#  1056 2005-03-17 00:00:00+00:00 Pos Value:  111445.4101 PnL:  11527.8402662
# Bars Completed:
#  1078 2005-04-19 00:00:00+00:00 Pos Value:  109449.8877 PnL:  9753.27351393
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  112310.4261 PnL:  12264.1979299
# Bars Completed:
#  1122 2005-06-21 00:00:00+00:00 Pos Value:  115272.649 PnL:  15324.1274513
# Bars Completed:
#  1144 2005-07-22 00:00:00+00:00 Pos Value:  115313.5312 PnL:  15420.5989533
# Bars Completed:
#  1166 2005-08-23 00:00:00+00:00 Pos Value:  116778.4657 PnL:  16598.9458348
# Bars Completed:
#  1188 2005-09-23 00:00:00+00:00 Pos Value:  116896.8646 PnL:  16788.769119
# Bars Completed:
#  1210 2005-10-25 00:00:00+00:00 Pos Value:  113776.8868 PnL:  13660.9851459
# Bars Completed:
#  1232 2005-11-25 00:00:00+00:00 Pos Value:  118137.9634 PnL:  18091.0146936
# Bars Completed:
#  1254 2005-12-28 00:00:00+00:00 Pos Value:  118910.4013 PnL:  18680.5212745
# Bars Completed:
#  1276 2006-01-31 00:00:00+00:00 Pos Value:  119218.0018 PnL:  19042.7307334
# Bars Completed:
#  1298 2006-03-03 00:00:00+00:00 Pos Value:  123111.9409 PnL:  23472.275652
# Bars Completed:
#  1320 2006-04-04 00:00:00+00:00 Pos Value:  125683.798 PnL:  26307.4563711
# Bars Completed:
#  1342 2006-05-05 00:00:00+00:00 Pos Value:  127359.5447 PnL:  27132.8863352
# Bars Completed:
#  1364 2006-06-07 00:00:00+00:00 Pos Value:  125116.8062 PnL:  24858.7995222
# Bars Completed:
#  1386 2006-07-10 00:00:00+00:00 Pos Value:  127083.6299 PnL:  26840.5391183
# Bars Completed:
#  1408 2006-08-09 00:00:00+00:00 Pos Value:  126428.7143 PnL:  26428.484283
# Bars Completed:
#  1430 2006-09-11 00:00:00+00:00 Pos Value:  130722.9628 PnL:  31419.7678164
# Bars Completed:
#  1452 2006-10-11 00:00:00+00:00 Pos Value:  131208.4724 PnL:  31435.5998692
# Bars Completed:
#  1474 2006-11-10 00:00:00+00:00 Pos Value:  134198.2981 PnL:  34033.0686731
# Bars Completed:
#  1496 2006-12-13 00:00:00+00:00 Pos Value:  137496.7409 PnL:  37212.9696875
# Bars Completed:
#  1518 2007-01-18 00:00:00+00:00 Pos Value:  139386.8501 PnL:  39339.1337635
# Bars Completed:
#  1540 2007-02-20 00:00:00+00:00 Pos Value:  142683.1278 PnL:  42649.9072251
# Bars Completed:
#  1562 2007-03-22 00:00:00+00:00 Pos Value:  139916.5963 PnL:  40085.4471514
# Bars Completed:
#  1584 2007-04-24 00:00:00+00:00 Pos Value:  148408.9499 PnL:  48267.5992687
# Bars Completed:
#  1606 2007-05-24 00:00:00+00:00 Pos Value:  149575.0316 PnL:  49848.644725
# Bars Completed:
#  1628 2007-06-26 00:00:00+00:00 Pos Value:  147061.064 PnL:  46678.3212454
# Bars Completed:
#  1650 2007-07-27 00:00:00+00:00 Pos Value:  144750.2145 PnL:  44554.7730809
# Bars Completed:
#  1672 2007-08-28 00:00:00+00:00 Pos Value:  143901.6668 PnL:  44301.6793357
# Bars Completed:
#  1694 2007-09-28 00:00:00+00:00 Pos Value:  147035.4666 PnL:  47268.8529925
# Bars Completed:
#  1716 2007-10-30 00:00:00+00:00 Pos Value:  147963.2593 PnL:  47396.0756345
# Bars Completed:
#  1738 2007-11-30 00:00:00+00:00 Pos Value:  153859.5082 PnL:  53716.6239413
# Bars Completed:
#  1760 2008-01-03 00:00:00+00:00 Pos Value:  148684.4781 PnL:  49093.7609212
# Bars Completed:
#  1782 2008-02-05 00:00:00+00:00 Pos Value:  142665.4306 PnL:  42542.3879054
# Bars Completed:
#  1804 2008-03-07 00:00:00+00:00 Pos Value:  144518.5964 PnL:  44743.7039865
# Bars Completed:
#  1826 2008-04-09 00:00:00+00:00 Pos Value:  146434.061 PnL:  46120.2896489
# Bars Completed:
#  1848 2008-05-09 00:00:00+00:00 Pos Value:  142264.6538 PnL:  42427.9533245
# Bars Completed:
#  1870 2008-06-11 00:00:00+00:00 Pos Value:  143334.1421 PnL:  44210.9641153
# Bars Completed:
#  1892 2008-07-14 00:00:00+00:00 Pos Value:  146688.6035 PnL:  47129.9500261
# Bars Completed:
#  1914 2008-08-13 00:00:00+00:00 Pos Value:  155993.8712 PnL:  56434.4474884
# Bars Completed:
#  1936 2008-09-15 00:00:00+00:00 Pos Value:  150400.3072 PnL:  50945.9595962
# Bars Completed:
#  1958 2008-10-15 00:00:00+00:00 Pos Value:  121955.8814 PnL:  22659.7544777
# Bars Completed:
#  1980 2008-11-14 00:00:00+00:00 Pos Value:  117264.4791 PnL:  19597.5890529
# Bars Completed:
#  2002 2008-12-17 00:00:00+00:00 Pos Value:  114479.269 PnL:  13922.5328466
# Bars Completed:
#  2024 2009-01-21 00:00:00+00:00 Pos Value:  125213.5534 PnL:  25327.7657895
# Bars Completed:
#  2046 2009-02-23 00:00:00+00:00 Pos Value:  131175.8969 PnL:  31130.4031308
# Bars Completed:
#  2068 2009-03-25 00:00:00+00:00 Pos Value:  124069.7867 PnL:  23473.7828589
# Bars Completed:
#  2090 2009-04-27 00:00:00+00:00 Pos Value:  122895.7242 PnL:  24171.0519249
# Bars Completed:
#  2112 2009-05-28 00:00:00+00:00 Pos Value:  129500.0861 PnL:  29446.1795182
# Bars Completed:
#  2134 2009-06-29 00:00:00+00:00 Pos Value:  137150.3778 PnL:  36854.5105378
# Bars Completed:
#  2156 2009-07-30 00:00:00+00:00 Pos Value:  145622.3729 PnL:  45911.111033
# Bars Completed:
#  2178 2009-08-31 00:00:00+00:00 Pos Value:  142540.2116 PnL:  42616.5292359
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  144243.5414 PnL:  44813.0751986
# Bars Completed:
#  2222 2009-11-02 00:00:00+00:00 Pos Value:  146659.2316 PnL:  47205.8789472
# Bars Completed:
#  2244 2009-12-03 00:00:00+00:00 Pos Value:  158083.6692 PnL:  58074.6068766
# Bars Completed:
#  2266 2010-01-06 00:00:00+00:00 Pos Value:  159033.9731 PnL:  58433.4987558
# Bars Completed:
#  2288 2010-02-08 00:00:00+00:00 Pos Value:  157338.1881 PnL:  58133.0732248
# Bars Completed:
#  2310 2010-03-11 00:00:00+00:00 Pos Value:  166270.6031 PnL:  66270.2367089
# Bars Completed:
#  2332 2010-04-13 00:00:00+00:00 Pos Value:  168545.0938 PnL:  68546.5241532
# Bars Completed:
#  2354 2010-05-13 00:00:00+00:00 Pos Value:  163330.158 PnL:  63263.7430056
# Bars Completed:
#  2376 2010-06-15 00:00:00+00:00 Pos Value:  166203.2958 PnL:  65511.7819601
# Bars Completed:
#  2398 2010-07-16 00:00:00+00:00 Pos Value:  164026.1112 PnL:  64439.029151
# Bars Completed:
#  2420 2010-08-17 00:00:00+00:00 Pos Value:  171367.1739 PnL:  71580.1805768
# Bars Completed:
#  2442 2010-09-17 00:00:00+00:00 Pos Value:  175951.198 PnL:  76022.7147595
# Bars Completed:
#  2464 2010-10-19 00:00:00+00:00 Pos Value:  182118.4168 PnL:  82267.5062041
# Bars Completed:
#  2486 2010-11-18 00:00:00+00:00 Pos Value:  182736.2213 PnL:  82859.8672218
# Bars Completed:
#  2508 2010-12-21 00:00:00+00:00 Pos Value:  185538.0731 PnL:  85379.1716649
# Bars Completed:
#  2530 2011-01-24 00:00:00+00:00 Pos Value:  183008.8608 PnL:  81757.7084257
# Bars Completed:
#  2552 2011-02-24 00:00:00+00:00 Pos Value:  181656.6868 PnL:  81853.3789557
# Bars Completed:
#  2574 2011-03-28 00:00:00+00:00 Pos Value:  186148.8539 PnL:  85362.8793331
# Bars Completed:
#  2596 2011-04-28 00:00:00+00:00 Pos Value:  201108.1755 PnL:  101049.047095
# Bars Completed:
#  2618 2011-05-31 00:00:00+00:00 Pos Value:  210708.0126 PnL:  110836.364585
# Bars Completed:
#  2640 2011-06-30 00:00:00+00:00 Pos Value:  206787.2739 PnL:  106596.333867
# Bars Completed:
#  2662 2011-08-02 00:00:00+00:00 Pos Value:  201478.3934 PnL:  100901.62874
# Bars Completed:
#  2684 2011-09-01 00:00:00+00:00 Pos Value:  205900.6359 PnL:  105891.299296
# Bars Completed:
#  2706 2011-10-04 00:00:00+00:00 Pos Value:  209661.0184 PnL:  107204.960246
# Bars Completed:
#  2728 2011-11-03 00:00:00+00:00 Pos Value:  193328.6527 PnL:  94855.1384332
# Bars Completed:
#  2750 2011-12-06 00:00:00+00:00 Pos Value:  193738.0257 PnL:  93334.7058922
# Bars Completed:
#  2772 2012-01-09 00:00:00+00:00 Pos Value:  195212.5405 PnL:  96231.8093164
# Bars Completed:
#  2794 2012-02-09 00:00:00+00:00 Pos Value:  197927.8375 PnL:  98094.2956819
# Bars Completed:
#  2816 2012-03-13 00:00:00+00:00 Pos Value:  211999.0845 PnL:  111841.010938
# Bars Completed:
#  2838 2012-04-13 00:00:00+00:00 Pos Value:  216347.4385 PnL:  116232.136975
# Bars Completed:
#  2860 2012-05-15 00:00:00+00:00 Pos Value:  217179.9666 PnL:  116777.904559
# Bars Completed:
#  2882 2012-06-15 00:00:00+00:00 Pos Value:  222127.5935 PnL:  121413.940103
# Bars Completed:
#  2904 2012-07-18 00:00:00+00:00 Pos Value:  231084.2194 PnL:  131196.960071
# Bars Completed:
#  2926 2012-08-17 00:00:00+00:00 Pos Value:  235494.3665 PnL:  135330.22721
# Bars Completed:
#  2948 2012-09-19 00:00:00+00:00 Pos Value:  235596.9519 PnL:  134317.65035
# Bars Completed:
#  2970 2012-10-19 00:00:00+00:00 Pos Value:  237699.8367 PnL:  138910.44238
# Bars Completed:
#  2992 2012-11-23 00:00:00+00:00 Pos Value:  239806.6225 PnL:  140163.355218
# Bars Completed:
#  3014 2012-12-26 00:00:00+00:00 Pos Value:  237362.9195 PnL:  137521.716962
# Bars Completed:
#  3036 2013-01-29 00:00:00+00:00 Pos Value:  253081.2884 PnL:  152643.118873
# Bars Completed:
#  3058 2013-03-01 00:00:00+00:00 Pos Value:  257494.6985 PnL:  156851.353061
# Bars Completed:
#  3080 2013-04-03 00:00:00+00:00 Pos Value:  276035.4938 PnL:  176574.326678
# Bars Completed:
#  3102 2013-05-03 00:00:00+00:00 Pos Value:  292293.9466 PnL:  192915.879443
# Bars Completed:
#  3124 2013-06-05 00:00:00+00:00 Pos Value:  286801.7561 PnL:  185498.948533
# Bars Completed:
#  3146 2013-07-08 00:00:00+00:00 Pos Value:  294149.261 PnL:  194435.634975
# Bars Completed:
#  3168 2013-08-07 00:00:00+00:00 Pos Value:  308111.8146 PnL:  208541.182298
# Bars Completed:
#  3190 2013-09-09 00:00:00+00:00 Pos Value:  313110.202 PnL:  212028.474314
# Bars Completed:
#  3212 2013-10-09 00:00:00+00:00 Pos Value:  308429.5546 PnL:  209269.900627
# Bars Completed:
#  3234 2013-11-08 00:00:00+00:00 Pos Value:  327784.7173 PnL:  226215.332662
# Bars Completed:
#  3256 2013-12-11 00:00:00+00:00 Pos Value:  325120.6516 PnL:  225378.946542
# Bars Completed:
#  3278 2014-01-14 00:00:00+00:00 Pos Value:  337551.361 PnL:  237827.427523
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  339813.198 PnL:  238685.911489
# Bars Completed:
#  3322 2014-03-19 00:00:00+00:00 Pos Value:  345467.5547 PnL:  245710.354237
# Bars Completed:
#  3344 2014-04-21 00:00:00+00:00 Pos Value:  352571.7342 PnL:  252538.935636
# Bars Completed:
#  3366 2014-05-21 00:00:00+00:00 Pos Value:  360616.0234 PnL:  261703.565571
# Bars Completed:
#  3388 2014-06-23 00:00:00+00:00 Pos Value:  374414.5995 PnL:  273943.180539
# Bars Completed:
#  3410 2014-07-24 00:00:00+00:00 Pos Value:  373549.4606 PnL:  274476.712827
# Bars Completed:
#  3432 2014-08-25 00:00:00+00:00 Pos Value:  374470.4029 PnL:  273908.700679
# Bars Completed:
#  3454 2014-09-25 00:00:00+00:00 Pos Value:  371219.32 PnL:  271828.672113
# Bars Completed:
# [2014-11-20 23:27] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-20 23:27] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-20 23:27] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3476 2014-10-27 00:00:00+00:00 Pos Value:  369441.36 PnL:  269273.163361

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 100000.0/data['SPY']['price'][66]*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-weight']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  1291.242

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(14)]]
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.102382                 0.161352  0.046455
# 2013-10              0.115254                 0.380367  0.198313
# 2012-10              0.107868                 0.185020  0.136793
# 2011-10              0.142727                 0.085679  0.062329
# 2010-10              0.118821                 0.257631  0.196336
# 2009-10              0.214568                 0.163460  0.149718
# 2008-10              0.235453                -0.152260  0.017951
# 2007-10              0.097768                 0.104304  0.021884
# 2006-10              0.089284                 0.172882  0.064887
# 2005-10              0.096507                 0.084834  0.022387
# 2004-10              0.097376                 0.144336  0.089505
# 2003-10              0.138486                 0.050726 -0.045965
# 2002-10              0.198585                -0.096065 -0.009463
# 2014-09              0.101136                 0.184480  0.042897
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.776514
# 2013-10                      0.243868              0.117836  0.745487
# 2012-10                      0.126753              0.153977  0.371527
# 2011-10                      0.059192              0.215031  0.381941
# 2010-10                      0.141933              0.181490  0.422911
# 2009-10                      0.069615              0.358120  0.152344
# 2008-10                     -0.374750              0.346362  0.473092
# 2007-10                      0.124418              0.135401  0.500126
# 2006-10                      0.141614              0.100152  0.633427
# 2005-10                      0.067961              0.105708  0.778177
# 2004-10                      0.075654              0.112001  0.605550
# 2003-10                      0.186224              0.185829  0.482841
# 2002-10                     -0.164204              0.254499  0.565999
# 2014-09                      0.172900              0.102981  0.817502
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.160252     0.011341      0.060128  1.565225  2.136154
# 2013-10            0.379367     0.081420      0.064832  3.291587  4.925227
# 2012-10            0.183215     0.021072      0.049171  1.698504  3.030033
# 2011-10            0.084479     0.004168      0.102660  0.591891  0.745435
# 2010-10            0.255431     0.039723      0.082589  2.149707  3.192780
# 2009-10            0.159760     0.007396      0.129857  0.744567  1.143549
# 2008-10           -0.165697     0.068707      0.227664 -0.703737 -0.883461
# 2007-10            0.063904    -0.014496      0.049680  0.653624  0.878959
# 2006-10            0.122982     0.022521      0.038739  1.377415  2.260696
# 2005-10            0.041734     0.016666      0.057775  0.432443  0.698372
# 2004-10            0.121473     0.046209      0.102519  1.247470  1.837392
# 2003-10            0.037626    -0.056935      0.113066  0.271697  0.494121
# 2002-10           -0.110665     0.023587      0.247029 -0.557271 -0.856831
# 2014-09            0.183180     0.010275      0.054863  1.811227  2.577327
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
# 2014-09                252                0.001300
