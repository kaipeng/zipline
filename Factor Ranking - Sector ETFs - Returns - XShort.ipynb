# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg, load_bars_from_yahoo

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
fields=[]
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
import pandas as pd
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Factor Ranking - Sector ETFs - Returns - XShort"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(5, '1d', 'price')
    add_history(20, '1d', 'price')
    add_history(60, '1d', 'price')

    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.001))

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200 or (context.i % 5 != 0):
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_return = history(5, '1d', 'price').ix[0]
    for k,v in data.items():
        short_return[k] = data[k].price / short_return[k]
    med_return = history(20, '1d', 'price').ix[0]
    for k,v in data.items():
        med_return[k] = data[k].price / med_return[k]    
    long_return = history(60, '1d', 'price').ix[0]
    for k,v in data.items():
        long_return[k] = data[k].price / long_return[k]
    #print short_return, med_return
    short_return_rank = short_return.rank()
    med_return_rank = med_return.rank()
    long_return_rank = long_return.rank()
    
    for sec in short_return_rank.keys():
        ##### Trading logic ######
        target = 0
        if(short_return_rank[sec] > len(short_return_rank.keys())/2.0+2):
            target = -1
        elif(short_return_rank[sec] < len(short_return_rank.keys())/2.0-1):
            target = 1
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_return_rank[sec])
        record(sec+'-m_ma', med_return_rank[sec])
        record(sec+'-l_ma', long_return_rank[sec])
    

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  1426.9488 PnL:  2772.47691476
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  208.6431 PnL:  4818.48767744
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  461.829 PnL:  4458.67784267
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  -577.5941 PnL:  9513.63490426
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  -358.5321 PnL:  9759.4980284
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  236.7709 PnL:  9281.95861364
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  -252.5377 PnL:  8889.20734387
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  -253.1426 PnL:  8921.05226534
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  -346.9877 PnL:  10621.5894859
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  113.6798 PnL:  9431.84873356
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  -325.7814 PnL:  10923.1508549
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  628.1055 PnL:  12891.65663
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  -10.1923 PnL:  13844.2355138
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  5.5504 PnL:  15842.5187274
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  92.753 PnL:  14659.5281827
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  267.0315 PnL:  18830.8684888
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  -979.4946 PnL:  17091.122735
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  1783.8559 PnL:  22357.7529231
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  -740.6522 PnL:  21347.4245229
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  -678.1968 PnL:  24598.9004857
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  -394.7499 PnL:  23510.7014962
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  612.7031 PnL:  24795.525765
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  -163.303 PnL:  23892.8400846
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  -460.6085 PnL:  27543.0830582
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  -1020.1995 PnL:  27850.6266821
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  -74.7293 PnL:  27758.2642119
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  1237.6952 PnL:  29065.9191311
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  506.5472 PnL:  30548.2091463
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  191.2926 PnL:  30242.0353278
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  464.076 PnL:  34416.3591202
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  315.5953 PnL:  32948.621073
# Bars Completed:
# [2014-11-14 14:36] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-14 14:36] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-14 14:36] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  -278.6776 PnL:  31729.6854235

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-s_ma']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  1757.885

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.021655                -0.018103 -0.022895
# 2013-10              0.024703                 0.036193  0.032278
# 2012-10              0.028839                 0.014194  0.007536
# 2011-10              0.035889                 0.026885  0.023303
# 2010-10              0.031499                -0.010890 -0.015234
# 2009-10              0.080403                 0.057758  0.053273
# 2008-10              0.077289                 0.038353  0.049130
# 2007-10              0.028613                 0.015042 -0.024723
# 2006-10              0.036255                 0.018674 -0.032057
# 2005-10              0.031055                 0.027586 -0.016052
# 2004-10              0.032792                -0.027154 -0.050154
# 2003-10              0.046405                 0.079223  0.072643
# 2002-10              0.060326                 0.034704  0.029638
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  0.025192
# 2013-10                      0.243868              0.117836  0.012005
# 2012-10                      0.126753              0.153977  0.038835
# 2011-10                      0.059192              0.215031  0.041075
# 2010-10                      0.141933              0.181490  0.015343
# 2009-10                      0.069615              0.358120  0.011908
# 2008-10                     -0.374750              0.346362  0.062376
# 2007-10                      0.124418              0.135401 -0.007565
# 2006-10                      0.141614              0.100152  0.009057
# 2005-10                      0.067961              0.105708  0.021633
# 2004-10                      0.075654              0.112001  0.002603
# 2003-10                      0.186224              0.185829 -0.037663
# 2002-10                     -0.164204              0.254499  0.053321
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10           -0.019203    -0.093056      0.030650 -0.886752 -1.524055
# 2013-10            0.035193    -0.100247      0.013213  1.424677  2.495894
# 2012-10            0.012389    -0.048870      0.016573  0.429586  0.705583
# 2011-10            0.025685    -0.016085      0.033984  0.715676  1.067217
# 2010-10           -0.013090    -0.055533      0.045425 -0.415558 -0.663229
# 2009-10            0.054058    -0.012522      0.060085  0.672333  0.907832
# 2008-10            0.024916     0.084958      0.040975  0.322374  0.454390
# 2007-10           -0.025358    -0.050316      0.024995 -0.886260 -1.418381
# 2006-10           -0.031226    -0.070540      0.024178 -0.861296 -1.433764
# 2005-10           -0.015514    -0.025408      0.029324 -0.499569 -0.971914
# 2004-10           -0.050016    -0.057680      0.052776 -1.525273 -2.362679
# 2003-10            0.066123    -0.035176      0.024683  1.424912  2.789221
# 2002-10            0.020104     0.046510      0.044579  0.333247  0.535198
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
