# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_bloomberg

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
fields=[]
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
import pandas as pd
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np
import pandas as pd

from collections import deque

algo_name = "Factor Ranking - Sector ETFs - Returns - Short"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(10, '1d', 'price')
    add_history(20, '1d', 'price')
    add_history(60, '1d', 'price')

    context.i = 0
    set_commission(zipline.finance.commission.PerShare(cost=0.001))

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200 or (context.i % 10 != 0):
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_return = history(5, '1d', 'price').ix[0]
    for k,v in data.items():
        short_return[k] = data[k].price / short_return[k]
    med_return = history(20, '1d', 'price').ix[0]
    for k,v in data.items():
        med_return[k] = data[k].price / med_return[k]    
    long_return = history(60, '1d', 'price').ix[0]
    for k,v in data.items():
        long_return[k] = data[k].price / long_return[k]
    #print short_return, med_return
    short_return_rank = short_return.rank()
    med_return_rank = med_return.rank()
    long_return_rank = long_return.rank()
    
    for sec in short_return_rank.keys():
        ##### Trading logic ######
        target = 0
        if(short_return_rank[sec] > len(short_return_rank.keys())/2.0+1):
            target = -1
        elif(short_return_rank[sec] < len(short_return_rank.keys())/2.0):
            target = 1
        target=target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_return_rank[sec])
        record(sec+'-m_ma', med_return_rank[sec])
        record(sec+'-l_ma', long_return_rank[sec])
    

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  865.0104 PnL:  417.83195301
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  -172.9672 PnL:  7154.64037037
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  -246.9984 PnL:  7967.41919828
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  -689.3359 PnL:  11665.8442773
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  801.2531 PnL:  14763.5263334
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  -423.5704 PnL:  13527.050783
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  -746.3469 PnL:  12177.8815253
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  -23.927 PnL:  13434.7214416
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  797.4715 PnL:  11565.6902309
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  -727.7159 PnL:  10457.6988108
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  983.1341 PnL:  9375.92861174
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  -1119.3807 PnL:  9191.61752637
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  277.8206 PnL:  11800.2276759
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  -613.1875 PnL:  14724.5790322
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  763.325 PnL:  14042.4940596
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  305.6242 PnL:  19867.855786
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  160.3977 PnL:  23565.5919192
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  176.8104 PnL:  32755.0341451
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  -342.2798 PnL:  34155.4643929
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  2664.497 PnL:  44934.670545
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  -377.0316 PnL:  48334.2944084
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  546.2315 PnL:  46650.4182063
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  44.6416 PnL:  45339.3570594
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  884.1294 PnL:  48320.0943754
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  -852.9359 PnL:  47812.2217619
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  578.4723 PnL:  48966.2585218
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  -1268.149 PnL:  44938.6665355
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  127.4476 PnL:  43954.0173947
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  759.9966 PnL:  40659.9848087
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  368.6537 PnL:  41858.607921
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  -716.2095 PnL:  41423.2419923
# Bars Completed:
# [2014-11-13 23:34] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-13 23:34] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-13 23:34] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  -486.4106 PnL:  40105.1005336

# %%
import pandas as pd
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2, c='k')
        
        ax3 = ax2.twinx()
        perf[[sec+'-s_ma']].plot(ax=ax3)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
    
file_analyze(algo_name+'.pickle', 0)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions
# Out:
# Total Commish:  1047.138

# %%
from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.025862                -0.005531 -0.006581
# 2013-10              0.027784                -0.014327 -0.017166
# 2012-10              0.032914                -0.012621 -0.015664
# 2011-10              0.037205                -0.001872 -0.002762
# 2010-10              0.035761                -0.029385 -0.033950
# 2009-10              0.073984                 0.148299  0.146279
# 2008-10              0.092775                 0.141934  0.152750
# 2007-10              0.031393                 0.044063  0.003632
# 2006-10              0.040653                -0.004529 -0.052043
# 2005-10              0.034135                -0.014437 -0.057272
# 2004-10              0.038319                -0.019477 -0.043173
# 2003-10              0.052602                 0.042927  0.042916
# 2002-10              0.067257                 0.093171  0.092386
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213 -0.000342
# 2013-10                      0.243868              0.117836  0.007574
# 2012-10                      0.126753              0.153977  0.009910
# 2011-10                      0.059192              0.215031 -0.005352
# 2010-10                      0.141933              0.181490  0.016924
# 2009-10                      0.069615              0.358120 -0.025493
# 2008-10                     -0.374750              0.346362  0.062476
# 2007-10                      0.124418              0.135401  0.000371
# 2006-10                      0.141614              0.100152 -0.026014
# 2005-10                      0.067961              0.105708 -0.010682
# 2004-10                      0.075654              0.112001  0.015779
# 2003-10                      0.186224              0.185829 -0.075607
# 2002-10                     -0.164204              0.254499  0.077261
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10           -0.006631    -0.082899      0.028824 -0.256408 -0.431735
# 2013-10           -0.015327    -0.125410      0.038071 -0.551635 -0.811879
# 2012-10           -0.014426    -0.058005      0.049371 -0.438281 -0.757232
# 2011-10           -0.003072    -0.023461      0.032264 -0.082576 -0.116572
# 2010-10           -0.031585    -0.061878      0.047502 -0.883209 -1.421356
# 2009-10            0.144599     0.001632      0.033169  1.954452  2.910417
# 2008-10            0.128497     0.101962      0.061748  1.385038  2.076076
# 2007-10            0.003663    -0.037632      0.028685  0.116676  0.192157
# 2006-10           -0.054429    -0.080504      0.028333 -1.338871 -2.221826
# 2005-10           -0.057537    -0.047809      0.037937 -1.685584 -3.264024
# 2004-10           -0.042340    -0.053182      0.048745 -1.104926 -1.694258
# 2003-10            0.029827    -0.044171      0.036869  0.567021  1.080297
# 2002-10            0.078571     0.061711      0.041263  1.168225  2.016564
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
