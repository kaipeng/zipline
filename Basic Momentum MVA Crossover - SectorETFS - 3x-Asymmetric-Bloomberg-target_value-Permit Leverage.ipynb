# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML

import pytz
from datetime import datetime

from zipline.data.loader import load_bars_from_yahoo
from zipline.data.loader import load_bars_from_bloomberg
import pandas as pd

# Load data manually from Yahoo! finance
startdate = datetime(2001, 1, 1, 0, 0, 0, 0, pytz.utc)
enddate = datetime(2014, 11, 1, 0, 0, 0, 0, pytz.utc)
secs=['TLT','IYE','IYW','IYH','IYF','IYJ','IYZ','IYC','IYM','IYK']
#data = load_bars_from_yahoo(stocks=secs, start=startdate, end=enddate)

fields=[]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = load_bars_from_bloomberg(securities=secs, start=startdate, end=enddate)
print data
for sym in data.items:
    data[sym].ix[:,5:].plot(title=sym, figsize=(15, 3))
data.to_pickle('bbg_sector_etf_data-12yr.pickle')

# %%
from zipline.algorithm import TradingAlgorithm
from zipline.api import order_target_value, record, symbol, history, add_history, set_commission
import zipline
import numpy as np

from collections import deque

algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg-target_value-Levered"

# Define algorithm
def initialize(context):
    #set_benchmark(symbol('SPY'))
                  
    # Register 2 histories that track daily prices,
    # one with a 100 window and one with a 300 day window
    #add_history(10, '1d', 'price')
    add_history(20, '1d', 'price')
    add_history(100, '1d', 'price')
    add_history(200, '1d', 'price')

    context.i = 0
    context.secs = secs
    '''
    #context.window = pd.Panel(items=context.secs)
    #for sec in context.secs:
    context.cache = {}
    #context.cache['xs_ma'] = deque()
    context.cache['s_ma'] = deque()
    context.cache['m_ma'] = deque()
    context.cache['l_ma'] = deque()
    '''
    set_commission(zipline.finance.commission.PerShare(cost=0.001))
        

def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 200:
        return
    
    # Progess report
    if context.i % 100 == 0:
        print 'Bars Completed: ', context.i, data[data.keys()[0]]['dt'], 'Pos Value: ', context.portfolio.positions_value,'PnL: ', context.portfolio.pnl 

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(20, '1d', 'price').mean()
    med_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(200, '1d', 'price').mean()
    
    for sec in data.keys():
        
        ##### Trading logic ######
        # Compounding Moving Average Crossover Signals
        target = 0.0
        if short_mavg[sec] > med_mavg[sec]:
            target += .2
        if short_mavg[sec] > long_mavg[sec]:
            target += .3
        if med_mavg[sec] > long_mavg[sec]:
            target += .5

        if short_mavg[sec] < med_mavg[sec]:
            target -= .2
        if short_mavg[sec] < long_mavg[sec]:
            target -= .1
        if med_mavg[sec] < long_mavg[sec]:
            target -= 0
            
        target=2*target*(context.portfolio.portfolio_value)/len(data)
        ##### Trading logic ######
        
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target_value(sec, target)

        # Save values for later inspection
        record(sec, data[sec].price)
        record(sec+'-s_ma', short_mavg[sec])
        record(sec+'-m_ma', med_mavg[sec])
        record(sec+'-l_ma', long_mavg[sec])
    
    '''
    context.cache['s_ma'].append(short_mavg)
    context.cache['m_ma'].append(med_mavg)
    context.cache['l_ma'].append(long_mavg)
    
    #trim cache
    for key in context.cache.keys():
        if len(context.cache[key]) > 3:
            context.cache[key].popleft()
    '''    

# Create algorithm object passing in initialize and
# handle_data functions
algo_obj = TradingAlgorithm(initialize=initialize, 
                            handle_data=handle_data)

# Run algorithm
data = pd.read_pickle('bbg_sector_etf_data-12yr.pickle')
perf_manual = algo_obj.run(data)
perf_manual.to_pickle(algo_name+'.pickle')
# Out:
# Bars Completed:  200 2001-10-22 00:00:00+00:00 Pos Value:  0.0 PnL:  0.0
# Bars Completed:
#  300 2002-03-18 00:00:00+00:00 Pos Value:  69205.2643 PnL:  -4110.73754982
# Bars Completed:
#  400 2002-08-08 00:00:00+00:00 Pos Value:  -22191.8922 PnL:  -11143.725261
# Bars Completed:
#  500 2002-12-31 00:00:00+00:00 Pos Value:  26094.0744 PnL:  -12994.5572541
# Bars Completed:
#  600 2003-05-27 00:00:00+00:00 Pos Value:  129298.2536 PnL:  -7161.22985519
# Bars Completed:
#  700 2003-10-16 00:00:00+00:00 Pos Value:  178014.7704 PnL:  6356.86165143
# Bars Completed:
#  800 2004-03-11 00:00:00+00:00 Pos Value:  247325.5337 PnL:  22010.4945574
# Bars Completed:
#  900 2004-08-04 00:00:00+00:00 Pos Value:  132090.7221 PnL:  22286.7349047
# Bars Completed:
#  1000 2004-12-27 00:00:00+00:00 Pos Value:  233232.1876 PnL:  36731.1036715
# Bars Completed:
#  1100 2005-05-19 00:00:00+00:00 Pos Value:  141034.1313 PnL:  35502.4519603
# Bars Completed:
#  1200 2005-10-11 00:00:00+00:00 Pos Value:  171015.3748 PnL:  35515.3018892
# Bars Completed:
#  1300 2006-03-07 00:00:00+00:00 Pos Value:  270104.6416 PnL:  47572.1196606
# Bars Completed:
#  1400 2006-07-28 00:00:00+00:00 Pos Value:  132109.678 PnL:  46671.7706227
# Bars Completed:
#  1500 2006-12-19 00:00:00+00:00 Pos Value:  309793.7138 PnL:  63286.025638
# Bars Completed:
#  1600 2007-05-16 00:00:00+00:00 Pos Value:  368463.9963 PnL:  85351.4351645
# Bars Completed:
#  1700 2007-10-08 00:00:00+00:00 Pos Value:  246989.8626 PnL:  89869.2508541
# Bars Completed:
#  1800 2008-03-03 00:00:00+00:00 Pos Value:  54538.252 PnL:  80171.6075947
# Bars Completed:
#  1900 2008-07-24 00:00:00+00:00 Pos Value:  18193.6515 PnL:  71248.5619332
# Bars Completed:
#  2000 2008-12-15 00:00:00+00:00 Pos Value:  -61273.2018 PnL:  86568.1888825
# Bars Completed:
#  2100 2009-05-11 00:00:00+00:00 Pos Value:  38511.08 PnL:  76016.1093235
# Bars Completed:
#  2200 2009-10-01 00:00:00+00:00 Pos Value:  398628.5199 PnL:  113941.220327
# Bars Completed:
#  2300 2010-02-25 00:00:00+00:00 Pos Value:  350143.4141 PnL:  143248.089647
# Bars Completed:
#  2400 2010-07-20 00:00:00+00:00 Pos Value:  127091.88 PnL:  134582.664203
# Bars Completed:
#  2500 2010-12-09 00:00:00+00:00 Pos Value:  428567.7421 PnL:  161937.888151
# Bars Completed:
#  2600 2011-05-04 00:00:00+00:00 Pos Value:  565795.1517 PnL:  208849.479338
# Bars Completed:
#  2700 2011-09-26 00:00:00+00:00 Pos Value:  12877.7151 PnL:  152050.805382
# Bars Completed:
#  2800 2012-02-17 00:00:00+00:00 Pos Value:  316716.509 PnL:  155460.101867
# Bars Completed:
#  2900 2012-07-12 00:00:00+00:00 Pos Value:  335054.1947 PnL:  146187.562035
# Bars Completed:
#  3000 2012-12-05 00:00:00+00:00 Pos Value:  322552.9956 PnL:  160603.51953
# Bars Completed:
#  3100 2013-05-01 00:00:00+00:00 Pos Value:  482610.8395 PnL:  207780.106935
# Bars Completed:
#  3200 2013-09-23 00:00:00+00:00 Pos Value:  612267.9231 PnL:  250315.054868
# Bars Completed:
#  3300 2014-02-14 00:00:00+00:00 Pos Value:  697668.181 PnL:  301824.077171
# Bars Completed:
# [2014-11-14 18:04] INFO: Performance: Simulated 3480 trading days out of 3480.
# [2014-11-14 18:04] INFO: Performance: first open: 2001-01-02 14:31:00+00:00
# [2014-11-14 18:04] INFO: Performance: last close: 2014-10-31 20:00:00+00:00
#  3400 2014-07-10 00:00:00+00:00 Pos Value:  917590.3036 PnL:  357207.181149

# %%
def file_analyze(filename, begin=0, end=-1):
    data = load_bars_from_yahoo(stocks=['SPY'], start=startdate,
                            end=enddate)
    #data['SPY'].ix[:,:-2].plot(title='SPY', figsize=(15, 3))
    
    perf = pd.read_pickle(filename)[begin:end]
    fig = plt.figure(figsize=(15,10*(len(secs)+1)))
    ax1 = fig.add_subplot(len(secs)+1,1,1)
    perf.portfolio_value.plot(ax=ax1)
    perf.ending_cash.plot(ax=ax1)
    ax1.plot(data['SPY'].index, 1200*data['SPY']['price'])

    ax1.set_ylabel('portfolio value vs cash balance vs benchmark')

    # Display Indicators
    i = 1
    for sec in secs:
        i+=1;
        ax2 = fig.add_subplot(len(secs)+1,1,i)
        perf[sec].plot(ax=ax2)
        perf[[sec+'-s_ma', sec+'-m_ma', sec+'-l_ma']].plot(ax=ax2)

        perf_trans = perf.ix[[t != [] for t in perf.transactions]]

        buys = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] > 0) for trade in t]) for t in perf_trans.transactions]]
        sells = perf_trans.ix[[(True in [(trade['sid']==sec and trade['amount'] < 0) for trade in t]) for t in perf_trans.transactions]]

        buy_markers = [max([(trade['amount'] if (trade['sid']==sec and trade['amount'] > 0) else 0) for trade in t]) for t in perf.transactions.ix[buys.index]]
        sell_markers = [-1*min([(trade['amount'] if (trade['sid']==sec and trade['amount'] < 0) else 0) for trade in t]) for t in perf.transactions.ix[sells.index]]

        ax2.scatter(buys.index, perf[sec].ix[buys.index], s=buy_markers, color='g', marker='^', alpha=.99)
        ax2.scatter(sells.index, perf[sec].ix[sells.index], s=sell_markers, color='r', marker='v', alpha=.99) 
        ax2.set_ylabel(sec+' price in $')

    plt.legend(loc=0)
    plt.show()
algo_name = "Basic Momentum MVA Crossover - SectorETFS - 3x-Asymmetric-Bloomberg-target_value-Levered"

file_analyze(algo_name+'.pickle', 2000,2050)
# Out:
# SPY

# %%
perf = perf_manual
perf_trans = perf.ix[[t != [] for t in perf.transactions]]
trades = perf_trans.ix[[t[0]['amount'] <> 0 for t in perf_trans.transactions]]
commissions = sum([sum([trade['commission'] for trade in t]) for t in perf.ix[trades.index].transactions])
print "Total Commish: ", commissions

from zipline.finance import trading
from zipline.finance import risk
from zipline.utils.factory import create_returns_from_list

env = trading.SimulationParameters(startdate, enddate)
returns_risk = create_returns_from_list(perf.returns.values, env)
my_risk = risk.RiskReport(returns_risk, env)
# Out:
# Total Commish:  395.156

# %%
pd.DataFrame.from_records(my_risk.to_dict()['twelve_month'], index='period_label').ix[[-12*(i)-1 for i in range(13)]]
#print my_risk.year_periods
#print json.dumps(my_risk.to_dict()['one_month'], indent = 2, separators=(',', ': '))
# Out:
#               algo_volatility  algorithm_period_return     alpha  \
# period_label
# 2014-10              0.185654                 0.215969 -0.024360
# 2013-10              0.199692                 0.437078  0.034062
# 2012-10              0.141177                 0.083783  0.009409
# 2011-10              0.235418                -0.026192 -0.063579
# 2010-10              0.254638                 0.159185 -0.012977
# 2009-10              0.269780                 0.233221  0.247659
# 2008-10              0.181741                -0.110538 -0.202546
# 2007-10              0.201107                 0.254531  0.096665
# 2006-10              0.144042                 0.137327 -0.033421
# 2005-10              0.138220                 0.062800 -0.010524
# 2004-10              0.161220                 0.191992  0.101636
# 2003-10              0.155316                 0.211147  0.135238
# 2002-10              0.113211                -0.116920 -0.149643
#
#               benchmark_period_return  benchmark_volatility      beta  \
# period_label
# 2014-10                      0.147647              0.110213  1.632438
# 2013-10                      0.243868              0.117836  1.655293
# 2012-10                      0.126753              0.153977  0.580795
# 2011-10                      0.059192              0.215031  0.623993
# 2010-10                      0.141933              0.181490  1.216328
# 2009-10                      0.069615              0.358120 -0.275175
# 2008-10                     -0.374750              0.346362 -0.202404
# 2007-10                      0.124418              0.135401  1.398113
# 2006-10                      0.141614              0.100152  1.317657
# 2005-10                      0.067961              0.105708  1.215715
# 2004-10                      0.075654              0.112001  1.278484
# 2003-10                      0.186224              0.185829  0.362795
# 2002-10                     -0.164204              0.254499 -0.101355
#
#               excess_return  information  max_drawdown    sharpe   sortino  \
# period_label
# 2014-10            0.214869     0.052169      0.115395  1.157364  1.478530
# 2013-10            0.436078     0.112432      0.111022  2.183753  2.947676
# 2012-10            0.081978    -0.020278      0.127325  0.580680  0.799163
# 2011-10           -0.027392    -0.023750      0.274335 -0.116354 -0.134655
# 2010-10            0.156985     0.014730      0.216526  0.616502  0.727338
# 2009-10            0.229521     0.013882      0.173184  0.850772  1.205083
# 2008-10           -0.123975     0.043270      0.137433 -0.682155 -0.831383
# 2007-10            0.214131     0.087918      0.158112  1.064763  1.218803
# 2006-10            0.087427     0.001515      0.143874  0.606959  0.835163
# 2005-10            0.019700    -0.001000      0.102399  0.142527  0.218748
# 2004-10            0.169129     0.086123      0.116956  1.049058  1.472697
# 2003-10            0.198047     0.005382      0.081374  1.275120  1.570425
# 2002-10           -0.131520     0.006119      0.137727 -1.161723 -1.598990
#
#               trading_days  treasury_period_return
# period_label
# 2014-10                252                0.001100
# 2013-10                252                0.001000
# 2012-10                251                0.001805
# 2011-10                253                0.001200
# 2010-10                251                0.002200
# 2009-10                251                0.003700
# 2008-10                253                0.013437
# 2007-10                251                0.040400
# 2006-10                252                0.049900
# 2005-10                253                0.043100
# 2004-10                250                0.022862
# 2003-10                252                0.013100
# 2002-10                252                0.014600
